# %% [markdown]
# ## 00. Quick Start

# %%
print('Concept Portfolio V2 Lab — staged와 one-click은 동일 Core를 사용합니다.')
print('LIVE_TEST_LEVEL로 CORE / LEGAL_C1 / FULL_E2E / ONE_CLICK 중 하나만 선택하세요.')
# Out:
# Concept Portfolio V2 Lab — staged와 one-click은 동일 Core를 사용합니다.
# LIVE_TEST_LEVEL로 CORE / LEGAL_C1 / FULL_E2E / ONE_CLICK 중 하나만 선택하세요.

# %% [markdown]
# ## 01. Environment

# %%
import os, sys, json
from pathlib import Path
from IPython.display import display
SEARCH_ROOTS = [Path.cwd(), *Path.cwd().parents]
AI_ROOT = next((p for p in SEARCH_ROOTS if (p / 'app').is_dir()), None)
if AI_ROOT is None: AI_ROOT = next((p / 'ai' for p in SEARCH_ROOTS if (p / 'ai' / 'app').is_dir()))
if str(AI_ROOT) not in sys.path: sys.path.insert(0, str(AI_ROOT))
print({'python': sys.version.split()[0], 'aiRoot': str(AI_ROOT)})
# Out:
# {'python': '3.14.5', 'aiRoot': 'C:\\Users\\seewo\\Desktop\\big_proj_01\\new_3\\ai'}

# %% [markdown]
# ## 02. MODE

# %%
MODE = 'LIVE'  # MOCK | REPLAY | LIVE
RECORDINGS_DIR = AI_ROOT / 'recordings' / 'concept_portfolio_v2'
print({'mode': MODE, 'liveExternalOperationsEnabled': MODE == 'LIVE'})
# Out:
# {'mode': 'LIVE', 'liveExternalOperationsEnabled': True}

# %% [markdown]
# ## 03. Environment Check

# %%
LIVE_ENV_KEYS = ['AI_PROVIDER', 'AI_API_KEY', 'AI_MODEL', 'MOLEG_API_KEY', 'LEGAL_REGISTRY_VERSION']
env_status = {key: bool(os.getenv(key)) for key in LIVE_ENV_KEYS}
print(env_status if MODE == 'LIVE' else {'mode': MODE, 'message': '외부 환경변수 불필요'})
# Out:
# {'AI_PROVIDER': True, 'AI_API_KEY': True, 'AI_MODEL': True, 'MOLEG_API_KEY': True, 'LEGAL_REGISTRY_VERSION': True}

# %% [markdown]
# ## 04. Schema Preflight

# %%
from app.concept_portfolio_v2 import ConceptPortfolioEngine, ProviderGateway, ProviderMode
from app.concept_portfolio_v2.adapters import CurrentLegalAdapter
from app.concept_portfolio_v2.diagnostics.notebook_view import *
gateway = ProviderGateway(MODE, recordings_dir=RECORDINGS_DIR)
engine = ConceptPortfolioEngine(MODE, gateway=gateway)
schema_preflight = engine.schema_preflight_report()
display(show_schema_preflight(schema_preflight))
assert schema_preflight.status == 'PASS' and schema_preflight.providerCalls == 0
# Out:
#                                 스키마    상태  실패  Provider 호출
# 0                     PlanDraftPool  PASS  []            0
# 1             ConceptCandidateDraft  PASS  []            0
# 2        SemanticDistinctnessResult  PASS  []            0
# 3            SemanticFidelityResult  PASS  []            0
# 4         SemanticArchitectureBatch  PASS  []            0
# 5           SemanticHypothesisBatch  PASS  []            0
# 6         BusinessRoleSemanticBatch  PASS  []            0
# 7  LegalFactDependencySemanticBatch  PASS  []            0
# 8          LegalFactCompletionPatch  PASS  []            0

# %% [markdown]
# ## 05. Input

# %%
SCENARIO_FILE = AI_ROOT / 'fixtures' / 'concept_portfolio_v2' / 'live_scenarios.json'
SCENARIOS = {item['scenarioId']: item for item in json.loads(SCENARIO_FILE.read_text(encoding='utf-8'))}
LIVE_SCENARIO = 'WEEKEND_TRIP_PLANNER'
LIVE_TEST_LEVEL = 'FULL_E2E'  # CORE | LEGAL_C1 | FULL_E2E | ONE_CLICK
RUN_STAGED_CORE = LIVE_TEST_LEVEL in {'CORE', 'LEGAL_C1', 'FULL_E2E'}
RUN_STAGED_LEGAL = LIVE_TEST_LEVEL in {'LEGAL_C1', 'FULL_E2E'}
RUN_STAGED_FULL = LIVE_TEST_LEVEL == 'FULL_E2E'
scenario = SCENARIOS[LIVE_SCENARIO]
TEST_INPUT = {key: scenario[key] for key in ('ideaOverview', 'problem', 'targetUsers')}
MAX_CONCEPTS = 5
display({'scenario': LIVE_SCENARIO, 'testLevel': LIVE_TEST_LEVEL, 'domain': scenario['domain'],
         'expectedStructuralFeatures': scenario['expectedStructuralFeatures']})
# Out:
# {'scenario': 'WEEKEND_TRIP_PLANNER',
#  'testLevel': 'FULL_E2E',
#  'domain': 'Travel planning',
#  'expectedStructuralFeatures': ['디지털 계획', '예약 연결 역할과 직접 판매 구분']}

# %% [markdown]
# ## 06. Idea Brief Derivation

# %%
seed = engine.seed_adapter.adapt(TEST_INPUT)
idea_context = None
if RUN_STAGED_CORE:
    engine._reset()
    idea_context = await engine.derive_idea_brief(seed)
print({'ideaCallComplete': bool(idea_context), 'interpretationPresent': bool(seed.interpretation),
       'stagedCore': RUN_STAGED_CORE})
# Out:
# {'ideaCallComplete': True, 'interpretationPresent': True, 'stagedCore': True}

# %% [markdown]
# ## 07. Safety

# %%
display(idea_context.safetyReview.model_dump(mode='json') if idea_context else {'status': 'SKIPPED'})
assert idea_context is None or idea_context.safetyReview.passed
# Out:
# {'decision': 'ALLOW',
#  'categories': [],
#  'restrictions': [],
#  'userFacingReason': '이 아이디어는 안전하며, 여행 계획 서비스를 제공하는 것으로 보입니다.'}

# %% [markdown]
# ## 08. AI가 이해한 아이디어

# %%
display(show_idea_interpretation(idea_context) if idea_context else {'status': 'SKIPPED'})
# Out:
#                                항목  \
# 0              interpretedProblem
# 1          interpretedTargetUsers
# 2                    usageContext
# 3                industryCategory
# 4                   researchScope
# 5           conciseIdeaDefinition
# 6      targetRegionInterpretation
# 7  relevantKnownCompetitorContext
#
#                                             AI 이해 결과
# 0               짧은 주말 여행을 계획하는 데 소요되는 시간과 노력을 줄이는 것.
# 1                           주말에 짧은 여행을 자주 계획하는 직장인들.
# 2  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 3                                            여행 및 관광
# 4                                       주말 여행 계획 서비스
# 5  사용자의 이동 가능 시간과 관심사를 기반으로 주말 여행 일정을 자동으로 구성하는 서비스.
# 6                                    대상 지역은 명시되지 않음.
# 7                                      경쟁자는 명시되지 않음.

# %% [markdown]
# ## 09. Readiness / Summary / commitments

# %%
display(show_idea_readiness(idea_context) if idea_context else {'status': 'SKIPPED'})
# Out:
# {'readiness': {'status': 'READY_FOR_REVIEW',
#   'score': 0,
#   'missingFieldKeys': []},
#  'readinessDiagnostic': 'READINESS_INCONSISTENT',
#  'userFacingSummary': '이 서비스는 사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동으로 구성하고, 숙박 및 체험 예약 페이지로 연결하는 기능을 제공합니다.',
#  'commitmentCandidates': [],
#  'contradictions': [],
#  'questions': []}

# %% [markdown]
# ## 10. Seed Analysis

# %%
analysis = await engine.analyze_seed(seed) if RUN_STAGED_CORE else None
display(show_seed_analysis(analysis) if analysis else {'status': 'SKIPPED'})
# Out:
#         구분                                                  값
# 0     탐색 폭                                            EXPLORE
# 1  다양성 수용량                                                  5
# 2       설명  선택 입력 LOCK 0개로 11개 설계 차원이 열려 있습니다. diversityCa...

# %% [markdown]
# ## 11. Generic Opportunity Kernel

# %%
display(analysis.opportunityKernel.model_dump(mode='json') if analysis else {'status': 'SKIPPED'})
# Out:
# {'problemCore': '짧은 주말 여행을 계획하는 데 소요되는 시간과 노력을 줄이는 것.',
#  'targetCore': '주말에 짧은 여행을 자주 계획하는 직장인들.',
#  'useContexts': ['사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 페이지로 연결하는 서비스.'],
#  'intentComponents': ['사용자의 이동 가능 시간과 관심사를 기반으로 주말 여행 일정을 자동으로 구성하는 서비스.'],
#  'mustPreserve': ['짧은 주말 여행을 계획하는 데 소요되는 시간과 노력을 줄이는 것.',
#   '주말에 짧은 여행을 자주 계획하는 직장인들.',
#   '사용자의 이동 가능 시간과 관심사를 기반으로 주말 여행 일정을 자동으로 구성하는 서비스.'],
#  'maySpecialize': ['핵심 대상의 의미 있는 하위 세그먼트',
#   '핵심 사용 맥락의 구체화',
#   '가치 제안 또는 offer의 구체화'],
#  'forbiddenDriftSummary': '핵심 문제와 대상이 모두 무관한 기회로 교체되면 범위를 벗어납니다.'}

# %% [markdown]
# ## 12. Design Space

# %%
display(show_design_space(analysis) if analysis else {'status': 'SKIPPED'})
# Out:
#                  분류                  필드  \
# 0       SOURCE_LOCK        ideaOverview
# 1       SOURCE_LOCK             problem
# 2       SOURCE_LOCK         targetUsers
# 3   SEMANTIC_ANCHOR        ideaOverview
# 4   SEMANTIC_ANCHOR             problem
# 5   SEMANTIC_ANCHOR         targetUsers
# 6              OPEN   solutionMechanism
# 7              OPEN       valueDelivery
# 8              OPEN      operatingModel
# 9              OPEN     supplyStructure
# 10             OPEN        partnerModel
# 11             OPEN     transactionFlow
# 12             OPEN         fulfillment
# 13             OPEN        platformRole
# 14             OPEN      commercialFlow
# 15             OPEN      dataDependency
# 16             OPEN  physicalDependency
#
#                                                     값
# 0   사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고...
# 1      짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.
# 2                          주말 1~2일 단기 여행을 자주 계획하는 직장인
# 3   사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고...
# 4      짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.
# 5                          주말 1~2일 단기 여행을 자주 계획하는 직장인
# 6                                               변경 가능
# 7                                               변경 가능
# 8                                               변경 가능
# 9                                               변경 가능
# 10                                              변경 가능
# 11                                              변경 가능
# 12                                              변경 가능
# 13                                              변경 가능
# 14                                              변경 가능
# 15                                              변경 가능
# 16                                              변경 가능

# %% [markdown]
# ## 13. Generate and Adaptively Replenish Plan Pool

# %%
plan_validation = (await engine.prepare_portfolio_plans(seed, analysis, max_concepts=MAX_CONCEPTS)
                   if RUN_STAGED_CORE else None)
plans = engine._last_plan_pool if plan_validation else []
print({'totalPlans': len(plans),
       'planningRounds': plan_validation.planningRounds if plan_validation else 0,
       'replenishmentRequested': plan_validation.replenishmentRequested if plan_validation else 0})
# Out:
# {'totalPlans': 9, 'planningRounds': 2, 'replenishmentRequested': 3}

# %% [markdown]
# ## 14. Plan Count / Adaptive Replenishment Check

# %%
display(show_plan_pool_status(engine._last_plan_pool_status) if plan_validation else {'status': 'SKIPPED'})
display({'planningRounds': plan_validation.planningRounds if plan_validation else 0,
         'replenishmentRequested': plan_validation.replenishmentRequested if plan_validation else 0,
         'adaptiveReplenishmentUsed': bool(plan_validation and plan_validation.planningRounds > 1)})
# Out:
#    requestedPoolSize  returnedPoolSize  initialTarget  reserveTarget  \
# 0                  7                 6              5              2
#
#    reserveAvailable             status
# 0                 0  RESERVE_SHORTFALL
# {'planningRounds': 2,
#  'replenishmentRequested': 3,
#  'adaptiveReplenishmentUsed': True}

# %% [markdown]
# ## 15. Korean Plan Display

# %%
display(show_portfolio_plans(plan_validation.acceptedPlans + plan_validation.reservePlans)
        if plan_validation else {'status': 'SKIPPED'})
# Out:
#   planId                 제목     선택 상태  selectionScore  \
# 0     P1  주말 여행 자동 계획 서비스 A  SELECTED          0.9035
# 1     P8    주말 여행 일정 자동 생성기  SELECTED          0.7808
# 2     P3  주말 여행 자동 계획 서비스 C  SELECTED          0.7308
# 3     P9       주말 여행 계획 도우미  SELECTED          0.7154
# 4     P2  주말 여행 자동 계획 서비스 B  SELECTED          0.6413
# 5     P7   주말 여행 맞춤형 추천 서비스   RESERVE          0.6920
#
#                                      selectionReason relationToPortfolio  \
# 0        Opportunity fit과 Concept clarity가 가장 높은 대표안      PORTFOLIO_SEED
# 1  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 2  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 3  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 4  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 5  Selected Portfolio 대비 marginal value가 낮아 reser...             VARIANT
#
#       Concept Family             Target Thesis  \
# 0    기타 역할 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 1  플랫폼 인프라 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 2    기타 역할 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 3  플랫폼 인프라 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 4    기타 역할 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 5  플랫폼 인프라 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
#
#                                          Use Context  \
# 0  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 1    사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하는 서비스.
# 2  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 3         사용자가 이동 가능 시간과 관심사를 입력하면, 여행 계획을 도와주는 서비스.
# 4  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 5  사용자가 선호하는 여행 스타일과 이동 가능 시간을 입력하면, 맞춤형 여행지를 추천하...
#
#                                     Value Thesis  \
# 0  사용자는 간편하게 주말 여행을 계획할 수 있으며, 시간과 노력을 절약할 수 있다.
# 1                  사용자는 간편하게 주말 여행 일정을 계획할 수 있다.
# 2   사용자는 간편하게 여행 계획을 세울 수 있으며, 시간과 노력을 절약할 수 있다.
# 3                   사용자는 간편하게 주말 여행 계획을 세울 수 있다.
# 4   사용자는 손쉽게 여행 계획을 세울 수 있으며, 더 많은 시간을 절약할 수 있다.
# 5               사용자는 개인의 취향에 맞는 여행지를 쉽게 찾을 수 있다.
#
#                                      Offer Thesis  \
# 0        사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 여행 일정을 제공한다.
# 1  사용자의 이동 가능 시간과 관심사를 반영한 자동 여행 일정 생성 서비스를 제공한다.
# 2        사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 여행 일정을 제공한다.
# 3    사용자의 이동 가능 시간과 관심사를 반영한 여행 계획 도우미 서비스를 제공한다.
# 4                  사용자의 선호를 반영한 개인화된 여행 일정을 제공한다.
# 5    사용자의 취향과 이동 가능 시간을 반영한 맞춤형 여행지 추천 서비스를 제공한다.
#
#                                      Solution Thesis  \
# 0    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.
# 1  사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.
# 2    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.
# 3           사용자가 입력한 정보를 바탕으로 여행 계획을 도와주는 시스템을 구축한다.
# 4    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.
# 5         사용자가 입력한 정보를 바탕으로 최적의 여행지를 추천하는 시스템을 구축한다.
#
#                                         Architecture  \
# 0  {'businessRole': 'OTHER', 'operatingModel': 'A...
# 1  {'businessRole': 'PLATFORM_INFRASTRUCTURE', 'o...
# 2  {'businessRole': 'OTHER', 'operatingModel': 'A...
# 3  {'businessRole': 'PLATFORM_INFRASTRUCTURE', 'o...
# 4  {'businessRole': 'OTHER', 'operatingModel': 'A...
# 5  {'businessRole': 'PLATFORM_INFRASTRUCTURE', 'o...
#
#                                  비교 가치
# 0  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 1  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 2  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 3  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 4  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 5  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.

# %% [markdown]
# ## 16. Plan Lock/Intent Validation

# %%
display({'accepted': [p.planId for p in plan_validation.acceptedPlans] if plan_validation else [],
         'rejected': [p.model_dump(mode='json') for p in plan_validation.rejectedPlans]
                     if plan_validation else []})
# Out:
# {'accepted': ['P1', 'P8', 'P3', 'P9', 'P2'],
#  'rejected': [{'planId': 'P4',
#    'reasonCode': 'PLAN_DUPLICATE',
#    'safeSummary': 'Concept Thesis와 Architecture가 기존 Plan과 사실상 같습니다.',
#    'conflictPlanId': 'P2'},
#   {'planId': 'P5',
#    'reasonCode': 'PLAN_DUPLICATE',
#    'safeSummary': 'Concept Thesis와 Architecture가 기존 Plan과 사실상 같습니다.',
#    'conflictPlanId': 'P3'},
#   {'planId': 'P6',
#    'reasonCode': 'PLAN_DUPLICATE',
#    'safeSummary': 'Concept Thesis와 Architecture가 기존 Plan과 사실상 같습니다.',
#    'conflictPlanId': 'P2'}]}

# %% [markdown]
# ## 17. Portfolio Family / Variant / Distinct

# %%
display(show_plan_diversity(plan_validation.diversity) if plan_validation else {'status': 'SKIPPED'})
# Out:
#      A   B         판정                                   Family A  \
# 0   P1  P2    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 1   P1  P3    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 2   P2  P3    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 3   P1  P4    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 4   P2  P4  DUPLICATE                    OTHER:AUTOMATED_DIGITAL
# 5   P1  P5    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 6   P2  P5    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 7   P3  P5  DUPLICATE                    OTHER:AUTOMATED_DIGITAL
# 8   P1  P6    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 9   P2  P6  DUPLICATE                    OTHER:AUTOMATED_DIGITAL
# 10  P1  P7    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 11  P2  P7    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 12  P3  P7    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 13  P1  P8    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 14  P2  P8    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 15  P3  P8    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 16  P7  P8    VARIANT  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 17  P1  P9    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 18  P2  P9    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 19  P3  P9    VARIANT                    OTHER:AUTOMATED_DIGITAL
# 20  P7  P9    VARIANT  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 21  P8  P9    VARIANT  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
#
#                                      Family B  \
# 0                     OTHER:AUTOMATED_DIGITAL
# 1                     OTHER:AUTOMATED_DIGITAL
# 2                     OTHER:AUTOMATED_DIGITAL
# 3                     OTHER:AUTOMATED_DIGITAL
# 4                     OTHER:AUTOMATED_DIGITAL
# 5                     OTHER:AUTOMATED_DIGITAL
# 6                     OTHER:AUTOMATED_DIGITAL
# 7                     OTHER:AUTOMATED_DIGITAL
# 8                     OTHER:AUTOMATED_DIGITAL
# 9                     OTHER:AUTOMATED_DIGITAL
# 10  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 11  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 12  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 13  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 14  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 15  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 16  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 17  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 18  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 19  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 20  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
# 21  PLATFORM_INFRASTRUCTURE:AUTOMATED_DIGITAL
#
#                                                    겹침  \
# 0   businessRole, operatingModel, partnerModel, de...
# 1   businessRole, operatingModel, partnerModel, de...
# 2   businessRole, operatingModel, partnerModel, de...
# 3   businessRole, operatingModel, partnerModel, de...
# 4   businessRole, operatingModel, partnerModel, de...
# 5   businessRole, operatingModel, partnerModel, de...
# 6   businessRole, operatingModel, partnerModel, de...
# 7   businessRole, operatingModel, partnerModel, de...
# 8   businessRole, operatingModel, partnerModel, de...
# 9   businessRole, operatingModel, partnerModel, de...
# 10  operatingModel, partnerModel, transactionModel...
# 11  operatingModel, partnerModel, transactionModel...
# 12  operatingModel, partnerModel, transactionModel...
# 13  operatingModel, partnerModel, transactionModel...
# 14  operatingModel, partnerModel, transactionModel...
# 15  operatingModel, partnerModel, transactionModel...
# 16  businessRole, operatingModel, partnerModel, de...
# 17  operatingModel, partnerModel, transactionModel...
# 18  operatingModel, partnerModel, transactionModel...
# 19  operatingModel, partnerModel, transactionModel...
# 20  businessRole, operatingModel, partnerModel, de...
# 21  businessRole, operatingModel, partnerModel, de...
#
#                                                 실질 차이  \
# 0                 valuePropositionThesis, offerThesis
# 1                              valuePropositionThesis
# 2                 valuePropositionThesis, offerThesis
# 3                 valuePropositionThesis, offerThesis
# 4
# 5                              valuePropositionThesis
# 6                 valuePropositionThesis, offerThesis
# 7
# 8                 valuePropositionThesis, offerThesis
# 9
# 10  businessRole, monetizationModel, deliveryModel...
# 11  businessRole, monetizationModel, deliveryModel...
# 12  businessRole, monetizationModel, deliveryModel...
# 13  businessRole, monetizationModel, deliveryModel...
# 14  businessRole, monetizationModel, deliveryModel...
# 15  businessRole, monetizationModel, deliveryModel...
# 16  useCaseThesis, valuePropositionThesis, offerTh...
# 17  businessRole, monetizationModel, deliveryModel...
# 18  businessRole, monetizationModel, deliveryModel...
# 19  businessRole, monetizationModel, deliveryModel...
# 20  useCaseThesis, valuePropositionThesis, offerTh...
# 21                                     solutionThesis
#
#                            단계  semantic judge  \
# 0   MEANINGFUL_THESIS_VARIANT           False
# 1   MEANINGFUL_THESIS_VARIANT           False
# 2   MEANINGFUL_THESIS_VARIANT           False
# 3   MEANINGFUL_THESIS_VARIANT           False
# 4     THESIS_AND_ARCHITECTURE           False
# 5   MEANINGFUL_THESIS_VARIANT           False
# 6   MEANINGFUL_THESIS_VARIANT           False
# 7     THESIS_AND_ARCHITECTURE           False
# 8   MEANINGFUL_THESIS_VARIANT           False
# 9     THESIS_AND_ARCHITECTURE           False
# 10  MEANINGFUL_THESIS_VARIANT           False
# 11  MEANINGFUL_THESIS_VARIANT           False
# 12  MEANINGFUL_THESIS_VARIANT           False
# 13  MEANINGFUL_THESIS_VARIANT           False
# 14  MEANINGFUL_THESIS_VARIANT           False
# 15  MEANINGFUL_THESIS_VARIANT           False
# 16  MEANINGFUL_THESIS_VARIANT           False
# 17  MEANINGFUL_THESIS_VARIANT           False
# 18  MEANINGFUL_THESIS_VARIANT           False
# 19  MEANINGFUL_THESIS_VARIANT           False
# 20  MEANINGFUL_THESIS_VARIANT           False
# 21  MEANINGFUL_THESIS_VARIANT           False
#
#                                                 관계 설명
# 0   Architecture family는 유사하지만 target/use case/val...
# 1   Architecture family는 유사하지만 target/use case/val...
# 2   Architecture family는 유사하지만 target/use case/val...
# 3   Architecture family는 유사하지만 target/use case/val...
# 4   이름이나 표현을 제외한 Concept Thesis와 Business Architec...
# 5   Architecture family는 유사하지만 target/use case/val...
# 6   Architecture family는 유사하지만 target/use case/val...
# 7   이름이나 표현을 제외한 Concept Thesis와 Business Architec...
# 8   Architecture family는 유사하지만 target/use case/val...
# 9   이름이나 표현을 제외한 Concept Thesis와 Business Architec...
# 10  Architecture family는 유사하지만 target/use case/val...
# 11  Architecture family는 유사하지만 target/use case/val...
# 12  Architecture family는 유사하지만 target/use case/val...
# 13  Architecture family는 유사하지만 target/use case/val...
# 14  Architecture family는 유사하지만 target/use case/val...
# 15  Architecture family는 유사하지만 target/use case/val...
# 16  Architecture family는 유사하지만 target/use case/val...
# 17  Architecture family는 유사하지만 target/use case/val...
# 18  Architecture family는 유사하지만 target/use case/val...
# 19  Architecture family는 유사하지만 target/use case/val...
# 20  Architecture family는 유사하지만 target/use case/val...
# 21  Architecture family는 유사하지만 target/use case/val...

# %% [markdown]
# ## 18. Selected + Reserve Plans

# %%
selected_plans = plan_validation.acceptedPlans if plan_validation else []
reserve_plans = plan_validation.reservePlans if plan_validation else []
display(show_portfolio_plans(selected_plans + reserve_plans))
display({'selected': [p.planId for p in selected_plans], 'reserve': [p.planId for p in reserve_plans]})
# Out:
#   planId                 제목     선택 상태  selectionScore  \
# 0     P1  주말 여행 자동 계획 서비스 A  SELECTED          0.9035
# 1     P8    주말 여행 일정 자동 생성기  SELECTED          0.7808
# 2     P3  주말 여행 자동 계획 서비스 C  SELECTED          0.7308
# 3     P9       주말 여행 계획 도우미  SELECTED          0.7154
# 4     P2  주말 여행 자동 계획 서비스 B  SELECTED          0.6413
# 5     P7   주말 여행 맞춤형 추천 서비스   RESERVE          0.6920
#
#                                      selectionReason relationToPortfolio  \
# 0        Opportunity fit과 Concept clarity가 가장 높은 대표안      PORTFOLIO_SEED
# 1  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 2  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 3  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 4  같은 Family를 허용하면서 의미 있는 target/use/value Varian...             VARIANT
# 5  Selected Portfolio 대비 marginal value가 낮아 reser...             VARIANT
#
#       Concept Family             Target Thesis  \
# 0    기타 역할 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 1  플랫폼 인프라 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 2    기타 역할 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 3  플랫폼 인프라 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 4    기타 역할 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
# 5  플랫폼 인프라 · 디지털 자동화  주말에 짧은 여행을 자주 계획하는 직장인들.
#
#                                          Use Context  \
# 0  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 1    사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하는 서비스.
# 2  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 3         사용자가 이동 가능 시간과 관심사를 입력하면, 여행 계획을 도와주는 서비스.
# 4  사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 ...
# 5  사용자가 선호하는 여행 스타일과 이동 가능 시간을 입력하면, 맞춤형 여행지를 추천하...
#
#                                     Value Thesis  \
# 0  사용자는 간편하게 주말 여행을 계획할 수 있으며, 시간과 노력을 절약할 수 있다.
# 1                  사용자는 간편하게 주말 여행 일정을 계획할 수 있다.
# 2   사용자는 간편하게 여행 계획을 세울 수 있으며, 시간과 노력을 절약할 수 있다.
# 3                   사용자는 간편하게 주말 여행 계획을 세울 수 있다.
# 4   사용자는 손쉽게 여행 계획을 세울 수 있으며, 더 많은 시간을 절약할 수 있다.
# 5               사용자는 개인의 취향에 맞는 여행지를 쉽게 찾을 수 있다.
#
#                                      Offer Thesis  \
# 0        사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 여행 일정을 제공한다.
# 1  사용자의 이동 가능 시간과 관심사를 반영한 자동 여행 일정 생성 서비스를 제공한다.
# 2        사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 여행 일정을 제공한다.
# 3    사용자의 이동 가능 시간과 관심사를 반영한 여행 계획 도우미 서비스를 제공한다.
# 4                  사용자의 선호를 반영한 개인화된 여행 일정을 제공한다.
# 5    사용자의 취향과 이동 가능 시간을 반영한 맞춤형 여행지 추천 서비스를 제공한다.
#
#                                      Solution Thesis  \
# 0    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.
# 1  사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.
# 2    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.
# 3           사용자가 입력한 정보를 바탕으로 여행 계획을 도와주는 시스템을 구축한다.
# 4    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.
# 5         사용자가 입력한 정보를 바탕으로 최적의 여행지를 추천하는 시스템을 구축한다.
#
#                                         Architecture  \
# 0  {'businessRole': 'OTHER', 'operatingModel': 'A...
# 1  {'businessRole': 'PLATFORM_INFRASTRUCTURE', 'o...
# 2  {'businessRole': 'OTHER', 'operatingModel': 'A...
# 3  {'businessRole': 'PLATFORM_INFRASTRUCTURE', 'o...
# 4  {'businessRole': 'OTHER', 'operatingModel': 'A...
# 5  {'businessRole': 'PLATFORM_INFRASTRUCTURE', 'o...
#
#                                  비교 가치
# 0  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 1  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 2  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 3  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 4  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# 5  주말 여행 계획의 효율성을 높이고 사용자 경험을 개선하기 위해.
# {'selected': ['P1', 'P8', 'P3', 'P9', 'P2'], 'reserve': ['P7']}

# %% [markdown]
# ## 19. Candidate 1

# %%
candidate_one = (await engine.expand_plan(seed, selected_plans[0], 1)
                 if RUN_STAGED_CORE and selected_plans else None)
display(show_candidates([candidate_one]) if candidate_one else [])
# Out:
#   candidateId lineageId parentCandidateId                 이름  \
# 0          C1        L1              None  주말 여행 자동 계획 서비스 A
#
#                                            핵심 작동방식           family  \
# 0  자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
#
#                                           descriptor  \
# 0  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#
#                                수익                                    운영
# 0  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.  데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.

# %% [markdown]
# ## 20. Candidate 1 Korean/Governance

# %%
candidate_one_reports = []
display({'candidateId': candidate_one.candidateId if candidate_one else None,
         'status': 'PENDING_FULL_CANDIDATE_RECOVERY'})
# Out:
# {'candidateId': 'C1', 'status': 'PENDING_FULL_CANDIDATE_RECOVERY'}

# %% [markdown]
# ## 21. Candidate 1 Actual Generic Descriptor

# %%
display(show_concept_descriptors([candidate_one]) if candidate_one else [])
# Out:
#   entityId                   family                 dimension  \
# 0       C1  OTHER:AUTOMATED_DIGITAL              businessRole
# 1       C1  OTHER:AUTOMATED_DIGITAL            operatingModel
# 2       C1  OTHER:AUTOMATED_DIGITAL              partnerModel
# 3       C1  OTHER:AUTOMATED_DIGITAL             deliveryModel
# 4       C1  OTHER:AUTOMATED_DIGITAL          transactionModel
# 5       C1  OTHER:AUTOMATED_DIGITAL         monetizationModel
# 6       C1  OTHER:AUTOMATED_DIGITAL  customerInteractionModel
# 7       C1  OTHER:AUTOMATED_DIGITAL            dataDependency
# 8       C1  OTHER:AUTOMATED_DIGITAL        physicalDependency
#
#                 code confidence   source
# 0              OTHER        LOW  UNKNOWN
# 1  AUTOMATED_DIGITAL       HIGH     RULE
# 2    PARTNER_NETWORK       HIGH     RULE
# 3              OTHER        LOW  UNKNOWN
# 4            BOOKING       HIGH     RULE
# 5              OTHER        LOW  UNKNOWN
# 6              OTHER        LOW  UNKNOWN
# 7           MATERIAL        NaN      NaN
# 8           MATERIAL        NaN      NaN

# %% [markdown]
# ## 22. Candidate 1 Fidelity

# %%
display({'candidateId': candidate_one.candidateId if candidate_one else None,
         'fidelity': '전체 Candidate Recovery 단계에서 semantic fallback 포함 검증'})
# Out:
# {'candidateId': 'C1',
#  'fidelity': '전체 Candidate Recovery 단계에서 semantic fallback 포함 검증'}

# %% [markdown]
# ## 23. Remaining Candidates

# %%
remaining_candidates = []
if RUN_STAGED_CORE:
    for i, plan in enumerate(selected_plans[1:], 2):
        remaining_candidates.append(await engine.expand_plan(seed, plan, i))
candidate_drafts = ([candidate_one] if candidate_one else []) + remaining_candidates
display(show_candidates(candidate_drafts))
# Out:
#   candidateId lineageId parentCandidateId                 이름  \
# 0          C1        L1              None  주말 여행 자동 계획 서비스 A
# 1          C2        L2              None    주말 여행 일정 자동 생성기
# 2          C3        L3              None  주말 여행 자동 계획 서비스 C
# 3          C4        L4              None       주말 여행 계획 도우미
# 4          C5        L5              None  주말 여행 자동 계획 서비스 B
#
#                                              핵심 작동방식           family  \
# 0    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
# 1  사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.  거래 중개 · 디지털 자동화
# 2    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
# 3           사용자가 입력한 정보를 바탕으로 여행 계획을 도와주는 시스템을 구축한다.  거래 중개 · 디지털 자동화
# 4    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
#
#                                           descriptor  \
# 0  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
# 1  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
# 2  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
# 3  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
# 4  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#
#                                수익  \
# 0  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 1  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 2  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 3  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 4  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#
#                                                운영
# 0            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
# 1            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
# 2            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
# 3  데이터 분석 및 알고리즘을 통해 사용자 맞춤형 여행 계획 도우미 서비스를 제공한다.
# 4            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.

# %% [markdown]
# ## 24. Candidate Actual Generic Descriptors

# %%
display(show_concept_descriptors(candidate_drafts))
# Out:
#    entityId                          family                 dimension  \
# 0        C1         OTHER:AUTOMATED_DIGITAL              businessRole
# 1        C1         OTHER:AUTOMATED_DIGITAL            operatingModel
# 2        C1         OTHER:AUTOMATED_DIGITAL              partnerModel
# 3        C1         OTHER:AUTOMATED_DIGITAL             deliveryModel
# 4        C1         OTHER:AUTOMATED_DIGITAL          transactionModel
# 5        C1         OTHER:AUTOMATED_DIGITAL         monetizationModel
# 6        C1         OTHER:AUTOMATED_DIGITAL  customerInteractionModel
# 7        C1         OTHER:AUTOMATED_DIGITAL            dataDependency
# 8        C1         OTHER:AUTOMATED_DIGITAL        physicalDependency
# 9        C2  INTERMEDIARY:AUTOMATED_DIGITAL              businessRole
# 10       C2  INTERMEDIARY:AUTOMATED_DIGITAL            operatingModel
# 11       C2  INTERMEDIARY:AUTOMATED_DIGITAL              partnerModel
# 12       C2  INTERMEDIARY:AUTOMATED_DIGITAL             deliveryModel
# 13       C2  INTERMEDIARY:AUTOMATED_DIGITAL          transactionModel
# 14       C2  INTERMEDIARY:AUTOMATED_DIGITAL         monetizationModel
# 15       C2  INTERMEDIARY:AUTOMATED_DIGITAL  customerInteractionModel
# 16       C2  INTERMEDIARY:AUTOMATED_DIGITAL            dataDependency
# 17       C2  INTERMEDIARY:AUTOMATED_DIGITAL        physicalDependency
# 18       C3         OTHER:AUTOMATED_DIGITAL              businessRole
# 19       C3         OTHER:AUTOMATED_DIGITAL            operatingModel
# 20       C3         OTHER:AUTOMATED_DIGITAL              partnerModel
# 21       C3         OTHER:AUTOMATED_DIGITAL             deliveryModel
# 22       C3         OTHER:AUTOMATED_DIGITAL          transactionModel
# 23       C3         OTHER:AUTOMATED_DIGITAL         monetizationModel
# 24       C3         OTHER:AUTOMATED_DIGITAL  customerInteractionModel
# 25       C3         OTHER:AUTOMATED_DIGITAL            dataDependency
# 26       C3         OTHER:AUTOMATED_DIGITAL        physicalDependency
# 27       C4  INTERMEDIARY:AUTOMATED_DIGITAL              businessRole
# 28       C4  INTERMEDIARY:AUTOMATED_DIGITAL            operatingModel
# 29       C4  INTERMEDIARY:AUTOMATED_DIGITAL              partnerModel
# 30       C4  INTERMEDIARY:AUTOMATED_DIGITAL             deliveryModel
# 31       C4  INTERMEDIARY:AUTOMATED_DIGITAL          transactionModel
# 32       C4  INTERMEDIARY:AUTOMATED_DIGITAL         monetizationModel
# 33       C4  INTERMEDIARY:AUTOMATED_DIGITAL  customerInteractionModel
# 34       C4  INTERMEDIARY:AUTOMATED_DIGITAL            dataDependency
# 35       C4  INTERMEDIARY:AUTOMATED_DIGITAL        physicalDependency
# 36       C5         OTHER:AUTOMATED_DIGITAL              businessRole
# 37       C5         OTHER:AUTOMATED_DIGITAL            operatingModel
# 38       C5         OTHER:AUTOMATED_DIGITAL              partnerModel
# 39       C5         OTHER:AUTOMATED_DIGITAL             deliveryModel
# 40       C5         OTHER:AUTOMATED_DIGITAL          transactionModel
# 41       C5         OTHER:AUTOMATED_DIGITAL         monetizationModel
# 42       C5         OTHER:AUTOMATED_DIGITAL  customerInteractionModel
# 43       C5         OTHER:AUTOMATED_DIGITAL            dataDependency
# 44       C5         OTHER:AUTOMATED_DIGITAL        physicalDependency
#
#                  code confidence   source
# 0               OTHER        LOW  UNKNOWN
# 1   AUTOMATED_DIGITAL       HIGH     RULE
# 2     PARTNER_NETWORK       HIGH     RULE
# 3               OTHER        LOW  UNKNOWN
# 4             BOOKING       HIGH     RULE
# 5               OTHER        LOW  UNKNOWN
# 6               OTHER        LOW  UNKNOWN
# 7            MATERIAL        NaN      NaN
# 8            MATERIAL        NaN      NaN
# 9        INTERMEDIARY       HIGH     RULE
# 10  AUTOMATED_DIGITAL       HIGH     RULE
# 11    PARTNER_NETWORK       HIGH     RULE
# 12              OTHER        LOW  UNKNOWN
# 13            BOOKING       HIGH     RULE
# 14              OTHER        LOW  UNKNOWN
# 15              OTHER        LOW  UNKNOWN
# 16           MATERIAL        NaN      NaN
# 17           MATERIAL        NaN      NaN
# 18              OTHER        LOW  UNKNOWN
# 19  AUTOMATED_DIGITAL       HIGH     RULE
# 20    PARTNER_NETWORK       HIGH     RULE
# 21              OTHER        LOW  UNKNOWN
# 22            BOOKING       HIGH     RULE
# 23              OTHER        LOW  UNKNOWN
# 24              OTHER        LOW  UNKNOWN
# 25               NONE        NaN      NaN
# 26           MATERIAL        NaN      NaN
# 27       INTERMEDIARY       HIGH     RULE
# 28  AUTOMATED_DIGITAL       HIGH     RULE
# 29    PARTNER_NETWORK       HIGH     RULE
# 30              OTHER        LOW  UNKNOWN
# 31            BOOKING       HIGH     RULE
# 32              OTHER        LOW  UNKNOWN
# 33              OTHER        LOW  UNKNOWN
# 34           MATERIAL        NaN      NaN
# 35           MATERIAL        NaN      NaN
# 36              OTHER        LOW  UNKNOWN
# 37  AUTOMATED_DIGITAL       HIGH     RULE
# 38    PARTNER_NETWORK       HIGH     RULE
# 39              OTHER        LOW  UNKNOWN
# 40            BOOKING       HIGH     RULE
# 41              OTHER        LOW  UNKNOWN
# 42              OTHER        LOW  UNKNOWN
# 43           MATERIAL        NaN      NaN
# 44           MATERIAL        NaN      NaN

# %% [markdown]
# ## 25. Candidate Recovery / Portfolio Relations

# %%
candidate_preparation = (await engine.prepare_candidate_portfolio(
    seed, plan_validation, max_concepts=MAX_CONCEPTS, initial_candidates=candidate_drafts)
    if RUN_STAGED_CORE and plan_validation else None)
candidates = candidate_preparation.candidates if candidate_preparation else []
candidate_reports = candidate_preparation.reports if candidate_preparation else []
display(show_candidate_recovery(candidate_preparation) if candidate_preparation else {'status': 'SKIPPED'})
candidate_pairwise = [engine.compare_candidates(candidates[i], candidates[j])
                      for i in range(len(candidates)) for j in range(i + 1, len(candidates))]
display(show_plan_diversity(candidate_pairwise))
# Out:
# {'summary':    candidateGenerated  candidateAcceptedInitially  candidateRegenerated  \
#  0                   5                           5                     0
#
#     candidateRecovered  reservePlansActivated  candidateRecoveryReplans  \
#  0                   0                      0                         0
#
#     finalCandidatePortfolio
#  0                        5  ,
#  'attempts':   candidateId  schemaValid  hardLockPreserved  semanticAnchorPreserved  \
#  0          C1         True               True                     True
#  1          C2         True               True                     True
#  2          C3         True               True                     True
#  3          C4         True               True                     True
#  4          C5         True               True                     True
#
#     planFidelity anchorDecision fidelityDecision  contentLanguageValid  \
#  0          True           PASS          ADAPTED                  True
#  1          True           PASS          ADAPTED                  True
#  2          True           PASS          ADAPTED                  True
#  3          True           PASS          ADAPTED                  True
#  4          True           PASS          ADAPTED                  True
#
#     accepted   outcome  semanticFidelityUsed  \
#  0      True  ACCEPTED                 False
#  1      True  ACCEPTED                 False
#  2      True  ACCEPTED                 False
#  3      True  ACCEPTED                 False
#  4      True  ACCEPTED                 False
#
#                             matchedIdentityComponents  \
#  0  [targetSegmentThesis, valuePropositionThesis, ...
#  1  [targetSegmentThesis, valuePropositionThesis, ...
#  2  [targetSegmentThesis, valuePropositionThesis, ...
#  3  [targetSegmentThesis, valuePropositionThesis, ...
#  4  [targetSegmentThesis, valuePropositionThesis, ...
#
#        missingIdentityComponents reasonCodes safeSummary
#  0  [useCaseThesis, offerThesis]          []       검사 통과
#  1  [useCaseThesis, offerThesis]          []       검사 통과
#  2  [useCaseThesis, offerThesis]          []       검사 통과
#  3  [useCaseThesis, offerThesis]          []       검사 통과
#  4  [useCaseThesis, offerThesis]          []       검사 통과  ,
#  'finalCandidates':   candidateId lineageId parentCandidateId                 이름  \
#  0          C1        L1              None  주말 여행 자동 계획 서비스 A
#  1          C2        L2              None    주말 여행 일정 자동 생성기
#  2          C3        L3              None  주말 여행 자동 계획 서비스 C
#  3          C4        L4              None       주말 여행 계획 도우미
#  4          C5        L5              None  주말 여행 자동 계획 서비스 B
#
#                                               핵심 작동방식           family  \
#  0    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
#  1  사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.  거래 중개 · 디지털 자동화
#  2    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
#  3           사용자가 입력한 정보를 바탕으로 여행 계획을 도와주는 시스템을 구축한다.  거래 중개 · 디지털 자동화
#  4    자동화된 시스템을 통해 사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 생성한다.  기타 역할 · 디지털 자동화
#
#                                            descriptor  \
#  0  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#  1  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#  2  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#  3  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#  4  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#
#                                 수익  \
#  0  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#  1  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#  2  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#  3  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#  4  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#
#                                                 운영
#  0            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
#  1            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
#  2            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
#  3  데이터 분석 및 알고리즘을 통해 사용자 맞춤형 여행 계획 도우미 서비스를 제공한다.
#  4            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.  }
#     A   B       판정                        Family A  \
# 0  C1  C2  VARIANT         OTHER:AUTOMATED_DIGITAL
# 1  C1  C3  VARIANT         OTHER:AUTOMATED_DIGITAL
# 2  C1  C4  VARIANT         OTHER:AUTOMATED_DIGITAL
# 3  C1  C5  VARIANT         OTHER:AUTOMATED_DIGITAL
# 4  C2  C3  VARIANT  INTERMEDIARY:AUTOMATED_DIGITAL
# 5  C2  C4  VARIANT  INTERMEDIARY:AUTOMATED_DIGITAL
# 6  C2  C5  VARIANT  INTERMEDIARY:AUTOMATED_DIGITAL
# 7  C3  C4  VARIANT         OTHER:AUTOMATED_DIGITAL
# 8  C3  C5  VARIANT         OTHER:AUTOMATED_DIGITAL
# 9  C4  C5  VARIANT  INTERMEDIARY:AUTOMATED_DIGITAL
#
#                          Family B  \
# 0  INTERMEDIARY:AUTOMATED_DIGITAL
# 1         OTHER:AUTOMATED_DIGITAL
# 2  INTERMEDIARY:AUTOMATED_DIGITAL
# 3         OTHER:AUTOMATED_DIGITAL
# 4         OTHER:AUTOMATED_DIGITAL
# 5  INTERMEDIARY:AUTOMATED_DIGITAL
# 6         OTHER:AUTOMATED_DIGITAL
# 7  INTERMEDIARY:AUTOMATED_DIGITAL
# 8         OTHER:AUTOMATED_DIGITAL
# 9         OTHER:AUTOMATED_DIGITAL
#
#                                                   겹침  \
# 0  operatingModel, partnerModel, deliveryModel, t...
# 1  businessRole, operatingModel, partnerModel, de...
# 2  operatingModel, partnerModel, deliveryModel, t...
# 3  businessRole, operatingModel, partnerModel, de...
# 4  operatingModel, partnerModel, deliveryModel, t...
# 5  businessRole, operatingModel, partnerModel, de...
# 6  operatingModel, partnerModel, deliveryModel, t...
# 7  operatingModel, partnerModel, deliveryModel, t...
# 8  businessRole, operatingModel, partnerModel, de...
# 9  operatingModel, partnerModel, deliveryModel, t...
#
#                                                실질 차이  \
# 0               businessRole, valuePropositionThesis
# 1             dataDependency, valuePropositionThesis
# 2  businessRole, valuePropositionThesis, solution...
# 3                             valuePropositionThesis
# 4  businessRole, dataDependency, valueProposition...
# 5             valuePropositionThesis, solutionThesis
# 6               businessRole, valuePropositionThesis
# 7  businessRole, dataDependency, valueProposition...
# 8             dataDependency, valuePropositionThesis
# 9  businessRole, valuePropositionThesis, solution...
#
#                           단계  semantic judge  \
# 0  MEANINGFUL_THESIS_VARIANT           False
# 1  MEANINGFUL_THESIS_VARIANT           False
# 2  MEANINGFUL_THESIS_VARIANT           False
# 3  MEANINGFUL_THESIS_VARIANT           False
# 4  MEANINGFUL_THESIS_VARIANT           False
# 5  MEANINGFUL_THESIS_VARIANT           False
# 6  MEANINGFUL_THESIS_VARIANT           False
# 7  MEANINGFUL_THESIS_VARIANT           False
# 8  MEANINGFUL_THESIS_VARIANT           False
# 9  MEANINGFUL_THESIS_VARIANT           False
#
#                                                관계 설명
# 0  Architecture family는 유사하지만 target/use case/val...
# 1  Architecture family는 유사하지만 target/use case/val...
# 2  Architecture family는 유사하지만 target/use case/val...
# 3  Architecture family는 유사하지만 target/use case/val...
# 4  Architecture family는 유사하지만 target/use case/val...
# 5  Architecture family는 유사하지만 target/use case/val...
# 6  Architecture family는 유사하지만 target/use case/val...
# 7  Architecture family는 유사하지만 target/use case/val...
# 8  Architecture family는 유사하지만 target/use case/val...
# 9  Architecture family는 유사하지만 target/use case/val...

# %% [markdown]
# ## 26. Legal Fact Completeness + Business Design Completion + C1 Fact Pattern

# %%
prechecks = [engine.legal_precheck(item) for item in candidates] if RUN_STAGED_LEGAL else []
display(show_legal_precheck(prechecks))
legal_preparation = (await engine.prepare_legal_candidates(seed, candidates)
                     if RUN_STAGED_LEGAL and candidates else None)
candidates_before_legal = candidates
candidates = legal_preparation.candidates if legal_preparation else candidates
display({'factCompleteness': [item.model_dump(mode='json') for item in legal_preparation.reports]
                              if legal_preparation else [],
         'roleSemanticBatchCalls': legal_preparation.roleSemanticBatchCalls if legal_preparation else 0,
         'dependencySemanticBatchCalls': legal_preparation.dependencySemanticBatchCalls if legal_preparation else 0,
         'completionAttempted': legal_preparation.completionAttempted if legal_preparation else 0,
         'completionValidated': legal_preparation.completionValidated if legal_preparation else 0,
         'completionAccepted': legal_preparation.completionAccepted if legal_preparation else 0,
         'completionExhausted': legal_preparation.completionExhausted if legal_preparation else 0,
         'completionCompliance': [item.model_dump(mode='json') for item in legal_preparation.completionCompliance] if legal_preparation else [],
         'factConsistency': [item.model_dump(mode='json') for item in legal_preparation.consistencyReports] if legal_preparation else [],
         'consistencyRepairAttempted': legal_preparation.consistencyRepairAttempted if legal_preparation else 0,
         'consistencyRepairAccepted': legal_preparation.consistencyRepairAccepted if legal_preparation else 0,
         'consistencyRepairExhausted': legal_preparation.consistencyRepairExhausted if legal_preparation else 0,
         'preLegalExclusions': legal_preparation.excludedCandidates if legal_preparation else []})
display(show_legal_fact_pattern(candidates[0].candidate, seed) if candidates else [])
# Out:
#   candidateId                                              label  \
# 0          C1  Structural risk precheck — not final legal review
# 1          C2  Structural risk precheck — not final legal review
# 2          C3  Structural risk precheck — not final legal review
# 3          C4  Structural risk precheck — not final legal review
# 4          C5  Structural risk precheck — not final legal review
#
#    directSeller  intermediary  regulatedPhysicalActivity  \
# 0         False         False                       True
# 1          True          True                       True
# 2          True         False                       True
# 3          True          True                       True
# 4         False         False                       True
#
#    personalDataDependency  qualificationDependency      riskHints
# 0                    True                    False  [물리 활동, 개인정보]
# 1                    True                    False  [물리 활동, 개인정보]
# 2                   False                    False        [물리 활동]
# 3                    True                    False  [물리 활동, 개인정보]
# 4                    True                    False  [물리 활동, 개인정보]
# {'factCompleteness': [{'candidateId': 'C1',
#    'status': 'COMPLETABLE',
#    'missingDesignFacts': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'contradictions': [],
#    'completionRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'affectedFields': ['sellerRole'],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MISMATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MISMATCH',
#      'finalStatus': 'MISMATCH',
#      'safeReason': '다른 역할의 설명이 들어 있어 해당 역할을 다시 명시해야 합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [{'field': 'sellerRole',
#      'reasonType': 'ROLE_MISMATCH',
#      'dependencyType': None,
#      'instruction': 'sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'}],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'OTHER',
#     'confidence': 'LOW',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '동일 Concept 안에서 누락된 사업 사실을 한 번 보완할 수 있습니다.'},
#   {'candidateId': 'C2',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'CONSISTENT',
#     'businessRole': 'INTERMEDIARY',
#     'confidence': 'HIGH',
#     'safeReason': '고신뢰 architecture와 Candidate의 중개 역할이 일치합니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C3',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'NOT_REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'NOT_REQUIRED',
#      'safeReason': '데이터 비의존 구조이며 개인 단위 처리 신호가 없습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'OTHER',
#     'confidence': 'LOW',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C4',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'CONSISTENT',
#     'businessRole': 'INTERMEDIARY',
#     'confidence': 'HIGH',
#     'safeReason': '고신뢰 architecture와 Candidate의 중개 역할이 일치합니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C5',
#    'status': 'COMPLETABLE',
#    'missingDesignFacts': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'contradictions': [],
#    'completionRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'affectedFields': ['sellerRole'],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MISMATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MISMATCH',
#      'finalStatus': 'MISMATCH',
#      'safeReason': '다른 역할의 설명이 들어 있어 해당 역할을 다시 명시해야 합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [{'field': 'sellerRole',
#      'reasonType': 'ROLE_MISMATCH',
#      'dependencyType': None,
#      'instruction': 'sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'}],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'OTHER',
#     'confidence': 'LOW',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '동일 Concept 안에서 누락된 사업 사실을 한 번 보완할 수 있습니다.'},
#   {'candidateId': 'C1-F1',
#    'status': 'COMPLETABLE',
#    'missingDesignFacts': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'contradictions': [],
#    'completionRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'affectedFields': ['sellerRole'],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MISMATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MISMATCH',
#      'finalStatus': 'MISMATCH',
#      'safeReason': '다른 역할의 설명이 들어 있어 해당 역할을 다시 명시해야 합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [{'field': 'sellerRole',
#      'reasonType': 'ROLE_MISMATCH',
#      'dependencyType': None,
#      'instruction': 'sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'}],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'PLATFORM_INFRASTRUCTURE',
#     'confidence': 'HIGH',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '동일 Concept 안에서 누락된 사업 사실을 한 번 보완할 수 있습니다.'},
#   {'candidateId': 'C5-F1',
#    'status': 'COMPLETABLE',
#    'missingDesignFacts': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'contradictions': [],
#    'completionRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'affectedFields': ['sellerRole'],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MISMATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MISMATCH',
#      'finalStatus': 'MISMATCH',
#      'safeReason': '다른 역할의 설명이 들어 있어 해당 역할을 다시 명시해야 합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [{'field': 'sellerRole',
#      'reasonType': 'ROLE_MISMATCH',
#      'dependencyType': None,
#      'instruction': 'sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'}],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'PLATFORM_INFRASTRUCTURE',
#     'confidence': 'HIGH',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '동일 Concept 안에서 누락된 사업 사실을 한 번 보완할 수 있습니다.'}],
#  'roleSemanticBatchCalls': 2,
#  'dependencySemanticBatchCalls': 0,
#  'completionAttempted': 2,
#  'completionValidated': 2,
#  'completionAccepted': 0,
#  'completionExhausted': 2,
#  'completionCompliance': [{'candidateId': 'C1-F1',
#    'status': 'FAIL',
#    'satisfiedRequirements': [],
#    'unsatisfiedRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'changedFields': [],
#    'unchangedRequiredFields': ['sellerRole'],
#    'safeSummary': 'Completion Provider가 요청된 사업 사실을 실제로 보완하지 않았습니다.'},
#   {'candidateId': 'C5-F1',
#    'status': 'FAIL',
#    'satisfiedRequirements': [],
#    'unsatisfiedRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#    'changedFields': [],
#    'unchangedRequiredFields': ['sellerRole'],
#    'safeSummary': 'Completion Provider가 요청된 사업 사실을 실제로 보완하지 않았습니다.'}],
#  'factConsistency': [{'candidateId': 'C1',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C2',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C3',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C4',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C5',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'}],
#  'consistencyRepairAttempted': 0,
#  'consistencyRepairAccepted': 0,
#  'consistencyRepairExhausted': 0,
#  'preLegalExclusions': [{'candidateId': 'C1-F1',
#    'scope': 'PRE_LEGAL_EXCLUSION',
#    'reasonCode': 'LEGAL_FACT_COMPLETION_PROVIDER_NONCOMPLIANT',
#    'affectedFields': ['sellerRole'],
#    'dependencyDecisions': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'completionRequirements': [{'field': 'sellerRole',
#      'reasonType': 'ROLE_MISMATCH',
#      'dependencyType': None,
#      'instruction': 'sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'}],
#    'patchChangedFields': ['sellerRole'],
#    'completionCompliance': {'candidateId': 'C1-F1',
#     'status': 'FAIL',
#     'satisfiedRequirements': [],
#     'unsatisfiedRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#     'changedFields': [],
#     'unchangedRequiredFields': ['sellerRole'],
#     'safeSummary': 'Completion Provider가 요청된 사업 사실을 실제로 보완하지 않았습니다.'},
#    'recheckStatus': 'COMPLETABLE',
#    'recoveryAttempted': True,
#    'recoveryResolution': 'PROVIDER_NONCOMPLIANT',
#    'safeSummary': '동일 Concept 안에서 누락된 사업 사실을 한 번 보완할 수 있습니다.'},
#   {'candidateId': 'C5-F1',
#    'scope': 'PRE_LEGAL_EXCLUSION',
#    'reasonCode': 'LEGAL_FACT_COMPLETION_PROVIDER_NONCOMPLIANT',
#    'affectedFields': ['sellerRole'],
#    'dependencyDecisions': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '개인 단위 정보의 처리 항목 또는 목적이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'completionRequirements': [{'field': 'sellerRole',
#      'reasonType': 'ROLE_MISMATCH',
#      'dependencyType': None,
#      'instruction': 'sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'}],
#    'patchChangedFields': ['sellerRole'],
#    'completionCompliance': {'candidateId': 'C5-F1',
#     'status': 'FAIL',
#     'satisfiedRequirements': [],
#     'unsatisfiedRequirements': ['sellerRole의 역할 존재·부재와 해당 책임을 의미에 맞게 명시해야 합니다.'],
#     'changedFields': [],
#     'unchangedRequiredFields': ['sellerRole'],
#     'safeSummary': 'Completion Provider가 요청된 사업 사실을 실제로 보완하지 않았습니다.'},
#    'recheckStatus': 'COMPLETABLE',
#    'recoveryAttempted': True,
#    'recoveryResolution': 'PROVIDER_NONCOMPLIANT',
#    'safeSummary': '동일 Concept 안에서 누락된 사업 사실을 한 번 보완할 수 있습니다.'}]}
#                         field  \
# 0                platformRole
# 1                providerRole
# 2                  sellerRole
# 3            intermediaryRole
# 4             transactionFlow
# 5                 paymentFlow
# 6           personalDataUsage
# 7          physicalActivities
# 8         partnerRequirements
# 9   qualificationRequirements
# 10          advertisingClaims
#
#                                             legalFact             source  \
# 0                                여행 일정 생성 및 예약 플랫폼 제공  CONCEPT_GENERATED
# 1                                     여행 일정 생성 서비스 제공  CONCEPT_GENERATED
# 2                                       숙박 및 체험 상품 판매  CONCEPT_GENERATED
# 3                                           예약 서비스 중개  CONCEPT_GENERATED
# 4   [사용자가 이동 가능 시간과 관심사를 입력한다., 시스템이 자동으로 여행 일정을 생...  CONCEPT_GENERATED
# 5     [사용자가 예약 시 수수료를 지불한다., 파트너에게는 일정 비율의 수익을 분배한다.]  CONCEPT_GENERATED
# 6           [사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공한다.]  CONCEPT_GENERATED
# 7                                     [배송, 현장 방문, 설치]  CONCEPT_GENERATED
# 8                        [숙박업체와의 계약 체결, 체험 제공업체와의 협력]  CONCEPT_GENERATED
# 9                                                  []  CONCEPT_GENERATED
# 10          [사용자의 이동 가능 시간과 관심사를 반영한 자동 여행 일정 생성 서비스]  CONCEPT_GENERATED
#
#      authority  decision
# 0   REVIEWABLE  PROPOSED
# 1   REVIEWABLE  PROPOSED
# 2   REVIEWABLE  PROPOSED
# 3   REVIEWABLE  PROPOSED
# 4   REVIEWABLE  PROPOSED
# 5   REVIEWABLE  PROPOSED
# 6   REVIEWABLE  PROPOSED
# 7   REVIEWABLE  PROPOSED
# 8   REVIEWABLE  PROPOSED
# 9   REVIEWABLE  PROPOSED
# 10  REVIEWABLE  PROPOSED

# %% [markdown]
# ## 27. Prepared Legal C1 Evidence Summary

# %%
legal_adapter = CurrentLegalAdapter() if RUN_STAGED_LEGAL else None
legal_c1_input = (legal_adapter.task_input(candidates[0].candidate, seed)
                  if legal_adapter and candidates else None)
display({'candidateId': candidates[0].candidateId if candidates else None,
         'externalFacts': legal_c1_input['externalFactContext']['facts'] if legal_c1_input else [],
         'note': '공식 근거 수와 allowed index는 Full Legal 응답/실패 diagnostics에서 확인'})
# Out:
# {'candidateId': 'C2',
#  'externalFacts': [],
#  'note': '공식 근거 수와 allowed index는 Full Legal 응답/실패 diagnostics에서 확인'}

# %% [markdown]
# ## 28. Full Evidence Judgment — C1 Staged Smoke

# %%
RUN_FULL_LEGAL_C1 = RUN_STAGED_LEGAL
legal_one = None
if RUN_FULL_LEGAL_C1 and candidates:
    try:
        legal_one = await engine.review_legal_candidate(seed, candidates[0])
        display(show_legal_result([legal_one]))
    except Exception:
        display(show_legal_failure(candidates[0].candidateId, engine.gateway))
else:
    print('SKIPPED — RUN_FULL_LEGAL_C1=True로 명시해야 실행됩니다.')
# Out:
#   candidateId   route             productionStatus     sourceStatus  \
# 0          C2  ACCEPT  IMPLEMENTABLE_WITH_CONTROLS  SOURCE_COMPLETE
#
#   evidenceCoverage   reviewPhase factCompletenessStatus legalSourceStatus  \
# 0             None  LEGAL_SOURCE                   None   SOURCE_COMPLETE
#
#    finalEvidenceJudgmentExecuted recoveryResolution  ...  \
# 0                           True               None  ...
#
#    legalClarificationCount                                        safeSummary  \
# 0                        0  이 서비스는 사용자의 이동 가능 시간과 관심사를 반영하여 맞춤형 여행 일정을 생성하...
#
#    unknownFacts                                   requiredControls  \
# 0            []  [개인정보 수집 및 이용에 대한 동의를 명확히 받는다., 사용자의 이동 가능 시간과...
#
#             requiredPartnersAndQualifications  \
# 0  [숙박업체와의 계약 체결이 필요하다., 체험 제공업체와의 협력이 필요하다.]
#
#                                  requiredDisclosures  \
# 0  [개인정보 처리방침을 사용자에게 고지해야 한다., 예약 서비스 이용 시 수수료에 대...
#
#                                   prohibitedVariants evidenceCount  \
# 0  [사용자의 동의 없이 개인정보를 수집하거나 이용할 수 없다., 부당한 표시ㆍ광고 행...            24
#
#                                         evidenceRefs  \
# 0  [{'referenceIndex': 0, 'sourceType': 'OFFICIAL...
#
#                                  evidenceDiagnostics
# 0  {'coverageStatus': 'SOURCE_COMPLETE', 'coverag...
#
# [1 rows x 25 columns]

# %% [markdown]
# ## 29. C1 Route + Staged Redesign/Compliance/Second Legal

# %%
c1_portfolio, c1_legal_all, c1_required_inputs, c1_redesigned, c1_replanned = ([], [], [], 0, 0)
if legal_one and candidates:
    c1_portfolio, c1_legal_all, c1_required_inputs, c1_redesigned, c1_replanned = await engine.resolve_legal(
        seed, candidate_preparation.usedPlans, candidates[:1], [legal_one])
display({'initialRoute': legal_one.route.value if legal_one else 'SKIPPED',
         'redesignRequirements': legal_one.redesignRequirements if legal_one else [],
         'recoveryReviews': [item.model_dump(mode='json') for item in c1_legal_all[1:]],
         'requiredInputs': c1_required_inputs, 'terminalCandidates': len(c1_portfolio),
         'redesigned': c1_redesigned, 'replanned': c1_replanned})
# Out:
# {'initialRoute': 'ACCEPT',
#  'redesignRequirements': [],
#  'recoveryReviews': [],
#  'requiredInputs': [],
#  'terminalCandidates': 1,
#  'redesigned': 0,
#  'replanned': 0}

# %% [markdown]
# ## 30. Remaining 4 Legal + Exhaustive Recovery Summary

# %%
RUN_REMAINING_LEGAL = RUN_STAGED_FULL
legal_remaining = []
portfolio, legal_all, required_inputs = (list(c1_portfolio), list(c1_legal_all), list(c1_required_inputs))
redesigned_count, replanned_count = c1_redesigned, c1_replanned
c1_terminal = bool(c1_portfolio or c1_required_inputs or (c1_legal_all and c1_legal_all[-1].route.value == 'SYSTEM_FAILURE'))
if RUN_REMAINING_LEGAL and c1_terminal and len(candidates) > 1:
    legal_remaining = await engine.review_legal(seed, candidates[1:])
    rest_portfolio, rest_legal, rest_inputs, rest_redesigned, rest_replanned = await engine.resolve_legal(
        seed, candidate_preparation.usedPlans, candidates[1:], legal_remaining)
    portfolio += rest_portfolio; legal_all += rest_legal; required_inputs += rest_inputs
    redesigned_count += rest_redesigned; replanned_count += rest_replanned
else:
    print('SKIPPED — C1이 정상 terminal에 도달한 후 remaining Legal을 실행합니다.')
legal_initial = ([legal_one] if legal_one else []) + legal_remaining
display({'recoveryTrace': [item.model_dump(mode='json') for item in legal_all
                           if item.candidateId not in {x.candidateId for x in legal_initial}],
         'requiredInputs': required_inputs, 'metrics': engine._legal_metrics})
print({'Plan Selected': len(selected_plans),
       'Candidate Generated': candidate_preparation.candidateGenerated if candidate_preparation else 0,
       'Candidate Valid Initially': candidate_preparation.candidateAcceptedInitially if candidate_preparation else 0,
       'Candidate Regenerated': candidate_preparation.candidateRegenerated if candidate_preparation else 0,
       'Candidate Recovered': candidate_preparation.candidateRecovered if candidate_preparation else 0,
       'Fact Completion Attempted': legal_preparation.completionAttempted if legal_preparation else 0,
       'Fact Completion Validated': legal_preparation.completionValidated if legal_preparation else 0,
       'Fact Completion Accepted': legal_preparation.completionAccepted if legal_preparation else 0,
       'Dependency Semantic Calls': legal_preparation.dependencySemanticBatchCalls if legal_preparation else 0,
       'Completion Compliance PASS': sum(item.status == 'PASS' for item in legal_preparation.completionCompliance) if legal_preparation else 0,
       'Fact Consistency Invalid': sum(item.status == 'INVALID_FACT' for item in legal_preparation.consistencyReports) if legal_preparation else 0,
       'Consistency Repair Accepted': legal_preparation.consistencyRepairAccepted if legal_preparation else 0,
       'Legal Ready': len(candidates) if legal_preparation else 0,
       'Legal Reviewed': len(legal_initial),
       'Legal Accepted': sum(item.route.value == 'ACCEPT' for item in legal_all),
       'Legal Redesigned': redesigned_count, 'Legal Replanned': replanned_count,
       'Final Portfolio': len(portfolio)})
# Out:
# {'recoveryTrace': [{'candidateId': 'C3-R1-CR1',
#    'route': 'SYSTEM_FAILURE',
#    'productionStatus': None,
#    'sourceStatus': 'REDESIGN_COMPLIANCE',
#    'safeSummary': 'Legal redesign 요구를 targeted repair 1회 후에도 충족하지 못했습니다.',
#    'requiredControls': [],
#    'requiredPartnersAndQualifications': [],
#    'redesignRequirements': [],
#    'prohibitedVariants': [],
#    'requiredDisclosures': [],
#    'officialEvidenceReferences': [],
#    'deltaLegalReviews': [],
#    'conflictingLock': None,
#    'currentValue': None,
#    'requiredLegalChange': None,
#    'reason': None,
#    'possibleUserAction': None,
#    'unknownFacts': [],
#    'inputScope': 'CANDIDATE',
#    'evidenceDiagnostics': {},
#    'reviewPhase': None,
#    'factCompletenessStatus': None,
#    'legalSourceStatus': None,
#    'finalEvidenceJudgmentExecuted': None,
#    'recoveryResolution': 'LEGAL_REDESIGN_COMPLIANCE_EXHAUSTED',
#    'sourceQuestionCount': 0,
#    'resolvedByFactPatternCount': 0,
#    'designGapCount': 0,
#    'externalFactCount': 0,
#    'controlConvertibleCount': 0,
#    'legalClarificationCount': 0}],
#  'requiredInputs': [],
#  'metrics': {'factAttempted': 2,
#   'factValidated': 2,
#   'factAccepted': 0,
#   'factExhausted': 2,
#   'dependencySemanticCalls': 0,
#   'completionCompliancePassed': 0,
#   'providerNoncompliant': 2,
#   'recheckFailed': 0,
#   'consistencyInvalid': 0,
#   'consistencyRepairAttempted': 0,
#   'consistencyRepairAccepted': 0,
#   'consistencyRepairExhausted': 0,
#   'redesignAttempted': 1,
#   'redesignValidated': 1,
#   'redesignAccepted': 0,
#   'redesignExhausted': 1,
#   'replanAttempted': 0,
#   'replanValidated': 0,
#   'replanAccepted': 0,
#   'replanExhausted': 0}}
# {'Plan Selected': 5, 'Candidate Generated': 5, 'Candidate Valid Initially': 5, 'Candidate Regenerated': 0, 'Candidate Recovered': 0, 'Fact Completion Attempted': 2, 'Fact Completion Validated': 2, 'Fact Completion Accepted': 0, 'Dependency Semantic Calls': 0, 'Completion Compliance PASS': 0, 'Fact Consistency Invalid': 0, 'Consistency Repair Accepted': 0, 'Legal Ready': 3, 'Legal Reviewed': 3, 'Legal Accepted': 2, 'Legal Redesigned': 0, 'Legal Replanned': 0, 'Final Portfolio': 2}

# %% [markdown]
# ## 31. Replan

# %%
display(show_replan(type('PortfolioView', (), {'concepts': portfolio})()))
print({'replanned': replanned_count, 'reserveAvailable': len(reserve_plans)})
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# {'replanned': 0, 'reserveAvailable': 1}

# %% [markdown]
# ## 32. Final Portfolio

# %%
legal_terminal_status = ('READY_FULL' if len(portfolio) == MAX_CONCEPTS else
    'READY_LIMITED' if portfolio else
    'LEGAL_RECOVERY_COMPLETE_NO_ACCEPTED_CANDIDATE' if legal_initial and len(legal_initial) == len(candidates)
    else 'LEGAL_PENDING')
display(show_final_portfolio(type('PortfolioView', (), {'concepts': portfolio})()) if portfolio else {'status': legal_terminal_status})
# Out:
#   candidateId lineageId parentCandidateId               이름  \
# 0          C2        L2              None  주말 여행 일정 자동 생성기
# 1          C4        L4              None     주말 여행 계획 도우미
#
#                                              핵심 작동방식           family  \
# 0  사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.  거래 중개 · 디지털 자동화
# 1           사용자가 입력한 정보를 바탕으로 여행 계획을 도와주는 시스템을 구축한다.  거래 중개 · 디지털 자동화
#
#                                           descriptor  \
# 0  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
# 1  {'thesis': {'targetSegmentThesis': '주말 1~2일 단기...
#
#                                수익  \
# 0  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 1  프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
#
#                                                운영
# 0            데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.
# 1  데이터 분석 및 알고리즘을 통해 사용자 맞춤형 여행 계획 도우미 서비스를 제공한다.

# %% [markdown]
# ## 33. Unresolved Candidate Summary

# %%
display(show_required_inputs(required_inputs) if required_inputs else {'unresolved': []})
# Out:
# {'unresolved': []}

# %% [markdown]
# ## 34. Manual Concept Selection

# %%
SELECTED_CANDIDATE_ID = portfolio[0].candidateId if portfolio else None  # 사용자가 수정
selected_concept = next((item for item in portfolio if item.candidateId == SELECTED_CANDIDATE_ID), None)
print({'selectedCandidateId': SELECTED_CANDIDATE_ID})
# Out:
# {'selectedCandidateId': 'C2'}

# %% [markdown]
# ## 35. 7 Hypotheses

# %%
hypotheses = (engine.build_or_load_current_hypothesis_contract(selected_concept)
              if RUN_STAGED_FULL and selected_concept else [])
hypotheses = await engine.resolve_hypothesis_semantics(hypotheses) if hypotheses else []
display(show_hypotheses(hypotheses))
display(show_hypothesis_readiness(hypotheses))
# Out:
#          HypothesisType                                      ProposedValue  \
# 0         TARGET_REGION                                            대한민국 전역
# 1         REVENUE_MODEL                     프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 2                 PRICE                                 서비스 이용 시 예약 수수료 발생
# 3              CHANNELS                                       웹사이트 및 모바일 앱
# 4       DIFFERENTIATORS  사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험...
# 5  PRE_MARKET_SOM_SHARE  targetSharePercent=15.0 horizonYears=3 rationa...
# 6        PRE_MARKET_SOM  amount=500000.0 currency='KRW' period='연간' cal...
#
#   FinalValue SemanticStatus  \
# 0       None          VALID
# 1       None          VALID
# 2       None          VALID
# 3       None          VALID
# 4       None          VALID
# 5       None          VALID
# 6       None          VALID
#
#                                       SemanticReason  Locked DecisionStatus  \
# 0                                      실제 사업 가설값입니다.   False       PROPOSED
# 1                                      실제 사업 가설값입니다.   False       PROPOSED
# 2  The statement correctly relates to a pricing h...   False       PROPOSED
# 3                                      실제 사업 가설값입니다.   False       PROPOSED
# 4                                      실제 사업 가설값입니다.   False       PROPOSED
# 5                              수치·기간·산식 가설이 명시되었습니다.   False       PROPOSED
# 6                              수치·기간·산식 가설이 명시되었습니다.   False       PROPOSED
#
#   LegalImpact
# 0        NONE
# 1        NONE
# 2        NONE
# 3        NONE
# 4        NONE
# 5        NONE
# 6        NONE
# {'All Values Semantically Valid': True,
#  'All Decisions Confirmed': False,
#  'Ready For Handoff': False,
#  'status': 'NOT_READY',
#  'reason': 'UNRESOLVED_HYPOTHESES',
#  'unresolvedHypotheses': ['TARGET_REGION',
#   'REVENUE_MODEL',
#   'PRICE',
#   'CHANNELS',
#   'DIFFERENTIATORS',
#   'PRE_MARKET_SOM_SHARE',
#   'PRE_MARKET_SOM']}

# %% [markdown]
# ## 36. Confirm / Edit

# %%
CONFIRM_ALL_PROPOSED = True
HYPOTHESIS_EDITS = {
    # 'PRICE': '월 17,900원',
}
confirmed_hypotheses = engine.confirm_hypotheses(
    hypotheses, HYPOTHESIS_EDITS, confirm_all_proposed=CONFIRM_ALL_PROPOSED) if hypotheses else []
display(show_hypotheses(confirmed_hypotheses))
hypothesis_readiness = show_hypothesis_readiness(confirmed_hypotheses)
display(hypothesis_readiness)
# Out:
#          HypothesisType                                      ProposedValue  \
# 0         TARGET_REGION                                            대한민국 전역
# 1         REVENUE_MODEL                     프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.
# 2                 PRICE                                 서비스 이용 시 예약 수수료 발생
# 3              CHANNELS                                       웹사이트 및 모바일 앱
# 4       DIFFERENTIATORS  사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험...
# 5  PRE_MARKET_SOM_SHARE  targetSharePercent=15.0 horizonYears=3 rationa...
# 6        PRE_MARKET_SOM  amount=500000.0 currency='KRW' period='연간' cal...
#
#                                           FinalValue SemanticStatus  \
# 0                                            대한민국 전역          VALID
# 1                     프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.          VALID
# 2                                 서비스 이용 시 예약 수수료 발생          VALID
# 3                                       웹사이트 및 모바일 앱          VALID
# 4  사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험...          VALID
# 5  targetSharePercent=15.0 horizonYears=3 rationa...          VALID
# 6  amount=500000.0 currency='KRW' period='연간' cal...          VALID
#
#                                       SemanticReason  Locked DecisionStatus  \
# 0                                      실제 사업 가설값입니다.   False       ACCEPTED
# 1                                      실제 사업 가설값입니다.   False       ACCEPTED
# 2  The statement correctly relates to a pricing h...   False       ACCEPTED
# 3                                      실제 사업 가설값입니다.   False       ACCEPTED
# 4                                      실제 사업 가설값입니다.   False       ACCEPTED
# 5                              수치·기간·산식 가설이 명시되었습니다.   False       ACCEPTED
# 6                              수치·기간·산식 가설이 명시되었습니다.   False       ACCEPTED
#
#   LegalImpact
# 0        NONE
# 1        NONE
# 2        NONE
# 3        NONE
# 4        NONE
# 5        NONE
# 6        NONE
# {'All Values Semantically Valid': True,
#  'All Decisions Confirmed': True,
#  'Ready For Handoff': True,
#  'status': 'READY',
#  'reason': None,
#  'unresolvedHypotheses': []}

# %% [markdown]
# ## 37. Actual Delta Legal

# %%
RUN_DELTA_LEGAL = True
delta_legal_result = None
if RUN_STAGED_FULL and RUN_DELTA_LEGAL and selected_concept and any(h.deltaLegalRequired for h in confirmed_hypotheses):
    delta_legal_result = await engine.review_delta_legal(seed, selected_concept, confirmed_hypotheses)
    confirmed_hypotheses = engine.mark_delta_legal_reviewed(confirmed_hypotheses, delta_legal_result)
display(delta_legal_result.model_dump(mode='json') if delta_legal_result else {'status': 'NOT_REQUIRED_OR_SKIPPED'})
# Out:
# {'status': 'NOT_REQUIRED_OR_SKIPPED'}

# %% [markdown]
# ## 38. Market Seed

# %%
handoff = None
if selected_concept and legal_all and hypothesis_readiness['Ready For Handoff']:
    handoff = engine.build_downstream_handoff(seed, selected_concept, confirmed_hypotheses, legal_all)
display(handoff.marketAnalysisSeedSnapshot if handoff else {
    'status': 'NOT_READY', 'reason': hypothesis_readiness.get('reason'),
    'unresolvedHypotheses': hypothesis_readiness.get('unresolvedHypotheses', [])})
# Out:
# {'contract': 'market-analysis-seed-snapshot-v1',
#  'schemaVersion': '2.0',
#  'snapshotId': 'lab-market-seed',
#  'projectId': 0,
#  'selectionId': 0,
#  'conceptId': 'C2',
#  'createdAt': '2026-08-10T07:57:24.495724+00:00',
#  'sourceSnapshotHash': 'sha256:c715212e7e7a08af59439b73e313ea0d31fc991233c69b8d35b9944650ce22b8',
#  'originalSeed': {'ideaOverview': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#   'fields': {'ideaOverview': {'value': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#     'source': 'USER_INPUT',
#     'decisionState': 'LOCKED'},
#    'problem': {'value': '짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.',
#     'source': 'USER_INPUT',
#     'decisionState': 'LOCKED'},
#    'targetUsers': {'value': '주말 1~2일 단기 여행을 자주 계획하는 직장인',
#     'source': 'USER_INPUT',
#     'decisionState': 'LOCKED'}}},
#  'aiInterpretation': {'interpretedProblem': '짧은 주말 여행을 계획하는 데 소요되는 시간과 노력을 줄이는 것.',
#   'interpretedTargetUsers': '주말에 짧은 여행을 자주 계획하는 직장인들.',
#   'usageContext': '사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 페이지로 연결하는 서비스.',
#   'industryCategory': '여행 및 관광',
#   'researchScope': '주말 여행 계획 서비스',
#   'conciseIdeaDefinition': '사용자의 이동 가능 시간과 관심사를 기반으로 주말 여행 일정을 자동으로 구성하는 서비스.',
#   'targetRegionInterpretation': '대상 지역은 명시되지 않음.',
#   'relevantKnownCompetitorContext': '경쟁자는 명시되지 않음.'},
#  'selectedConcept': {'identity': {'conceptName': '주말 여행 일정 자동 생성기',
#    'conceptDefinition': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#    'introduction': '사용자는 웹사이트나 모바일 앱을 통해 자신의 이동 가능 시간과 관심사를 입력하여 최적의 여행 일정을 자동으로 생성할 수 있습니다.',
#    'coreValue': '사용자는 간편하게 주말 여행 일정을 계획할 수 있다.',
#    'targetUsers': '주말 1~2일 단기 여행을 자주 계획하는 직장인',
#    'industryCategory': '여행 및 관광',
#    'researchScope': '주말 여행 계획 서비스'},
#   'solution': {'problemScenario': '짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.',
#    'solutionMechanism': '사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.',
#    'featureSet': ['사용자 맞춤형 일정 생성', '숙박 및 체험 예약 통합', '이동 경로 최적화']},
#   'operation': {'actorRoles': ['사용자', '숙박업체', '체험 제공업체'],
#    'platformRole': '여행 일정 생성 및 예약 플랫폼 제공',
#    'operatingModel': '데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.',
#    'partnerModel': '숙박업체 및 체험 제공업체와 협력하여 예약 서비스를 통합한다.',
#    'providerRole': '여행 일정 생성 서비스 제공',
#    'sellerRole': '숙박 및 체험 상품 판매',
#    'intermediaryRole': '예약 서비스 중개',
#    'transactionFlow': ['사용자가 이동 가능 시간과 관심사를 입력한다.',
#     '시스템이 자동으로 여행 일정을 생성한다.',
#     '사용자가 생성된 일정을 확인하고 예약을 진행한다.',
#     '예약 시 수수료를 지불한다.'],
#    'paymentFlow': ['사용자가 예약 시 수수료를 지불한다.', '파트너에게는 일정 비율의 수익을 분배한다.'],
#    'personalDataUsage': ['사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공한다.'],
#    'physicalActivities': ['배송', '현장 방문', '설치'],
#    'partnerRequirements': ['숙박업체와의 계약 체결', '체험 제공업체와의 협력'],
#    'qualificationRequirements': []},
#   'valueSemantics': [{'fieldKey': 'conceptName',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'conceptDefinition',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'introduction',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'coreValue',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'targetUsers',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'industryCategory',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'researchScope',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'targetRegion',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'revenueModel',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'price',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'channels',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'differentiators',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'preMarketSomShareHypothesis',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'preMarketSomHypothesis',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'actorRoles',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'platformRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'problemScenario',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'solutionMechanism',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'featureSet',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'operatingModel',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'partnerModel',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'providerRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'sellerRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'intermediaryRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'transactionFlow',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'paymentFlow',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'personalDataUsage',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'physicalActivities',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'partnerRequirements',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'qualificationRequirements',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'advertisingClaims',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'}],
#   'canonicalHash': 'sha256:e723e1806e71199f9605694bfb991bcf7ba4b9374ef7d0165a456ab3ff0507a1'},
#  'finalHypotheses': {'targetRegion': {'value': '대한민국 전역',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'revenueModel': {'value': '프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'price': {'value': '서비스 이용 시 예약 수수료 발생',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'channels': {'value': '웹사이트 및 모바일 앱',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'differentiators': {'value': '사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험 옵션 제공',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'preMarketSomShare': {'value': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='주말 여행 시장의 성장과 사용자 편의성 증가로 인해 시장 점유율 확대 가능성.', assumptions=['주말 여행을 계획하는 직장인 수 증가', '자동화된 여행 일정 생성 서비스에 대한 수요 증가']),
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'preMarketSom': {'value': PreMarketSomHypothesis(amount=500000.0, currency='KRW', period='연간', calculationBasis='주말 여행 관련 서비스 시장 규모의 10%를 목표로 설정', assumptions=['주말 여행 시장의 연평균 성장률 5%', '사용자 편의성에 대한 수요 증가'], confidence='MEDIUM'),
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'}},
#  'legalResult': {'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#   'safeSummary': '이 서비스는 사용자의 이동 가능 시간과 관심사를 반영하여 맞춤형 여행 일정을 생성하고, 관련된 숙박 및 체험 상품을 예약할 수 있는 플랫폼입니다. 개인정보 보호법 및 전자상거래 관련 법령을 준수하여 운영됩니다.',
#   'requiredControls': ['개인정보 수집 및 이용에 대한 동의를 명확히 받는다.',
#    '사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공하기 위한 최소한의 정보만 수집한다.',
#    '예약 서비스 중개 시, 파트너와의 계약 체결을 통해 법적 요건을 충족한다.',
#    '서비스 이용 시 예약 수수료 발생에 대한 고지 및 동의를 받는다.',
#    '광고 및 마케팅 활동 시, 부당한 표시ㆍ광고 행위의 금지 규정을 준수한다.'],
#   'requiredPartnersAndQualifications': ['숙박업체와의 계약 체결이 필요하다.',
#    '체험 제공업체와의 협력이 필요하다.'],
#   'prohibitedVariants': ['사용자의 동의 없이 개인정보를 수집하거나 이용할 수 없다.',
#    '부당한 표시ㆍ광고 행위를 할 수 없다.'],
#   'requiredDisclosures': ['개인정보 처리방침을 사용자에게 고지해야 한다.',
#    '예약 서비스 이용 시 수수료에 대한 정보를 명확히 고지해야 한다.'],
#   'officialEvidenceReferences': [{'referenceIndex': 0,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제15조',
#     'title': '개인정보의 수집ㆍ이용',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:d057e48fdd8c23f93bcfcb814c84c02a71c51f476b2b2f824635725d488e4d9c',
#     'boundedProvisionSummary': '개인정보 수집 및 이용에 대한 규정을 명시하고 있어, 사용자 맞춤형 서비스 제공 시 개인정보 처리의 법적 근거를 제공한다.',
#     'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 1,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제16조',
#     'title': '개인정보의 수집 제한',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:92011a2e3a02220ab77a308a194cdf773752b2c24e3059a67a0e03a80399f032',
#     'boundedProvisionSummary': '개인정보 수집 시 최소한의 정보만 수집해야 한다는 규정을 포함하고 있다.',
#     'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 2,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제20조',
#     'title': '정보주체 이외로부터 수집한 개인정보의 수집 출처 등 통지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:55c5d509f53ddd4fe40875720902fff238b927862a415b5d68f91faf6a283e3a',
#     'boundedProvisionSummary': '정보주체 이외로부터 수집한 개인정보의 출처 및 처리 목적을 통지해야 한다는 규정이다.',
#     'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 3,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제22조',
#     'title': '동의를 받는 방법',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:0a2c63314441f4a7596423f6d8e42a957e7186af1edd0e3e608019dcb8e5f2d7',
#     'boundedProvisionSummary': '개인정보 처리에 대한 동의를 받을 때의 방법을 규정하고 있다.',
#     'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 4,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제12조',
#     'title': '통신판매업자의 신고 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#     'boundedProvisionSummary': '통신판매업자는 신고를 통해 사업자 정보를 제공해야 한다는 규정이다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 5,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제13조',
#     'title': '신원 및 거래조건에 대한 정보의 제공',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#     'boundedProvisionSummary': '신원 및 거래조건에 대한 정보를 제공해야 한다는 규정이다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 6,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제17조',
#     'title': '청약철회등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#     'boundedProvisionSummary': '청약철회에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 7,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제18조',
#     'title': '청약철회등의 효과',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#     'boundedProvisionSummary': '청약철회 시의 효과에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 8,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제5조',
#     'title': '과세기간',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#     'boundedProvisionSummary': '부가가치세의 과세기간에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 9,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제8조',
#     'title': '사업자등록',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#     'boundedProvisionSummary': '사업자등록에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 10,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제36조',
#     'title': '영수증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#     'boundedProvisionSummary': '영수증 발급에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 11,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제53조의2',
#     'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#     'boundedProvisionSummary': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부에 관한 특례를 규정하고 있다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 12,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제3조',
#     'title': '약관의 작성 및 설명의무 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:1616dce193e178dfd11405c2891a1bdea99e8a3b2e06ee7b662ebcb5d99bea23',
#     'boundedProvisionSummary': '약관의 작성 및 설명의무에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 13,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제5조',
#     'title': '약관의 해석',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:f85b7d1c454d2a8ed12a884b224e377844ab60a45906b658e47469009efc00e6',
#     'boundedProvisionSummary': '약관의 해석에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 14,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제16조',
#     'title': '일부 무효의 특칙',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:0719bda3584934dc655f86e42d2bd50b5faeedf32df5de39a409256332337d52',
#     'boundedProvisionSummary': '일부 무효의 특칙에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 15,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제17조',
#     'title': '불공정약관조항의 사용금지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:c443ce12c5268686ed554a0ced386d8c85057d3bf72b69c432f50429172c692a',
#     'boundedProvisionSummary': '불공정약관조항의 사용금지에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 16,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제3조',
#     'title': '부당한 표시ㆍ광고 행위의 금지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#     'boundedProvisionSummary': '부당한 표시ㆍ광고 행위의 금지에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 17,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제5조',
#     'title': '표시ㆍ광고 내용의 실증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#     'boundedProvisionSummary': '표시ㆍ광고 내용의 실증에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 18,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제10조',
#     'title': '손해배상책임',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#     'boundedProvisionSummary': '손해배상책임에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 19,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제17조',
#     'title': '벌칙',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#     'boundedProvisionSummary': '부당한 표시ㆍ광고 행위에 대한 벌칙을 규정하고 있다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 20,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제3조',
#     'title': '부당한 표시ㆍ광고의 내용',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:bb13d967a5a68cb02624c80f3ddd5f7baf852a1e9d4661d43c631d3620d01d91',
#     'boundedProvisionSummary': '부당한 표시ㆍ광고의 내용을 규정하고 있다.',
#     'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 21,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제4조',
#     'title': '실증방법 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:4ee972b82514a4bd88f90041f42bff69d15f6cd68a02ffcef1de2f4d0129aefd',
#     'boundedProvisionSummary': '실증방법에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 22,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제5조',
#     'title': '실증자료',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:6b8b9f88f5b159b791aa1e4f4521d558ea551933142259e5bb9a59a48e05d825',
#     'boundedProvisionSummary': '실증자료에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 23,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제6조',
#     'title': '실증자료의 공개',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:9a0527dca29be7e4c086e4f5bacae119ad81d2b016a78ea353f84343d4ffbb41',
#     'boundedProvisionSummary': '실증자료의 공개에 대한 규정을 포함하고 있다.',
#     'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#     'registryVersion': 'legal-registry-v1'}],
#   'deltaLegalReviews': []}}

# %% [markdown]
# ## 39. Marketing Source

# %%
display(handoff.marketingSourceSnapshot if handoff else {
    'status': 'NOT_READY', 'reason': hypothesis_readiness.get('reason'),
    'unresolvedHypotheses': hypothesis_readiness.get('unresolvedHypotheses', [])})
# Out:
# {'contract': 'marketing-source-snapshot-v1',
#  'schemaVersion': '2.0',
#  'snapshotId': 'lab-marketing-source',
#  'projectId': 0,
#  'selectionId': 0,
#  'conceptId': 'C2',
#  'marketAnalysisSeedSnapshotId': 'lab-market-seed',
#  'marketAnalysisSeedSnapshotHash': 'sha256:2b4f11b724281fb72e5399c040194b206362f3058c0eb11e5bdf6622e3f08ee1',
#  'createdAt': '2026-08-10T07:57:24.495724+00:00',
#  'conceptName': '주말 여행 일정 자동 생성기',
#  'targetSegment': '주말 1~2일 단기 여행을 자주 계획하는 직장인',
#  'problem': '짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.',
#  'valueProposition': '사용자는 간편하게 주말 여행 일정을 계획할 수 있다.',
#  'positioning': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#  'keyFeatures': ['사용자 맞춤형 일정 생성', '숙박 및 체험 예약 통합', '이동 경로 최적화'],
#  'targetRegion': '대한민국 전역',
#  'revenueModel': '프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.',
#  'price': '서비스 이용 시 예약 수수료 발생',
#  'pricing': '프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다. · 서비스 이용 시 예약 수수료 발생',
#  'channels': ['웹사이트 및 모바일 앱'],
#  'competitorDifferentiators': ['사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험 옵션 제공'],
#  'preMarketSomShare': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='주말 여행 시장의 성장과 사용자 편의성 증가로 인해 시장 점유율 확대 가능성.', assumptions=['주말 여행을 계획하는 직장인 수 증가', '자동화된 여행 일정 생성 서비스에 대한 수요 증가']),
#  'preMarketSom': PreMarketSomHypothesis(amount=500000.0, currency='KRW', period='연간', calculationBasis='주말 여행 관련 서비스 시장 규모의 10%를 목표로 설정', assumptions=['주말 여행 시장의 연평균 성장률 5%', '사용자 편의성에 대한 수요 증가'], confidence='MEDIUM'),
#  'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#  'allowedClaims': ['사용자의 이동 가능 시간과 관심사를 반영한 자동 여행 일정 생성 서비스'],
#  'prohibitedClaims': ['사용자의 동의 없이 개인정보를 수집하거나 이용할 수 없다.',
#   '부당한 표시ㆍ광고 행위를 할 수 없다.'],
#  'requiredDisclosures': ['개인정보 처리방침을 사용자에게 고지해야 한다.',
#   '예약 서비스 이용 시 수수료에 대한 정보를 명확히 고지해야 한다.'],
#  'requiredControls': ['개인정보 수집 및 이용에 대한 동의를 명확히 받는다.',
#   '사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공하기 위한 최소한의 정보만 수집한다.',
#   '예약 서비스 중개 시, 파트너와의 계약 체결을 통해 법적 요건을 충족한다.',
#   '서비스 이용 시 예약 수수료 발생에 대한 고지 및 동의를 받는다.',
#   '광고 및 마케팅 활동 시, 부당한 표시ㆍ광고 행위의 금지 규정을 준수한다.'],
#  'communicationRequiredControls': ['개인정보 수집 및 이용에 대한 동의를 명확히 받는다.',
#   '사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공하기 위한 최소한의 정보만 수집한다.',
#   '예약 서비스 중개 시, 파트너와의 계약 체결을 통해 법적 요건을 충족한다.',
#   '서비스 이용 시 예약 수수료 발생에 대한 고지 및 동의를 받는다.',
#   '광고 및 마케팅 활동 시, 부당한 표시ㆍ광고 행위의 금지 규정을 준수한다.'],
#  'officialEvidenceReferences': [{'referenceIndex': 0,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '011357',
#    'officialIdentifier': '270351',
#    'lawName': '개인정보 보호법',
#    'articleReference': '제15조',
#    'title': '개인정보의 수집ㆍ이용',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250401',
#    'effectiveDate': '20251002',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:d057e48fdd8c23f93bcfcb814c84c02a71c51f476b2b2f824635725d488e4d9c',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 1,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '011357',
#    'officialIdentifier': '270351',
#    'lawName': '개인정보 보호법',
#    'articleReference': '제16조',
#    'title': '개인정보의 수집 제한',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250401',
#    'effectiveDate': '20251002',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:92011a2e3a02220ab77a308a194cdf773752b2c24e3059a67a0e03a80399f032',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 2,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '011357',
#    'officialIdentifier': '270351',
#    'lawName': '개인정보 보호법',
#    'articleReference': '제20조',
#    'title': '정보주체 이외로부터 수집한 개인정보의 수집 출처 등 통지',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250401',
#    'effectiveDate': '20251002',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:55c5d509f53ddd4fe40875720902fff238b927862a415b5d68f91faf6a283e3a',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 3,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '011357',
#    'officialIdentifier': '270351',
#    'lawName': '개인정보 보호법',
#    'articleReference': '제22조',
#    'title': '동의를 받는 방법',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250401',
#    'effectiveDate': '20251002',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:0a2c63314441f4a7596423f6d8e42a957e7186af1edd0e3e608019dcb8e5f2d7',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 4,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제12조',
#    'title': '통신판매업자의 신고 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 5,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제13조',
#    'title': '신원 및 거래조건에 대한 정보의 제공',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 6,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제17조',
#    'title': '청약철회등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 7,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제18조',
#    'title': '청약철회등의 효과',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 8,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제5조',
#    'title': '과세기간',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 9,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제8조',
#    'title': '사업자등록',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 10,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제36조',
#    'title': '영수증 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 11,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제53조의2',
#    'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 12,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '000667',
#    'officialIdentifier': '260021',
#    'lawName': '약관의 규제에 관한 법률',
#    'articleReference': '제3조',
#    'title': '약관의 작성 및 설명의무 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20240206',
#    'effectiveDate': '20240807',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:1616dce193e178dfd11405c2891a1bdea99e8a3b2e06ee7b662ebcb5d99bea23',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 13,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '000667',
#    'officialIdentifier': '260021',
#    'lawName': '약관의 규제에 관한 법률',
#    'articleReference': '제5조',
#    'title': '약관의 해석',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20240206',
#    'effectiveDate': '20240807',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:f85b7d1c454d2a8ed12a884b224e377844ab60a45906b658e47469009efc00e6',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 14,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '000667',
#    'officialIdentifier': '260021',
#    'lawName': '약관의 규제에 관한 법률',
#    'articleReference': '제16조',
#    'title': '일부 무효의 특칙',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20240206',
#    'effectiveDate': '20240807',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:0719bda3584934dc655f86e42d2bd50b5faeedf32df5de39a409256332337d52',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 15,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '000667',
#    'officialIdentifier': '260021',
#    'lawName': '약관의 규제에 관한 법률',
#    'articleReference': '제17조',
#    'title': '불공정약관조항의 사용금지',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20240206',
#    'effectiveDate': '20240807',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:c443ce12c5268686ed554a0ced386d8c85057d3bf72b69c432f50429172c692a',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 16,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제3조',
#    'title': '부당한 표시ㆍ광고 행위의 금지',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 17,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제5조',
#    'title': '표시ㆍ광고 내용의 실증 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 18,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제10조',
#    'title': '손해배상책임',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 19,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제17조',
#    'title': '벌칙',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 20,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '005361',
#    'officialIdentifier': '286999',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#    'articleReference': '제3조',
#    'title': '부당한 표시ㆍ광고의 내용',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260616',
#    'effectiveDate': '20260701',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:bb13d967a5a68cb02624c80f3ddd5f7baf852a1e9d4661d43c631d3620d01d91',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 21,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '005361',
#    'officialIdentifier': '286999',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#    'articleReference': '제4조',
#    'title': '실증방법 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260616',
#    'effectiveDate': '20260701',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:4ee972b82514a4bd88f90041f42bff69d15f6cd68a02ffcef1de2f4d0129aefd',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 22,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '005361',
#    'officialIdentifier': '286999',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#    'articleReference': '제5조',
#    'title': '실증자료',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260616',
#    'effectiveDate': '20260701',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:6b8b9f88f5b159b791aa1e4f4521d558ea551933142259e5bb9a59a48e05d825',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 23,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '005361',
#    'officialIdentifier': '286999',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#    'articleReference': '제6조',
#    'title': '실증자료의 공개',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260616',
#    'effectiveDate': '20260701',
#    'retrievedAt': '2026-08-10T07:55:22.707505Z',
#    'contentHash': 'sha256:9a0527dca29be7e4c086e4f5bacae119ad81d2b016a78ea353f84343d4ffbb41',
#    'registryVersion': 'legal-registry-v1'}],
#  'hash': 'sha256:193af1c707255a2db1e6ce5d5f00b371ff02a98e131939bb0f6161f105bab605',
#  'sourceSnapshotHash': 'sha256:193af1c707255a2db1e6ce5d5f00b371ff02a98e131939bb0f6161f105bab605'}

# %% [markdown]
# ## 40. Contract Compatibility

# %%
display(show_downstream_handoff(handoff) if handoff else {
    'contract': 'NOT_READY', 'reason': hypothesis_readiness.get('reason'),
    'unresolvedHypotheses': hypothesis_readiness.get('unresolvedHypotheses', [])})
# Out:
# {'호환성': 'PASS',
#  '구조': 'STRUCTURE_PASS',
#  '계약': 'CONTRACT_PASS',
#  '필드 매핑':                        v2Field                             downstreamField  \
#  0        candidate.conceptName        selectedConcept.identity.conceptName
#  1  candidate.solutionMechanism  selectedConcept.solution.solutionMechanism
#  2                hypotheses[*]                             finalHypotheses
#  3                        legal                                 legalResult
#
#                source  transformed  required
#  0  CONCEPT_GENERATED        False      True
#  1  CONCEPT_GENERATED        False      True
#  2     USER_CONFIRMED         True      True
#  3  OFFICIAL_EVIDENCE         True      True  ,
#  'Market payload': {'contract': 'market-analysis-seed-snapshot-v1',
#   'schemaVersion': '2.0',
#   'snapshotId': 'lab-market-seed',
#   'projectId': 0,
#   'selectionId': 0,
#   'conceptId': 'C2',
#   'createdAt': '2026-08-10T07:57:24.495724+00:00',
#   'sourceSnapshotHash': 'sha256:c715212e7e7a08af59439b73e313ea0d31fc991233c69b8d35b9944650ce22b8',
#   'originalSeed': {'ideaOverview': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#    'fields': {'ideaOverview': {'value': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#      'source': 'USER_INPUT',
#      'decisionState': 'LOCKED'},
#     'problem': {'value': '짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.',
#      'source': 'USER_INPUT',
#      'decisionState': 'LOCKED'},
#     'targetUsers': {'value': '주말 1~2일 단기 여행을 자주 계획하는 직장인',
#      'source': 'USER_INPUT',
#      'decisionState': 'LOCKED'}}},
#   'aiInterpretation': {'interpretedProblem': '짧은 주말 여행을 계획하는 데 소요되는 시간과 노력을 줄이는 것.',
#    'interpretedTargetUsers': '주말에 짧은 여행을 자주 계획하는 직장인들.',
#    'usageContext': '사용자가 이동 가능 시간과 관심사를 입력하면, 자동으로 여행 일정을 구성하고 예약 페이지로 연결하는 서비스.',
#    'industryCategory': '여행 및 관광',
#    'researchScope': '주말 여행 계획 서비스',
#    'conciseIdeaDefinition': '사용자의 이동 가능 시간과 관심사를 기반으로 주말 여행 일정을 자동으로 구성하는 서비스.',
#    'targetRegionInterpretation': '대상 지역은 명시되지 않음.',
#    'relevantKnownCompetitorContext': '경쟁자는 명시되지 않음.'},
#   'selectedConcept': {'identity': {'conceptName': '주말 여행 일정 자동 생성기',
#     'conceptDefinition': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#     'introduction': '사용자는 웹사이트나 모바일 앱을 통해 자신의 이동 가능 시간과 관심사를 입력하여 최적의 여행 일정을 자동으로 생성할 수 있습니다.',
#     'coreValue': '사용자는 간편하게 주말 여행 일정을 계획할 수 있다.',
#     'targetUsers': '주말 1~2일 단기 여행을 자주 계획하는 직장인',
#     'industryCategory': '여행 및 관광',
#     'researchScope': '주말 여행 계획 서비스'},
#    'solution': {'problemScenario': '짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.',
#     'solutionMechanism': '사용자가 입력한 정보를 바탕으로 최적의 여행 일정을 자동으로 생성하는 시스템을 구축한다.',
#     'featureSet': ['사용자 맞춤형 일정 생성', '숙박 및 체험 예약 통합', '이동 경로 최적화']},
#    'operation': {'actorRoles': ['사용자', '숙박업체', '체험 제공업체'],
#     'platformRole': '여행 일정 생성 및 예약 플랫폼 제공',
#     'operatingModel': '데이터 분석 및 알고리즘을 통해 사용자 맞춤형 서비스를 제공한다.',
#     'partnerModel': '숙박업체 및 체험 제공업체와 협력하여 예약 서비스를 통합한다.',
#     'providerRole': '여행 일정 생성 서비스 제공',
#     'sellerRole': '숙박 및 체험 상품 판매',
#     'intermediaryRole': '예약 서비스 중개',
#     'transactionFlow': ['사용자가 이동 가능 시간과 관심사를 입력한다.',
#      '시스템이 자동으로 여행 일정을 생성한다.',
#      '사용자가 생성된 일정을 확인하고 예약을 진행한다.',
#      '예약 시 수수료를 지불한다.'],
#     'paymentFlow': ['사용자가 예약 시 수수료를 지불한다.', '파트너에게는 일정 비율의 수익을 분배한다.'],
#     'personalDataUsage': ['사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공한다.'],
#     'physicalActivities': ['배송', '현장 방문', '설치'],
#     'partnerRequirements': ['숙박업체와의 계약 체결', '체험 제공업체와의 협력'],
#     'qualificationRequirements': []},
#    'valueSemantics': [{'fieldKey': 'conceptName',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'conceptDefinition',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'introduction',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'coreValue',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'targetUsers',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'industryCategory',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'researchScope',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'targetRegion',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'revenueModel',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'price',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'channels',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'differentiators',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'preMarketSomShareHypothesis',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'preMarketSomHypothesis',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'actorRoles',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'platformRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'problemScenario',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'solutionMechanism',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'featureSet',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'operatingModel',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'partnerModel',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'providerRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'sellerRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'intermediaryRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'transactionFlow',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'paymentFlow',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'personalDataUsage',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'physicalActivities',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'partnerRequirements',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'qualificationRequirements',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'advertisingClaims',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'}],
#    'canonicalHash': 'sha256:e723e1806e71199f9605694bfb991bcf7ba4b9374ef7d0165a456ab3ff0507a1'},
#   'finalHypotheses': {'targetRegion': {'value': '대한민국 전역',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'revenueModel': {'value': '프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'price': {'value': '서비스 이용 시 예약 수수료 발생',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'channels': {'value': '웹사이트 및 모바일 앱',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'differentiators': {'value': '사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험 옵션 제공',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'preMarketSomShare': {'value': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='주말 여행 시장의 성장과 사용자 편의성 증가로 인해 시장 점유율 확대 가능성.', assumptions=['주말 여행을 계획하는 직장인 수 증가', '자동화된 여행 일정 생성 서비스에 대한 수요 증가']),
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'preMarketSom': {'value': PreMarketSomHypothesis(amount=500000.0, currency='KRW', period='연간', calculationBasis='주말 여행 관련 서비스 시장 규모의 10%를 목표로 설정', assumptions=['주말 여행 시장의 연평균 성장률 5%', '사용자 편의성에 대한 수요 증가'], confidence='MEDIUM'),
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'}},
#   'legalResult': {'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#    'safeSummary': '이 서비스는 사용자의 이동 가능 시간과 관심사를 반영하여 맞춤형 여행 일정을 생성하고, 관련된 숙박 및 체험 상품을 예약할 수 있는 플랫폼입니다. 개인정보 보호법 및 전자상거래 관련 법령을 준수하여 운영됩니다.',
#    'requiredControls': ['개인정보 수집 및 이용에 대한 동의를 명확히 받는다.',
#     '사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공하기 위한 최소한의 정보만 수집한다.',
#     '예약 서비스 중개 시, 파트너와의 계약 체결을 통해 법적 요건을 충족한다.',
#     '서비스 이용 시 예약 수수료 발생에 대한 고지 및 동의를 받는다.',
#     '광고 및 마케팅 활동 시, 부당한 표시ㆍ광고 행위의 금지 규정을 준수한다.'],
#    'requiredPartnersAndQualifications': ['숙박업체와의 계약 체결이 필요하다.',
#     '체험 제공업체와의 협력이 필요하다.'],
#    'prohibitedVariants': ['사용자의 동의 없이 개인정보를 수집하거나 이용할 수 없다.',
#     '부당한 표시ㆍ광고 행위를 할 수 없다.'],
#    'requiredDisclosures': ['개인정보 처리방침을 사용자에게 고지해야 한다.',
#     '예약 서비스 이용 시 수수료에 대한 정보를 명확히 고지해야 한다.'],
#    'officialEvidenceReferences': [{'referenceIndex': 0,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '011357',
#      'officialIdentifier': '270351',
#      'lawName': '개인정보 보호법',
#      'articleReference': '제15조',
#      'title': '개인정보의 수집ㆍ이용',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250401',
#      'effectiveDate': '20251002',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:d057e48fdd8c23f93bcfcb814c84c02a71c51f476b2b2f824635725d488e4d9c',
#      'boundedProvisionSummary': '개인정보 수집 및 이용에 대한 규정을 명시하고 있어, 사용자 맞춤형 서비스 제공 시 개인정보 처리의 법적 근거를 제공한다.',
#      'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 1,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '011357',
#      'officialIdentifier': '270351',
#      'lawName': '개인정보 보호법',
#      'articleReference': '제16조',
#      'title': '개인정보의 수집 제한',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250401',
#      'effectiveDate': '20251002',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:92011a2e3a02220ab77a308a194cdf773752b2c24e3059a67a0e03a80399f032',
#      'boundedProvisionSummary': '개인정보 수집 시 최소한의 정보만 수집해야 한다는 규정을 포함하고 있다.',
#      'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 2,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '011357',
#      'officialIdentifier': '270351',
#      'lawName': '개인정보 보호법',
#      'articleReference': '제20조',
#      'title': '정보주체 이외로부터 수집한 개인정보의 수집 출처 등 통지',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250401',
#      'effectiveDate': '20251002',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:55c5d509f53ddd4fe40875720902fff238b927862a415b5d68f91faf6a283e3a',
#      'boundedProvisionSummary': '정보주체 이외로부터 수집한 개인정보의 출처 및 처리 목적을 통지해야 한다는 규정이다.',
#      'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 3,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '011357',
#      'officialIdentifier': '270351',
#      'lawName': '개인정보 보호법',
#      'articleReference': '제22조',
#      'title': '동의를 받는 방법',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250401',
#      'effectiveDate': '20251002',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:0a2c63314441f4a7596423f6d8e42a957e7186af1edd0e3e608019dcb8e5f2d7',
#      'boundedProvisionSummary': '개인정보 처리에 대한 동의를 받을 때의 방법을 규정하고 있다.',
#      'queryKey': 'sha256:81c12570e2e5cea79930d1a540adc219753f11bd9d414624649648c5446ffd4a',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 4,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제12조',
#      'title': '통신판매업자의 신고 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#      'boundedProvisionSummary': '통신판매업자는 신고를 통해 사업자 정보를 제공해야 한다는 규정이다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 5,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제13조',
#      'title': '신원 및 거래조건에 대한 정보의 제공',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#      'boundedProvisionSummary': '신원 및 거래조건에 대한 정보를 제공해야 한다는 규정이다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 6,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제17조',
#      'title': '청약철회등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#      'boundedProvisionSummary': '청약철회에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 7,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제18조',
#      'title': '청약철회등의 효과',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#      'boundedProvisionSummary': '청약철회 시의 효과에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 8,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제5조',
#      'title': '과세기간',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#      'boundedProvisionSummary': '부가가치세의 과세기간에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 9,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제8조',
#      'title': '사업자등록',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#      'boundedProvisionSummary': '사업자등록에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 10,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제36조',
#      'title': '영수증 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#      'boundedProvisionSummary': '영수증 발급에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 11,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제53조의2',
#      'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#      'boundedProvisionSummary': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부에 관한 특례를 규정하고 있다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 12,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '000667',
#      'officialIdentifier': '260021',
#      'lawName': '약관의 규제에 관한 법률',
#      'articleReference': '제3조',
#      'title': '약관의 작성 및 설명의무 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20240206',
#      'effectiveDate': '20240807',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:1616dce193e178dfd11405c2891a1bdea99e8a3b2e06ee7b662ebcb5d99bea23',
#      'boundedProvisionSummary': '약관의 작성 및 설명의무에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 13,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '000667',
#      'officialIdentifier': '260021',
#      'lawName': '약관의 규제에 관한 법률',
#      'articleReference': '제5조',
#      'title': '약관의 해석',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20240206',
#      'effectiveDate': '20240807',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:f85b7d1c454d2a8ed12a884b224e377844ab60a45906b658e47469009efc00e6',
#      'boundedProvisionSummary': '약관의 해석에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 14,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '000667',
#      'officialIdentifier': '260021',
#      'lawName': '약관의 규제에 관한 법률',
#      'articleReference': '제16조',
#      'title': '일부 무효의 특칙',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20240206',
#      'effectiveDate': '20240807',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:0719bda3584934dc655f86e42d2bd50b5faeedf32df5de39a409256332337d52',
#      'boundedProvisionSummary': '일부 무효의 특칙에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 15,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '000667',
#      'officialIdentifier': '260021',
#      'lawName': '약관의 규제에 관한 법률',
#      'articleReference': '제17조',
#      'title': '불공정약관조항의 사용금지',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20240206',
#      'effectiveDate': '20240807',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:c443ce12c5268686ed554a0ced386d8c85057d3bf72b69c432f50429172c692a',
#      'boundedProvisionSummary': '불공정약관조항의 사용금지에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:e71cfb4d78c3ba6b3c458d97c9b6b31c2f7d35ec9e1b5418ac514c78d5df3a4d',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 16,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제3조',
#      'title': '부당한 표시ㆍ광고 행위의 금지',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#      'boundedProvisionSummary': '부당한 표시ㆍ광고 행위의 금지에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 17,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제5조',
#      'title': '표시ㆍ광고 내용의 실증 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#      'boundedProvisionSummary': '표시ㆍ광고 내용의 실증에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 18,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제10조',
#      'title': '손해배상책임',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#      'boundedProvisionSummary': '손해배상책임에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 19,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제17조',
#      'title': '벌칙',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#      'boundedProvisionSummary': '부당한 표시ㆍ광고 행위에 대한 벌칙을 규정하고 있다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 20,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '005361',
#      'officialIdentifier': '286999',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#      'articleReference': '제3조',
#      'title': '부당한 표시ㆍ광고의 내용',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260616',
#      'effectiveDate': '20260701',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:bb13d967a5a68cb02624c80f3ddd5f7baf852a1e9d4661d43c631d3620d01d91',
#      'boundedProvisionSummary': '부당한 표시ㆍ광고의 내용을 규정하고 있다.',
#      'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 21,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '005361',
#      'officialIdentifier': '286999',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#      'articleReference': '제4조',
#      'title': '실증방법 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260616',
#      'effectiveDate': '20260701',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:4ee972b82514a4bd88f90041f42bff69d15f6cd68a02ffcef1de2f4d0129aefd',
#      'boundedProvisionSummary': '실증방법에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 22,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '005361',
#      'officialIdentifier': '286999',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#      'articleReference': '제5조',
#      'title': '실증자료',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260616',
#      'effectiveDate': '20260701',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:6b8b9f88f5b159b791aa1e4f4521d558ea551933142259e5bb9a59a48e05d825',
#      'boundedProvisionSummary': '실증자료에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 23,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '005361',
#      'officialIdentifier': '286999',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#      'articleReference': '제6조',
#      'title': '실증자료의 공개',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260616',
#      'effectiveDate': '20260701',
#      'retrievedAt': '2026-08-10T07:55:22.707505Z',
#      'contentHash': 'sha256:9a0527dca29be7e4c086e4f5bacae119ad81d2b016a78ea353f84343d4ffbb41',
#      'boundedProvisionSummary': '실증자료의 공개에 대한 규정을 포함하고 있다.',
#      'queryKey': 'sha256:382b4f44c9f57ba85dbc573bab8ea2f5ef5e10463301ada99b8838bc3a3b8d99',
#      'registryVersion': 'legal-registry-v1'}],
#    'deltaLegalReviews': []}},
#  'Marketing payload': {'contract': 'marketing-source-snapshot-v1',
#   'schemaVersion': '2.0',
#   'snapshotId': 'lab-marketing-source',
#   'projectId': 0,
#   'selectionId': 0,
#   'conceptId': 'C2',
#   'marketAnalysisSeedSnapshotId': 'lab-market-seed',
#   'marketAnalysisSeedSnapshotHash': 'sha256:2b4f11b724281fb72e5399c040194b206362f3058c0eb11e5bdf6622e3f08ee1',
#   'createdAt': '2026-08-10T07:57:24.495724+00:00',
#   'conceptName': '주말 여행 일정 자동 생성기',
#   'targetSegment': '주말 1~2일 단기 여행을 자주 계획하는 직장인',
#   'problem': '짧은 주말 여행은 이동 시간까지 고려해 일정을 직접 조합하는 데 많은 시간이 든다.',
#   'valueProposition': '사용자는 간편하게 주말 여행 일정을 계획할 수 있다.',
#   'positioning': '사용자의 이동 가능 시간과 관심사를 바탕으로 주말 근거리 여행 일정을 자동 구성하고 숙박·체험 예약 페이지로 연결하는 여행 계획 서비스',
#   'keyFeatures': ['사용자 맞춤형 일정 생성', '숙박 및 체험 예약 통합', '이동 경로 최적화'],
#   'targetRegion': '대한민국 전역',
#   'revenueModel': '프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다.',
#   'price': '서비스 이용 시 예약 수수료 발생',
#   'pricing': '프리미엄 서비스 및 광고를 통해 추가 수익을 창출한다. · 서비스 이용 시 예약 수수료 발생',
#   'channels': ['웹사이트 및 모바일 앱'],
#   'competitorDifferentiators': ['사용자의 이동 가능 시간과 관심사를 반영한 맞춤형 일정 생성, 다양한 숙박 및 체험 옵션 제공'],
#   'preMarketSomShare': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='주말 여행 시장의 성장과 사용자 편의성 증가로 인해 시장 점유율 확대 가능성.', assumptions=['주말 여행을 계획하는 직장인 수 증가', '자동화된 여행 일정 생성 서비스에 대한 수요 증가']),
#   'preMarketSom': PreMarketSomHypothesis(amount=500000.0, currency='KRW', period='연간', calculationBasis='주말 여행 관련 서비스 시장 규모의 10%를 목표로 설정', assumptions=['주말 여행 시장의 연평균 성장률 5%', '사용자 편의성에 대한 수요 증가'], confidence='MEDIUM'),
#   'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#   'allowedClaims': ['사용자의 이동 가능 시간과 관심사를 반영한 자동 여행 일정 생성 서비스'],
#   'prohibitedClaims': ['사용자의 동의 없이 개인정보를 수집하거나 이용할 수 없다.',
#    '부당한 표시ㆍ광고 행위를 할 수 없다.'],
#   'requiredDisclosures': ['개인정보 처리방침을 사용자에게 고지해야 한다.',
#    '예약 서비스 이용 시 수수료에 대한 정보를 명확히 고지해야 한다.'],
#   'requiredControls': ['개인정보 수집 및 이용에 대한 동의를 명확히 받는다.',
#    '사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공하기 위한 최소한의 정보만 수집한다.',
#    '예약 서비스 중개 시, 파트너와의 계약 체결을 통해 법적 요건을 충족한다.',
#    '서비스 이용 시 예약 수수료 발생에 대한 고지 및 동의를 받는다.',
#    '광고 및 마케팅 활동 시, 부당한 표시ㆍ광고 행위의 금지 규정을 준수한다.'],
#   'communicationRequiredControls': ['개인정보 수집 및 이용에 대한 동의를 명확히 받는다.',
#    '사용자의 이동 가능 시간과 관심사를 수집하여 맞춤형 서비스를 제공하기 위한 최소한의 정보만 수집한다.',
#    '예약 서비스 중개 시, 파트너와의 계약 체결을 통해 법적 요건을 충족한다.',
#    '서비스 이용 시 예약 수수료 발생에 대한 고지 및 동의를 받는다.',
#    '광고 및 마케팅 활동 시, 부당한 표시ㆍ광고 행위의 금지 규정을 준수한다.'],
#   'officialEvidenceReferences': [{'referenceIndex': 0,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제15조',
#     'title': '개인정보의 수집ㆍ이용',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:d057e48fdd8c23f93bcfcb814c84c02a71c51f476b2b2f824635725d488e4d9c',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 1,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제16조',
#     'title': '개인정보의 수집 제한',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:92011a2e3a02220ab77a308a194cdf773752b2c24e3059a67a0e03a80399f032',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 2,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제20조',
#     'title': '정보주체 이외로부터 수집한 개인정보의 수집 출처 등 통지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:55c5d509f53ddd4fe40875720902fff238b927862a415b5d68f91faf6a283e3a',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 3,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '011357',
#     'officialIdentifier': '270351',
#     'lawName': '개인정보 보호법',
#     'articleReference': '제22조',
#     'title': '동의를 받는 방법',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EA%B0%9C%EC%9D%B8%EC%A0%95%EB%B3%B4%20%EB%B3%B4%ED%98%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250401',
#     'effectiveDate': '20251002',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:0a2c63314441f4a7596423f6d8e42a957e7186af1edd0e3e608019dcb8e5f2d7',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 4,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제12조',
#     'title': '통신판매업자의 신고 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 5,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제13조',
#     'title': '신원 및 거래조건에 대한 정보의 제공',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 6,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제17조',
#     'title': '청약철회등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 7,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제18조',
#     'title': '청약철회등의 효과',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 8,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제5조',
#     'title': '과세기간',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 9,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제8조',
#     'title': '사업자등록',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 10,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제36조',
#     'title': '영수증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 11,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제53조의2',
#     'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 12,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제3조',
#     'title': '약관의 작성 및 설명의무 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:1616dce193e178dfd11405c2891a1bdea99e8a3b2e06ee7b662ebcb5d99bea23',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 13,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제5조',
#     'title': '약관의 해석',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:f85b7d1c454d2a8ed12a884b224e377844ab60a45906b658e47469009efc00e6',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 14,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제16조',
#     'title': '일부 무효의 특칙',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:0719bda3584934dc655f86e42d2bd50b5faeedf32df5de39a409256332337d52',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 15,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000667',
#     'officialIdentifier': '260021',
#     'lawName': '약관의 규제에 관한 법률',
#     'articleReference': '제17조',
#     'title': '불공정약관조항의 사용금지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%95%BD%EA%B4%80%EC%9D%98%20%EA%B7%9C%EC%A0%9C%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20240206',
#     'effectiveDate': '20240807',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:c443ce12c5268686ed554a0ced386d8c85057d3bf72b69c432f50429172c692a',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 16,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제3조',
#     'title': '부당한 표시ㆍ광고 행위의 금지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 17,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제5조',
#     'title': '표시ㆍ광고 내용의 실증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 18,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제10조',
#     'title': '손해배상책임',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 19,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제17조',
#     'title': '벌칙',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 20,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제3조',
#     'title': '부당한 표시ㆍ광고의 내용',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:bb13d967a5a68cb02624c80f3ddd5f7baf852a1e9d4661d43c631d3620d01d91',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 21,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제4조',
#     'title': '실증방법 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:4ee972b82514a4bd88f90041f42bff69d15f6cd68a02ffcef1de2f4d0129aefd',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 22,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제5조',
#     'title': '실증자료',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:6b8b9f88f5b159b791aa1e4f4521d558ea551933142259e5bb9a59a48e05d825',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 23,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '005361',
#     'officialIdentifier': '286999',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률 시행령',
#     'articleReference': '제6조',
#     'title': '실증자료의 공개',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0%20%EC%8B%9C%ED%96%89%EB%A0%B9',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260616',
#     'effectiveDate': '20260701',
#     'retrievedAt': '2026-08-10T07:55:22.707505Z',
#     'contentHash': 'sha256:9a0527dca29be7e4c086e4f5bacae119ad81d2b016a78ea353f84343d4ffbb41',
#     'registryVersion': 'legal-registry-v1'}],
#   'hash': 'sha256:193af1c707255a2db1e6ce5d5f00b371ff02a98e131939bb0f6161f105bab605',
#   'sourceSnapshotHash': 'sha256:193af1c707255a2db1e6ce5d5f00b371ff02a98e131939bb0f6161f105bab605'},
#  '오류': []}

# %% [markdown]
# ## 41. Trace

# %%
display(show_trace(engine.trace))
# Out:
#     순서                                시각                 stage  \
# 0    1  2026-08-10T07:52:04.458596+00:00               CREATED
# 1    2  2026-08-10T07:52:10.223407+00:00       SAFETY_CHECKING
# 2    3  2026-08-10T07:52:10.223423+00:00       SAFETY_CHECKING
# 3    4  2026-08-10T07:52:10.316961+00:00        SEED_ANALYZING
# 4    5  2026-08-10T07:52:10.317253+00:00        SEED_ANALYZING
# ..  ..                               ...                   ...
# 62  63  2026-08-10T07:57:18.205697+00:00  CANDIDATE_VALIDATING
# 63  64  2026-08-10T07:57:22.211901+00:00  CANDIDATE_VALIDATING
# 64  65  2026-08-10T07:57:22.212517+00:00  CANDIDATE_VALIDATING
# 65  66  2026-08-10T07:57:24.438960+00:00  PORTFOLIO_VALIDATING
# 66  67  2026-08-10T07:57:24.512571+00:00  PORTFOLIO_VALIDATING
#
#                             action          entity parent   status  mode  \
# 0                          CREATED             NaN    NaN  RUNNING  LIVE
# 1               IDEA_BRIEF_DERIVED             NaN    NaN     PASS  LIVE
# 2           READINESS_INCONSISTENT             NaN    NaN  WARNING  LIVE
# 3                         ANALYZED  lab-idea-brief    NaN     PASS  LIVE
# 4               DESIGN_SPACE_READY             NaN    NaN     PASS  LIVE
# ..                             ...             ...    ...      ...   ...
# 62                         STARTED             NaN    NaN  RUNNING  LIVE
# 63  ARCHITECTURE_SEMANTIC_FALLBACK             NaN    NaN     PASS  LIVE
# 64                       VALIDATED       C3-R1-CR1    NaN     PASS  LIVE
# 65       HYPOTHESIS_SEMANTIC_BATCH             NaN    NaN     PASS  LIVE
# 66               HANDOFF_VALIDATED              C2    NaN     PASS  LIVE
#
#       호출                                                 요약  \
# 0    NaN                                 V2 Lab 실행을 생성했습니다.
# 1    1.0  Idea interpretation/readiness를 보존했습니다: READY_F...
# 2    NaN  READY_FOR_REVIEW이지만 score=0입니다. V2 gating은 막지 ...
# 3    NaN                            필수 3개와 LOCK 3개를 분류했습니다.
# 4    NaN              Open=11 Constrained=0 Breadth=EXPLORE
# ..   ...                                                ...
# 62   NaN                            Candidate 검사를 분리 수행합니다.
# 63  24.0  low-confidence Candidate architecture 1개를 batc...
# 64   NaN                                              검사 통과
# 65  25.0             ambiguous Hypothesis 1개를 batch 검증했습니다.
# 66   NaN             downstream contract compatibility=PASS
#
#                   decision reasonCode
# 0                      NaN        NaN
# 1                      NaN        NaN
# 2   READINESS_INCONSISTENT        NaN
# 3                      NaN        NaN
# 4                      NaN        NaN
# ..                     ...        ...
# 62                     NaN        NaN
# 63                     NaN        NaN
# 64                     NaN        NaN
# 65                     NaN        NaN
# 66                     NaN        NaN
#
# [67 rows x 12 columns]

# %% [markdown]
# ## 42. Provider/Legal Usage

# %%
display(show_provider_usage(engine.gateway.usage))
print('상위 외부 작업 수는 내부 AI/MOLEG 네트워크 호출 수와 동일하다고 주장하지 않습니다.')
# Out:
#    논리 작업  상위 외부 작업                                          논리 stage별  \
# 0     25        25  {'SAFETY_CHECKING': 1, 'PLANNING': 2, 'NORMALI...
#
#                                      상위 외부 작업 stage별  재시도  소요(ms)  \
# 0  {'SAFETY_CHECKING': 1, 'PLANNING': 2, 'NORMALI...    0  317692
#
#             모드별 token 보고 비용
# 0  {'LIVE': 25}  None  None
# 상위 외부 작업 수는 내부 AI/MOLEG 네트워크 호출 수와 동일하다고 주장하지 않습니다.

# %% [markdown]
# ## 43. Replay Manifest

# %%
display(show_replay_manifest(engine.gateway))
# Out:
# {'status': 'REPLAY_PARTIAL',
#  'entries':                    operation  \
#  0               LEGAL_REVIEW
#  1          SEMANTIC_RELATION
#  2                     EXPAND
#  3    NORMALIZE_ARCHITECTURES
#  4                     EXPAND
#  ..                       ...
#  536    LEGAL_FACT_COMPLETION
#  537    IDEA_BRIEF_DERIVATION
#  538       PLAN_REPLENISHMENT
#  539                PLAN_POOL
#  540             LEGAL_REVIEW
#
#                                                    hash operationVersion  \
#  0    00489dd62bff3c4b9e8711093fb3e398a39dde1547de32...               v3
#  1    00c1eeb4f93989a6db3891fb7a22355a71a68800a6f641...               v3
#  2    0120f755ef50e68db6e1d7d1adb0563892b2f762578608...               v3
#  3    013ebfc11d61a317c1041ddcf75902b1dab0d310e73666...               v1
#  4    02bf209b45f806d67ec78f5bdc5e0e24bf99e05fbd297f...               v3
#  ..                                                 ...              ...
#  536  fc333103264d3fbc56f5df306b221a16869fa737da87ab...               v1
#  537  fc5b3fe1b2fb09f8b0b6587abc4a067f3c1f1682a4e68c...               v2
#  538  fcc0dde517404bc3712e16384ce9f3a9c44ca5d5f06242...               v3
#  539  fd4ea7d8f4c176971dc390682c54fb6d7bc7428fa2d79a...               v3
#  540  ff7ecbd2ee5cb90f030bc7972f25779b05155b203be50c...               v3
#
#                                      promptVersion schemaVersion  recordExists  \
#  0                         concept-legal-review-v3           2.0          True
#  1                   concept-portfolio-relation-v3           2.0          True
#  2          concept-portfolio-generic-candidate-v3           2.0          True
#  3    concept-portfolio-architecture-classifier-v1           2.0          True
#  4          concept-portfolio-generic-candidate-v3           2.0          True
#  ..                                            ...           ...           ...
#  536              concept-legal-fact-completion-v1           2.0          True
#  537                         idea-brief-current-v2           2.0          True
#  538             concept-portfolio-generic-plan-v3           2.0          True
#  539             concept-portfolio-generic-plan-v3           2.0          True
#  540                       concept-legal-review-v3           2.0          True
#
#                              timestamp  versionCompatible
#  0    2026-08-10T05:26:30.277902+00:00               True
#  1    2026-08-10T05:23:00.398650+00:00               True
#  2    2026-08-10T07:53:56.875008+00:00               True
#  3    2026-08-10T06:48:53.957430+00:00               True
#  4    2026-08-10T04:54:06.673791+00:00               True
#  ..                                ...                ...
#  536  2026-08-10T03:54:15.847132+00:00               True
#  537  2026-08-10T07:52:25.701380+00:00               True
#  538  2026-08-10T07:55:41.833711+00:00               True
#  539  2026-08-10T04:53:21.046707+00:00               True
#  540  2026-08-10T05:18:41.881979+00:00               True
#
#  [541 rows x 8 columns]}

# %% [markdown]
# ## 44. One-click MOCK

# %%
mock_result = None
if LIVE_TEST_LEVEL == 'FULL_E2E' and MODE != 'LIVE':
    mock_result = await ConceptPortfolioEngine('MOCK').run_full(
        TEST_INPUT, max_concepts=MAX_CONCEPTS, auto_confirm_hypotheses=True)
display(show_run_summary(mock_result) if mock_result else {'status': 'SKIPPED'})
assert mock_result is None or (mock_result.handoff and mock_result.handoff.contractStatus == 'CONTRACT_PASS')
# Out:
# {'status': 'SKIPPED'}

# %% [markdown]
# ## 45. One-click REPLAY

# %%
RUN_ONE_CLICK_REPLAY = False
replay_result = None
if RUN_ONE_CLICK_REPLAY:
    replay_gateway = ProviderGateway('REPLAY', recordings_dir=RECORDINGS_DIR)
    replay_result = await ConceptPortfolioEngine('REPLAY', gateway=replay_gateway).run_full(
        TEST_INPUT, max_concepts=MAX_CONCEPTS, auto_confirm_hypotheses=False)
display(show_run_summary(replay_result) if replay_result else {'status': 'SKIPPED'})
# Out:
# {'status': 'SKIPPED'}

# %% [markdown]
# ## 46. One-click LIVE

# %%
RUN_ONE_CLICK_LIVE = True
live_result = None
if RUN_ONE_CLICK_LIVE and LIVE_TEST_LEVEL == 'ONE_CLICK':
    assert MODE == 'LIVE', 'MODE=LIVE를 먼저 명시하세요.'
    one_click_gateway = ProviderGateway('LIVE', recordings_dir=RECORDINGS_DIR)
    one_click_engine = ConceptPortfolioEngine('LIVE', gateway=one_click_gateway)
    live_result = await one_click_engine.run_full(TEST_INPUT, max_concepts=MAX_CONCEPTS,
                                                  auto_confirm_hypotheses=False)
display(show_run_summary(live_result) if live_result else {'status': 'SKIPPED'})
if live_result:
    display(show_live_validation_summary(LIVE_SCENARIO, live_result))
    display(show_required_inputs(live_result))
    display(show_pre_legal_exclusions(live_result))
    display(show_legal_resolutions(live_result))
    if live_result.runStatus.value == 'FAILED':
        display(show_run_failure(live_result))
        display(show_provider_failure(one_click_engine.gateway))
        display(show_provider_usage(live_result.providerUsage))
        display(show_trace(live_result.trace[-20:]))
        display({'unresolvedCandidates': live_result.unresolvedCandidates,
                 'lastSuccessfulStage': live_result.failureDiagnostics.lastSuccessfulStage if live_result.failureDiagnostics else None,
                 'firstFailedStage': live_result.failureDiagnostics.firstFailedStage if live_result.failureDiagnostics else None})
# Out:
# {'status': 'SKIPPED'}
