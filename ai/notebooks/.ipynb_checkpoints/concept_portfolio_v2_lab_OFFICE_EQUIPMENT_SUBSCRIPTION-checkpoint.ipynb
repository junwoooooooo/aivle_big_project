# %% [markdown]
# ## 00. Quick Start

# %%
print('Concept Portfolio V2 Lab — staged와 one-click은 동일 Core를 사용합니다.')
print('LIVE_TEST_LEVEL로 CORE / LEGAL_C1 / FULL_E2E / ONE_CLICK 중 하나만 선택하세요.')
# Out:
# Concept Portfolio V2 Lab — staged와 one-click은 동일 Core를 사용합니다.
# LIVE_TEST_LEVEL로 CORE / LEGAL_C1 / FULL_E2E / ONE_CLICK 중 하나만 선택하세요.

# %% [markdown]
# ## 01. Environment

# %%
import os, sys, json
from pathlib import Path
from IPython.display import display
SEARCH_ROOTS = [Path.cwd(), *Path.cwd().parents]
AI_ROOT = next((p for p in SEARCH_ROOTS if (p / 'app').is_dir()), None)
if AI_ROOT is None: AI_ROOT = next((p / 'ai' for p in SEARCH_ROOTS if (p / 'ai' / 'app').is_dir()))
if str(AI_ROOT) not in sys.path: sys.path.insert(0, str(AI_ROOT))
print({'python': sys.version.split()[0], 'aiRoot': str(AI_ROOT)})
# Out:
# {'python': '3.14.5', 'aiRoot': 'C:\\Users\\seewo\\Desktop\\big_proj_01\\new_3\\ai'}

# %% [markdown]
# ## 02. MODE

# %%
MODE = 'LIVE'  # MOCK | REPLAY | LIVE
RECORDINGS_DIR = AI_ROOT / 'recordings' / 'concept_portfolio_v2'
print({'mode': MODE, 'liveExternalOperationsEnabled': MODE == 'LIVE'})
# Out:
# {'mode': 'LIVE', 'liveExternalOperationsEnabled': True}

# %% [markdown]
# ## 03. Environment Check

# %%
LIVE_ENV_KEYS = ['AI_PROVIDER', 'AI_API_KEY', 'AI_MODEL', 'MOLEG_API_KEY', 'LEGAL_REGISTRY_VERSION']
env_status = {key: bool(os.getenv(key)) for key in LIVE_ENV_KEYS}
print(env_status if MODE == 'LIVE' else {'mode': MODE, 'message': '외부 환경변수 불필요'})
# Out:
# {'AI_PROVIDER': True, 'AI_API_KEY': True, 'AI_MODEL': True, 'MOLEG_API_KEY': True, 'LEGAL_REGISTRY_VERSION': True}

# %% [markdown]
# ## 04. Schema Preflight

# %%
from app.concept_portfolio_v2 import ConceptPortfolioEngine, ProviderGateway, ProviderMode
from app.concept_portfolio_v2.adapters import CurrentLegalAdapter
from app.concept_portfolio_v2.diagnostics.notebook_view import *
gateway = ProviderGateway(MODE, recordings_dir=RECORDINGS_DIR)
engine = ConceptPortfolioEngine(MODE, gateway=gateway)
schema_preflight = engine.schema_preflight_report()
display(show_schema_preflight(schema_preflight))
assert schema_preflight.status == 'PASS' and schema_preflight.providerCalls == 0
# Out:
#                                 스키마    상태  실패  Provider 호출
# 0                     PlanDraftPool  PASS  []            0
# 1             ConceptCandidateDraft  PASS  []            0
# 2        SemanticDistinctnessResult  PASS  []            0
# 3            SemanticFidelityResult  PASS  []            0
# 4         SemanticArchitectureBatch  PASS  []            0
# 5           SemanticHypothesisBatch  PASS  []            0
# 6         BusinessRoleSemanticBatch  PASS  []            0
# 7  LegalFactDependencySemanticBatch  PASS  []            0
# 8          LegalFactCompletionPatch  PASS  []            0

# %% [markdown]
# ## 05. Input

# %%
SCENARIO_FILE = AI_ROOT / 'fixtures' / 'concept_portfolio_v2' / 'live_scenarios.json'
SCENARIOS = {item['scenarioId']: item for item in json.loads(SCENARIO_FILE.read_text(encoding='utf-8'))}
LIVE_SCENARIO = 'OFFICE_EQUIPMENT_SUBSCRIPTION'
LIVE_TEST_LEVEL = 'FULL_E2E'  # CORE | LEGAL_C1 | FULL_E2E | ONE_CLICK
RUN_STAGED_CORE = LIVE_TEST_LEVEL in {'CORE', 'LEGAL_C1', 'FULL_E2E'}
RUN_STAGED_LEGAL = LIVE_TEST_LEVEL in {'LEGAL_C1', 'FULL_E2E'}
RUN_STAGED_FULL = LIVE_TEST_LEVEL == 'FULL_E2E'
scenario = SCENARIOS[LIVE_SCENARIO]
TEST_INPUT = {key: scenario[key] for key in ('ideaOverview', 'problem', 'targetUsers')}
MAX_CONCEPTS = 5
display({'scenario': LIVE_SCENARIO, 'testLevel': LIVE_TEST_LEVEL, 'domain': scenario['domain'],
         'expectedStructuralFeatures': scenario['expectedStructuralFeatures']})
# Out:
# {'scenario': 'OFFICE_EQUIPMENT_SUBSCRIPTION',
#  'testLevel': 'FULL_E2E',
#  'domain': 'B2B physical subscription',
#  'expectedStructuralFeatures': ['직접 운영', '구독', '물리 이행', '비중개']}

# %% [markdown]
# ## 06. Idea Brief Derivation

# %%
seed = engine.seed_adapter.adapt(TEST_INPUT)
idea_context = None
if RUN_STAGED_CORE:
    engine._reset()
    idea_context = await engine.derive_idea_brief(seed)
print({'ideaCallComplete': bool(idea_context), 'interpretationPresent': bool(seed.interpretation),
       'stagedCore': RUN_STAGED_CORE})
# Out:
# {'ideaCallComplete': True, 'interpretationPresent': True, 'stagedCore': True}

# %% [markdown]
# ## 07. Safety

# %%
display(idea_context.safetyReview.model_dump(mode='json') if idea_context else {'status': 'SKIPPED'})
assert idea_context is None or idea_context.safetyReview.passed
# Out:
# {'decision': 'ALLOW',
#  'categories': [],
#  'restrictions': [],
#  'userFacingReason': '이 아이디어는 안전하다고 판단됩니다.'}

# %% [markdown]
# ## 08. AI가 이해한 아이디어

# %%
display(show_idea_interpretation(idea_context) if idea_context else {'status': 'SKIPPED'})
# Out:
#                                항목  \
# 0              interpretedProblem
# 1          interpretedTargetUsers
# 2                    usageContext
# 3                industryCategory
# 4                   researchScope
# 5           conciseIdeaDefinition
# 6      targetRegionInterpretation
# 7  relevantKnownCompetitorContext
#
#                                             AI 이해 결과
# 0  소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 ...
# 1                              10~50인 규모의 소형 사무실 운영자
# 2                    소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 3                                               서비스업
# 4                              소형 사무실의 화상회의 장비 대여 시장
# 5                       소형 사무실을 위한 화상회의 장비 정기 대여 서비스
# 6                            대여 서비스가 제공될 지역은 명시되지 않음
# 7                                       경쟁자는 명시되지 않음

# %% [markdown]
# ## 09. Readiness / Summary / commitments

# %%
display(show_idea_readiness(idea_context) if idea_context else {'status': 'SKIPPED'})
# Out:
# {'readiness': {'status': 'READY_FOR_REVIEW',
#   'score': 0,
#   'missingFieldKeys': []},
#  'readinessDiagnostic': 'READINESS_INCONSISTENT',
#  'userFacingSummary': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스입니다.',
#  'commitmentCandidates': [],
#  'contradictions': [],
#  'questions': []}

# %% [markdown]
# ## 10. Seed Analysis

# %%
analysis = await engine.analyze_seed(seed) if RUN_STAGED_CORE else None
display(show_seed_analysis(analysis) if analysis else {'status': 'SKIPPED'})
# Out:
#         구분                                                  값
# 0     탐색 폭                                            EXPLORE
# 1  다양성 수용량                                                  5
# 2       설명  선택 입력 LOCK 0개로 11개 설계 차원이 열려 있습니다. diversityCa...

# %% [markdown]
# ## 11. Generic Opportunity Kernel

# %%
display(analysis.opportunityKernel.model_dump(mode='json') if analysis else {'status': 'SKIPPED'})
# Out:
# {'problemCore': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#  'targetCore': '10~50인 규모의 소형 사무실 운영자',
#  'useContexts': ['소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황'],
#  'intentComponents': ['소형 사무실을 위한 화상회의 장비 정기 대여 서비스'],
#  'mustPreserve': ['소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#   '10~50인 규모의 소형 사무실 운영자',
#   '소형 사무실을 위한 화상회의 장비 정기 대여 서비스'],
#  'maySpecialize': ['핵심 대상의 의미 있는 하위 세그먼트',
#   '핵심 사용 맥락의 구체화',
#   '가치 제안 또는 offer의 구체화'],
#  'forbiddenDriftSummary': '핵심 문제와 대상이 모두 무관한 기회로 교체되면 범위를 벗어납니다.'}

# %% [markdown]
# ## 12. Design Space

# %%
display(show_design_space(analysis) if analysis else {'status': 'SKIPPED'})
# Out:
#                  분류                  필드  \
# 0       SOURCE_LOCK        ideaOverview
# 1       SOURCE_LOCK             problem
# 2       SOURCE_LOCK         targetUsers
# 3   SEMANTIC_ANCHOR        ideaOverview
# 4   SEMANTIC_ANCHOR             problem
# 5   SEMANTIC_ANCHOR         targetUsers
# 6              OPEN   solutionMechanism
# 7              OPEN       valueDelivery
# 8              OPEN      operatingModel
# 9              OPEN     supplyStructure
# 10             OPEN        partnerModel
# 11             OPEN     transactionFlow
# 12             OPEN         fulfillment
# 13             OPEN        platformRole
# 14             OPEN      commercialFlow
# 15             OPEN      dataDependency
# 16             OPEN  physicalDependency
#
#                                                     값
# 0   소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스
# 1   소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 ...
# 2                               10~50인 규모의 소형 사무실 운영자
# 3   소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스
# 4   소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 ...
# 5                               10~50인 규모의 소형 사무실 운영자
# 6                                               변경 가능
# 7                                               변경 가능
# 8                                               변경 가능
# 9                                               변경 가능
# 10                                              변경 가능
# 11                                              변경 가능
# 12                                              변경 가능
# 13                                              변경 가능
# 14                                              변경 가능
# 15                                              변경 가능
# 16                                              변경 가능

# %% [markdown]
# ## 13. Generate and Adaptively Replenish Plan Pool

# %%
plan_validation = (await engine.prepare_portfolio_plans(seed, analysis, max_concepts=MAX_CONCEPTS)
                   if RUN_STAGED_CORE else None)
plans = engine._last_plan_pool if plan_validation else []
print({'totalPlans': len(plans),
       'planningRounds': plan_validation.planningRounds if plan_validation else 0,
       'replenishmentRequested': plan_validation.replenishmentRequested if plan_validation else 0})
# Out:
# {'totalPlans': 6, 'planningRounds': 1, 'replenishmentRequested': 0}

# %% [markdown]
# ## 14. Plan Count / Adaptive Replenishment Check

# %%
display(show_plan_pool_status(engine._last_plan_pool_status) if plan_validation else {'status': 'SKIPPED'})
display({'planningRounds': plan_validation.planningRounds if plan_validation else 0,
         'replenishmentRequested': plan_validation.replenishmentRequested if plan_validation else 0,
         'adaptiveReplenishmentUsed': bool(plan_validation and plan_validation.planningRounds > 1)})
# Out:
#    requestedPoolSize  returnedPoolSize  initialTarget  reserveTarget  \
# 0                  7                 6              5              2
#
#    reserveAvailable             status
# 0                 1  RESERVE_SHORTFALL
# {'planningRounds': 1,
#  'replenishmentRequested': 0,
#  'adaptiveReplenishmentUsed': False}

# %% [markdown]
# ## 15. Korean Plan Display

# %%
display(show_portfolio_plans(plan_validation.acceptedPlans + plan_validation.reservePlans)
        if plan_validation else {'status': 'SKIPPED'})
# Out:
#   planId                                  제목     선택 상태  selectionScore  \
# 0     P1               소형 사무실 화상회의 장비 대여 서비스  SELECTED          0.9145
# 1     P5  소형 사무실 화상회의 장비 대여 및 맞춤형 솔루션 제공 서비스  SELECTED          0.9573
# 2     P2           소형 사무실을 위한 화상회의 장비 관리 서비스  SELECTED          0.9145
# 3     P3          소형 사무실 화상회의 장비 대여 및 교육 서비스  SELECTED          0.7223
# 4     P4       소형 사무실 화상회의 장비 대여 및 기술 지원 서비스  SELECTED          0.6423
# 5     P6      소형 사무실 화상회의 장비 대여 및 데이터 분석 서비스   RESERVE          0.8023
#
#                                      selectionReason relationToPortfolio  \
# 0        Opportunity fit과 Concept clarity가 가장 높은 대표안      PORTFOLIO_SEED
# 1                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 2                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 3                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 4                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 5  Selected Portfolio 대비 marginal value가 낮아 reser...    DISTINCT,VARIANT
#
#    Concept Family          Target Thesis                      Use Context  \
# 0   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 1  전문가 자문 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 2   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 3   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 4   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 5   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
#
#                                         Value Thesis  \
# 0  정기 대여를 통해 소형 사무실이 부담 없이 최신 화상회의 장비를 이용할 수 있도록 ...
# 1         고객의 요구에 맞춘 맞춤형 솔루션을 제공하여 화상회의의 효율성을 극대화한다.
# 2  장비 관리와 유지보수를 통해 소형 사무실이 안정적으로 화상회의를 진행할 수 있도록 ...
# 3  장비 대여와 함께 사용 교육을 제공하여 고객이 장비를 효과적으로 활용할 수 있도록 ...
# 4  장비 대여와 함께 기술 지원을 제공하여 고객이 문제를 신속하게 해결할 수 있도록 지...
# 5          장비 대여와 함께 화상회의 데이터를 분석하여 고객의 회의 효율성을 높인다.
#
#                                         Offer Thesis  \
# 0  소형 사무실 운영자는 고가의 장비를 구매하지 않고도 필요한 장비를 정기적으로 대여하...
# 1        소형 사무실 운영자는 맞춤형 솔루션을 통해 화상회의 환경을 최적화할 수 있다.
# 2        소형 사무실 운영자는 장비 관리에 대한 부담을 덜고, 본업에 집중할 수 있다.
# 3  소형 사무실 운영자는 장비 사용에 대한 교육을 통해 화상회의의 효율성을 극대화할 수...
# 4  소형 사무실 운영자는 기술 지원을 통해 장비 사용 중 발생하는 문제를 즉시 해결할 ...
# 5           소형 사무실 운영자는 데이터 분석을 통해 회의의 질을 향상시킬 수 있다.
#
#                                      Solution Thesis  \
# 0  정기 대여 서비스와 고장 시 즉각적인 교체 및 회수 서비스를 통해 소형 사무실의 운...
# 1          대여 서비스와 맞춤형 솔루션을 결합하여 고객의 화상회의 경험을 향상시킨다.
# 2         전문적인 장비 관리 서비스를 통해 소형 사무실의 화상회의 환경을 최적화한다.
# 3            장비 대여와 교육 서비스를 결합하여 고객의 화상회의 경험을 향상시킨다.
# 4       대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.
# 5       대여 서비스와 데이터 분석 서비스를 결합하여 고객의 화상회의 경험을 향상시킨다.
#
#                                         Architecture  \
# 0  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 1  {'businessRole': 'ADVISORY', 'operatingModel':...
# 2  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 3  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 4  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 5  {'businessRole': 'OTHER', 'operatingModel': 'O...
#
#                                                비교 가치
# 0  소형 사무실의 화상회의 장비 운영 부담을 덜어주기 위한 서비스로, 시장의 수요에 부...
# 1   소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 성과를 높이는 서비스이다.
# 2  소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 효율성을 높이는 서비스이다.
# 3  소형 사무실의 화상회의 장비 사용을 최적화하여 고객의 비즈니스 성과를 높이는 서비스이다.
# 4  소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 효율성을 높이는 서비스이다.
# 5   소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 성과를 높이는 서비스이다.

# %% [markdown]
# ## 16. Plan Lock/Intent Validation

# %%
display({'accepted': [p.planId for p in plan_validation.acceptedPlans] if plan_validation else [],
         'rejected': [p.model_dump(mode='json') for p in plan_validation.rejectedPlans]
                     if plan_validation else []})
# Out:
# {'accepted': ['P1', 'P5', 'P2', 'P3', 'P4'], 'rejected': []}

# %% [markdown]
# ## 17. Portfolio Family / Variant / Distinct

# %%
display(show_plan_diversity(plan_validation.diversity) if plan_validation else {'status': 'SKIPPED'})
# Out:
#      A   B        판정        Family A        Family B  \
# 0   P1  P2  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 1   P1  P3  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 2   P2  P3  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 3   P1  P4  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 4   P2  P4  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 5   P3  P4  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 6   P1  P5  DISTINCT     OTHER:OTHER  ADVISORY:OTHER
# 7   P2  P5  DISTINCT     OTHER:OTHER  ADVISORY:OTHER
# 8   P3  P5   VARIANT     OTHER:OTHER  ADVISORY:OTHER
# 9   P4  P5   VARIANT     OTHER:OTHER  ADVISORY:OTHER
# 10  P1  P6  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 11  P2  P6  DISTINCT     OTHER:OTHER     OTHER:OTHER
# 12  P3  P6   VARIANT     OTHER:OTHER     OTHER:OTHER
# 13  P4  P6   VARIANT     OTHER:OTHER     OTHER:OTHER
# 14  P5  P6   VARIANT  ADVISORY:OTHER     OTHER:OTHER
#
#                                                    겹침  \
# 0   businessRole, operatingModel, partnerModel, de...
# 1   businessRole, operatingModel, partnerModel, de...
# 2   businessRole, operatingModel, partnerModel, de...
# 3   businessRole, operatingModel, partnerModel, de...
# 4   businessRole, operatingModel, partnerModel, de...
# 5   businessRole, operatingModel, partnerModel, de...
# 6   operatingModel, partnerModel, deliveryModel, t...
# 7   operatingModel, partnerModel, deliveryModel, m...
# 8   operatingModel, partnerModel, deliveryModel, t...
# 9   operatingModel, partnerModel, deliveryModel, t...
# 10  businessRole, operatingModel, partnerModel, de...
# 11  businessRole, operatingModel, partnerModel, de...
# 12  businessRole, operatingModel, partnerModel, de...
# 13  businessRole, operatingModel, partnerModel, de...
# 14  operatingModel, partnerModel, deliveryModel, t...
#
#                                                 실질 차이  \
# 0   transactionModel, monetizationModel, valueProp...
# 1   monetizationModel, valuePropositionThesis, off...
# 2   transactionModel, valuePropositionThesis, offe...
# 3   monetizationModel, valuePropositionThesis, off...
# 4   transactionModel, valuePropositionThesis, offe...
# 5   valuePropositionThesis, offerThesis, solutionT...
# 6   businessRole, monetizationModel, customerInter...
# 7   businessRole, transactionModel, customerIntera...
# 8   businessRole, customerInteractionModel, valueP...
# 9   businessRole, customerInteractionModel, valueP...
# 10  monetizationModel, valuePropositionThesis, off...
# 11  transactionModel, valuePropositionThesis, offe...
# 12  valuePropositionThesis, offerThesis, solutionT...
# 13  valuePropositionThesis, offerThesis, solutionT...
# 14  businessRole, customerInteractionModel, valueP...
#
#                            단계  semantic judge  \
# 0     PRIMARY_BUSINESS_CHOICE           False
# 1     PRIMARY_BUSINESS_CHOICE           False
# 2     PRIMARY_BUSINESS_CHOICE           False
# 3     PRIMARY_BUSINESS_CHOICE           False
# 4     PRIMARY_BUSINESS_CHOICE           False
# 5     PRIMARY_BUSINESS_CHOICE           False
# 6     PRIMARY_BUSINESS_CHOICE           False
# 7     PRIMARY_BUSINESS_CHOICE           False
# 8   MEANINGFUL_THESIS_VARIANT           False
# 9   MEANINGFUL_THESIS_VARIANT           False
# 10    PRIMARY_BUSINESS_CHOICE           False
# 11    PRIMARY_BUSINESS_CHOICE           False
# 12  MEANINGFUL_THESIS_VARIANT           False
# 13  MEANINGFUL_THESIS_VARIANT           False
# 14  MEANINGFUL_THESIS_VARIANT           False
#
#                                                 관계 설명
# 0   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 1   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 2   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 3   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 4   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 5   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 6   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 7   핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 8   Architecture family는 유사하지만 target/use case/val...
# 9   Architecture family는 유사하지만 target/use case/val...
# 10  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 11  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 12  Architecture family는 유사하지만 target/use case/val...
# 13  Architecture family는 유사하지만 target/use case/val...
# 14  Architecture family는 유사하지만 target/use case/val...

# %% [markdown]
# ## 18. Selected + Reserve Plans

# %%
selected_plans = plan_validation.acceptedPlans if plan_validation else []
reserve_plans = plan_validation.reservePlans if plan_validation else []
display(show_portfolio_plans(selected_plans + reserve_plans))
display({'selected': [p.planId for p in selected_plans], 'reserve': [p.planId for p in reserve_plans]})
# Out:
#   planId                                  제목     선택 상태  selectionScore  \
# 0     P1               소형 사무실 화상회의 장비 대여 서비스  SELECTED          0.9145
# 1     P5  소형 사무실 화상회의 장비 대여 및 맞춤형 솔루션 제공 서비스  SELECTED          0.9573
# 2     P2           소형 사무실을 위한 화상회의 장비 관리 서비스  SELECTED          0.9145
# 3     P3          소형 사무실 화상회의 장비 대여 및 교육 서비스  SELECTED          0.7223
# 4     P4       소형 사무실 화상회의 장비 대여 및 기술 지원 서비스  SELECTED          0.6423
# 5     P6      소형 사무실 화상회의 장비 대여 및 데이터 분석 서비스   RESERVE          0.8023
#
#                                      selectionReason relationToPortfolio  \
# 0        Opportunity fit과 Concept clarity가 가장 높은 대표안      PORTFOLIO_SEED
# 1                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 2                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 3                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 4                  현재 Portfolio에 주요 사업 선택의 비교 범위를 추가            DISTINCT
# 5  Selected Portfolio 대비 marginal value가 낮아 reser...    DISTINCT,VARIANT
#
#    Concept Family          Target Thesis                      Use Context  \
# 0   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 1  전문가 자문 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 2   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 3   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 4   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
# 5   기타 역할 · 기타 운영  10~50인 규모의 소형 사무실 운영자  소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황
#
#                                         Value Thesis  \
# 0  정기 대여를 통해 소형 사무실이 부담 없이 최신 화상회의 장비를 이용할 수 있도록 ...
# 1         고객의 요구에 맞춘 맞춤형 솔루션을 제공하여 화상회의의 효율성을 극대화한다.
# 2  장비 관리와 유지보수를 통해 소형 사무실이 안정적으로 화상회의를 진행할 수 있도록 ...
# 3  장비 대여와 함께 사용 교육을 제공하여 고객이 장비를 효과적으로 활용할 수 있도록 ...
# 4  장비 대여와 함께 기술 지원을 제공하여 고객이 문제를 신속하게 해결할 수 있도록 지...
# 5          장비 대여와 함께 화상회의 데이터를 분석하여 고객의 회의 효율성을 높인다.
#
#                                         Offer Thesis  \
# 0  소형 사무실 운영자는 고가의 장비를 구매하지 않고도 필요한 장비를 정기적으로 대여하...
# 1        소형 사무실 운영자는 맞춤형 솔루션을 통해 화상회의 환경을 최적화할 수 있다.
# 2        소형 사무실 운영자는 장비 관리에 대한 부담을 덜고, 본업에 집중할 수 있다.
# 3  소형 사무실 운영자는 장비 사용에 대한 교육을 통해 화상회의의 효율성을 극대화할 수...
# 4  소형 사무실 운영자는 기술 지원을 통해 장비 사용 중 발생하는 문제를 즉시 해결할 ...
# 5           소형 사무실 운영자는 데이터 분석을 통해 회의의 질을 향상시킬 수 있다.
#
#                                      Solution Thesis  \
# 0  정기 대여 서비스와 고장 시 즉각적인 교체 및 회수 서비스를 통해 소형 사무실의 운...
# 1          대여 서비스와 맞춤형 솔루션을 결합하여 고객의 화상회의 경험을 향상시킨다.
# 2         전문적인 장비 관리 서비스를 통해 소형 사무실의 화상회의 환경을 최적화한다.
# 3            장비 대여와 교육 서비스를 결합하여 고객의 화상회의 경험을 향상시킨다.
# 4       대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.
# 5       대여 서비스와 데이터 분석 서비스를 결합하여 고객의 화상회의 경험을 향상시킨다.
#
#                                         Architecture  \
# 0  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 1  {'businessRole': 'ADVISORY', 'operatingModel':...
# 2  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 3  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 4  {'businessRole': 'OTHER', 'operatingModel': 'O...
# 5  {'businessRole': 'OTHER', 'operatingModel': 'O...
#
#                                                비교 가치
# 0  소형 사무실의 화상회의 장비 운영 부담을 덜어주기 위한 서비스로, 시장의 수요에 부...
# 1   소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 성과를 높이는 서비스이다.
# 2  소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 효율성을 높이는 서비스이다.
# 3  소형 사무실의 화상회의 장비 사용을 최적화하여 고객의 비즈니스 성과를 높이는 서비스이다.
# 4  소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 효율성을 높이는 서비스이다.
# 5   소형 사무실의 화상회의 장비 운영을 지원하여 고객의 비즈니스 성과를 높이는 서비스이다.
# {'selected': ['P1', 'P5', 'P2', 'P3', 'P4'], 'reserve': ['P6']}

# %% [markdown]
# ## 19. Candidate 1

# %%
candidate_one = (await engine.expand_plan(seed, selected_plans[0], 1)
                 if RUN_STAGED_CORE and selected_plans else None)
display(show_candidates([candidate_one]) if candidate_one else [])
# Out:
#   candidateId lineageId parentCandidateId                     이름  \
# 0          C1        L1              None  소형 사무실 화상회의 장비 대여 서비스
#
#                                              핵심 작동방식         family  \
# 0  정기 대여 서비스와 고장 시 즉각적인 교체 및 회수 서비스를 통해 소형 사무실의 운...  거래 중개 · 기타 운영
#
#                                           descriptor                  수익  \
# 0  {'thesis': {'targetSegmentThesis': '10~50인 규모의...  구독 모델을 통한 정기 수익 창출
#
#                                         운영
# 0  고객의 요구에 맞춘 맞춤형 서비스 제공을 위해 고객 관리팀을 운영한다.

# %% [markdown]
# ## 20. Candidate 1 Korean/Governance

# %%
candidate_one_reports = []
display({'candidateId': candidate_one.candidateId if candidate_one else None,
         'status': 'PENDING_FULL_CANDIDATE_RECOVERY'})
# Out:
# {'candidateId': 'C1', 'status': 'PENDING_FULL_CANDIDATE_RECOVERY'}

# %% [markdown]
# ## 21. Candidate 1 Actual Generic Descriptor

# %%
display(show_concept_descriptors([candidate_one]) if candidate_one else [])
# Out:
#   entityId              family                 dimension             code  \
# 0       C1  INTERMEDIARY:OTHER              businessRole     INTERMEDIARY
# 1       C1  INTERMEDIARY:OTHER            operatingModel            OTHER
# 2       C1  INTERMEDIARY:OTHER              partnerModel  PARTNER_NETWORK
# 3       C1  INTERMEDIARY:OTHER             deliveryModel            OTHER
# 4       C1  INTERMEDIARY:OTHER          transactionModel        RECURRING
# 5       C1  INTERMEDIARY:OTHER         monetizationModel     SUBSCRIPTION
# 6       C1  INTERMEDIARY:OTHER  customerInteractionModel            OTHER
# 7       C1  INTERMEDIARY:OTHER            dataDependency             NONE
# 8       C1  INTERMEDIARY:OTHER        physicalDependency         MATERIAL
#
#   confidence   source
# 0       HIGH     RULE
# 1        LOW  UNKNOWN
# 2       HIGH     RULE
# 3        LOW  UNKNOWN
# 4       HIGH     RULE
# 5       HIGH     RULE
# 6        LOW  UNKNOWN
# 7        NaN      NaN
# 8        NaN      NaN

# %% [markdown]
# ## 22. Candidate 1 Fidelity

# %%
display({'candidateId': candidate_one.candidateId if candidate_one else None,
         'fidelity': '전체 Candidate Recovery 단계에서 semantic fallback 포함 검증'})
# Out:
# {'candidateId': 'C1',
#  'fidelity': '전체 Candidate Recovery 단계에서 semantic fallback 포함 검증'}

# %% [markdown]
# ## 23. Remaining Candidates

# %%
remaining_candidates = []
if RUN_STAGED_CORE:
    for i, plan in enumerate(selected_plans[1:], 2):
        remaining_candidates.append(await engine.expand_plan(seed, plan, i))
candidate_drafts = ([candidate_one] if candidate_one else []) + remaining_candidates
display(show_candidates(candidate_drafts))
# Out:
#   candidateId lineageId parentCandidateId                                  이름  \
# 0          C1        L1              None               소형 사무실 화상회의 장비 대여 서비스
# 1          C2        L2              None  소형 사무실 화상회의 장비 대여 및 맞춤형 솔루션 제공 서비스
# 2          C3        L3              None           소형 사무실을 위한 화상회의 장비 관리 서비스
# 3          C4        L4              None          소형 사무실 화상회의 장비 대여 및 교육 서비스
# 4          C5        L5              None       소형 사무실 화상회의 장비 대여 및 기술 지원 서비스
#
#                                              핵심 작동방식         family  \
# 0  정기 대여 서비스와 고장 시 즉각적인 교체 및 회수 서비스를 통해 소형 사무실의 운...  거래 중개 · 기타 운영
# 1          대여 서비스와 맞춤형 솔루션을 결합하여 고객의 화상회의 경험을 향상시킨다.  기타 역할 · 기타 운영
# 2            정기적인 점검 및 유지보수를 통해 고객의 장비를 안정적으로 관리합니다.  기타 역할 · 기타 운영
# 3           장비 대여와 교육 서비스를 결합하여 고객의 화상회의 경험을 향상시킵니다.  거래 중개 · 기타 운영
# 4       대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.  기타 역할 · 기타 운영
#
#                                           descriptor  \
# 0  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
# 1  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
# 2  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
# 3  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
# 4  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
#
#                                   수익  \
# 0                 구독 모델을 통한 정기 수익 창출
# 1                       구독 기반 대여 서비스
# 2  구독 기반 모델로, 월정액 요금제를 통해 수익을 창출합니다.
# 3         구독 기반 모델로, 월별 또는 연별 요금제 제공
# 4                        구독 기반 수익 모델
#
#                                              운영
# 0       고객의 요구에 맞춘 맞춤형 서비스 제공을 위해 고객 관리팀을 운영한다.
# 1             고객 맞춤형 솔루션을 제공하기 위해 전문 상담팀을 운영한다.
# 2  전문 기술 인력을 통해 고객의 장비를 관리하고, 신속한 대응 체계를 구축합니다.
# 3   전문 강사를 통해 고객에게 장비 사용법을 교육하고, 지속적인 지원을 제공한다.
# 4           전문 기술 지원 팀을 운영하여 고객의 문제를 신속하게 해결한다.

# %% [markdown]
# ## 24. Candidate Actual Generic Descriptors

# %%
display(show_concept_descriptors(candidate_drafts))
# Out:
#    entityId              family                 dimension             code  \
# 0        C1  INTERMEDIARY:OTHER              businessRole     INTERMEDIARY
# 1        C1  INTERMEDIARY:OTHER            operatingModel            OTHER
# 2        C1  INTERMEDIARY:OTHER              partnerModel  PARTNER_NETWORK
# 3        C1  INTERMEDIARY:OTHER             deliveryModel            OTHER
# 4        C1  INTERMEDIARY:OTHER          transactionModel        RECURRING
# 5        C1  INTERMEDIARY:OTHER         monetizationModel     SUBSCRIPTION
# 6        C1  INTERMEDIARY:OTHER  customerInteractionModel            OTHER
# 7        C1  INTERMEDIARY:OTHER            dataDependency             NONE
# 8        C1  INTERMEDIARY:OTHER        physicalDependency         MATERIAL
# 9        C2         OTHER:OTHER              businessRole            OTHER
# 10       C2         OTHER:OTHER            operatingModel            OTHER
# 11       C2         OTHER:OTHER              partnerModel  PARTNER_NETWORK
# 12       C2         OTHER:OTHER             deliveryModel            OTHER
# 13       C2         OTHER:OTHER          transactionModel        RECURRING
# 14       C2         OTHER:OTHER         monetizationModel     SUBSCRIPTION
# 15       C2         OTHER:OTHER  customerInteractionModel         ASSISTED
# 16       C2         OTHER:OTHER            dataDependency             NONE
# 17       C2         OTHER:OTHER        physicalDependency         MATERIAL
# 18       C3         OTHER:OTHER              businessRole            OTHER
# 19       C3         OTHER:OTHER            operatingModel            OTHER
# 20       C3         OTHER:OTHER              partnerModel  PARTNER_NETWORK
# 21       C3         OTHER:OTHER             deliveryModel            OTHER
# 22       C3         OTHER:OTHER          transactionModel        RECURRING
# 23       C3         OTHER:OTHER         monetizationModel     SUBSCRIPTION
# 24       C3         OTHER:OTHER  customerInteractionModel            OTHER
# 25       C3         OTHER:OTHER            dataDependency             NONE
# 26       C3         OTHER:OTHER        physicalDependency         MATERIAL
# 27       C4  INTERMEDIARY:OTHER              businessRole     INTERMEDIARY
# 28       C4  INTERMEDIARY:OTHER            operatingModel            OTHER
# 29       C4  INTERMEDIARY:OTHER              partnerModel  PARTNER_NETWORK
# 30       C4  INTERMEDIARY:OTHER             deliveryModel            OTHER
# 31       C4  INTERMEDIARY:OTHER          transactionModel            OTHER
# 32       C4  INTERMEDIARY:OTHER         monetizationModel     SUBSCRIPTION
# 33       C4  INTERMEDIARY:OTHER  customerInteractionModel            OTHER
# 34       C4  INTERMEDIARY:OTHER            dataDependency             NONE
# 35       C4  INTERMEDIARY:OTHER        physicalDependency         MATERIAL
# 36       C5         OTHER:OTHER              businessRole            OTHER
# 37       C5         OTHER:OTHER            operatingModel            OTHER
# 38       C5         OTHER:OTHER              partnerModel  PARTNER_NETWORK
# 39       C5         OTHER:OTHER             deliveryModel            OTHER
# 40       C5         OTHER:OTHER          transactionModel            OTHER
# 41       C5         OTHER:OTHER         monetizationModel     SUBSCRIPTION
# 42       C5         OTHER:OTHER  customerInteractionModel            OTHER
# 43       C5         OTHER:OTHER            dataDependency             NONE
# 44       C5         OTHER:OTHER        physicalDependency         MATERIAL
#
#    confidence   source
# 0        HIGH     RULE
# 1         LOW  UNKNOWN
# 2        HIGH     RULE
# 3         LOW  UNKNOWN
# 4        HIGH     RULE
# 5        HIGH     RULE
# 6         LOW  UNKNOWN
# 7         NaN      NaN
# 8         NaN      NaN
# 9         LOW  UNKNOWN
# 10        LOW  UNKNOWN
# 11       HIGH     RULE
# 12        LOW  UNKNOWN
# 13       HIGH     RULE
# 14       HIGH     RULE
# 15       HIGH     RULE
# 16        NaN      NaN
# 17        NaN      NaN
# 18        LOW  UNKNOWN
# 19        LOW  UNKNOWN
# 20       HIGH     RULE
# 21        LOW  UNKNOWN
# 22       HIGH     RULE
# 23       HIGH     RULE
# 24        LOW  UNKNOWN
# 25        NaN      NaN
# 26        NaN      NaN
# 27       HIGH     RULE
# 28        LOW  UNKNOWN
# 29       HIGH     RULE
# 30        LOW  UNKNOWN
# 31        LOW  UNKNOWN
# 32       HIGH     RULE
# 33        LOW  UNKNOWN
# 34        NaN      NaN
# 35        NaN      NaN
# 36        LOW  UNKNOWN
# 37        LOW  UNKNOWN
# 38       HIGH     RULE
# 39        LOW  UNKNOWN
# 40        LOW  UNKNOWN
# 41       HIGH     RULE
# 42        LOW  UNKNOWN
# 43        NaN      NaN
# 44        NaN      NaN

# %% [markdown]
# ## 25. Candidate Recovery / Portfolio Relations

# %%
candidate_preparation = (await engine.prepare_candidate_portfolio(
    seed, plan_validation, max_concepts=MAX_CONCEPTS, initial_candidates=candidate_drafts)
    if RUN_STAGED_CORE and plan_validation else None)
candidates = candidate_preparation.candidates if candidate_preparation else []
candidate_reports = candidate_preparation.reports if candidate_preparation else []
display(show_candidate_recovery(candidate_preparation) if candidate_preparation else {'status': 'SKIPPED'})
candidate_pairwise = [engine.compare_candidates(candidates[i], candidates[j])
                      for i in range(len(candidates)) for j in range(i + 1, len(candidates))]
display(show_plan_diversity(candidate_pairwise))
# Out:
# {'summary':    candidateGenerated  candidateAcceptedInitially  candidateRegenerated  \
#  0                   5                           5                     0
#
#     candidateRecovered  reservePlansActivated  candidateRecoveryReplans  \
#  0                   0                      0                         0
#
#     finalCandidatePortfolio
#  0                        5  ,
#  'attempts':   candidateId  schemaValid  hardLockPreserved  semanticAnchorPreserved  \
#  0          C1         True               True                     True
#  1          C2         True               True                     True
#  2          C3         True               True                     True
#  3          C4         True               True                     True
#  4          C5         True               True                     True
#
#     planFidelity anchorDecision fidelityDecision  contentLanguageValid  \
#  0          True           PASS          ADAPTED                  True
#  1          True           PASS          ADAPTED                  True
#  2          True           PASS             PASS                  True
#  3          True           PASS          ADAPTED                  True
#  4          True           PASS          ADAPTED                  True
#
#     accepted   outcome  semanticFidelityUsed  \
#  0      True  ACCEPTED                 False
#  1      True  ACCEPTED                 False
#  2      True  ACCEPTED                  True
#  3      True  ACCEPTED                 False
#  4      True  ACCEPTED                 False
#
#                             matchedIdentityComponents  \
#  0  [targetSegmentThesis, valuePropositionThesis, ...
#  1  [targetSegmentThesis, valuePropositionThesis, ...
#  2  [전문 기술 인력에 의한 맞춤형 관리 서비스 제공, 고객 맞춤형 유지보수 계획 수립...
#  3  [targetSegmentThesis, valuePropositionThesis, ...
#  4  [targetSegmentThesis, valuePropositionThesis, ...
#
#        missingIdentityComponents reasonCodes safeSummary
#  0  [useCaseThesis, offerThesis]          []       검사 통과
#  1  [useCaseThesis, offerThesis]          []       검사 통과
#  2                            []          []       검사 통과
#  3  [useCaseThesis, offerThesis]          []       검사 통과
#  4  [useCaseThesis, offerThesis]          []       검사 통과  ,
#  'finalCandidates':   candidateId lineageId parentCandidateId                                  이름  \
#  0          C1        L1              None               소형 사무실 화상회의 장비 대여 서비스
#  1          C2        L2              None  소형 사무실 화상회의 장비 대여 및 맞춤형 솔루션 제공 서비스
#  2          C3        L3              None           소형 사무실을 위한 화상회의 장비 관리 서비스
#  3          C4        L4              None          소형 사무실 화상회의 장비 대여 및 교육 서비스
#  4          C5        L5              None       소형 사무실 화상회의 장비 대여 및 기술 지원 서비스
#
#                                               핵심 작동방식         family  \
#  0  정기 대여 서비스와 고장 시 즉각적인 교체 및 회수 서비스를 통해 소형 사무실의 운...  거래 중개 · 기타 운영
#  1          대여 서비스와 맞춤형 솔루션을 결합하여 고객의 화상회의 경험을 향상시킨다.  기타 역할 · 기타 운영
#  2            정기적인 점검 및 유지보수를 통해 고객의 장비를 안정적으로 관리합니다.  기타 역할 · 기타 운영
#  3           장비 대여와 교육 서비스를 결합하여 고객의 화상회의 경험을 향상시킵니다.  거래 중개 · 기타 운영
#  4       대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.  기타 역할 · 기타 운영
#
#                                            descriptor  \
#  0  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
#  1  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
#  2  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
#  3  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
#  4  {'thesis': {'targetSegmentThesis': '10~50인 규모의...
#
#                                    수익  \
#  0                 구독 모델을 통한 정기 수익 창출
#  1                       구독 기반 대여 서비스
#  2  구독 기반 모델로, 월정액 요금제를 통해 수익을 창출합니다.
#  3         구독 기반 모델로, 월별 또는 연별 요금제 제공
#  4                        구독 기반 수익 모델
#
#                                               운영
#  0       고객의 요구에 맞춘 맞춤형 서비스 제공을 위해 고객 관리팀을 운영한다.
#  1             고객 맞춤형 솔루션을 제공하기 위해 전문 상담팀을 운영한다.
#  2  전문 기술 인력을 통해 고객의 장비를 관리하고, 신속한 대응 체계를 구축합니다.
#  3   전문 강사를 통해 고객에게 장비 사용법을 교육하고, 지속적인 지원을 제공한다.
#  4           전문 기술 지원 팀을 운영하여 고객의 문제를 신속하게 해결한다.  }
#     A   B        판정            Family A            Family B  \
# 0  C1  C2  DISTINCT  INTERMEDIARY:OTHER         OTHER:OTHER
# 1  C1  C3  DISTINCT  INTERMEDIARY:OTHER         OTHER:OTHER
# 2  C1  C4  DISTINCT  INTERMEDIARY:OTHER  INTERMEDIARY:OTHER
# 3  C1  C5  DISTINCT  INTERMEDIARY:OTHER         OTHER:OTHER
# 4  C2  C3  DISTINCT         OTHER:OTHER         OTHER:OTHER
# 5  C2  C4  DISTINCT         OTHER:OTHER  INTERMEDIARY:OTHER
# 6  C2  C5   VARIANT         OTHER:OTHER         OTHER:OTHER
# 7  C3  C4  DISTINCT         OTHER:OTHER  INTERMEDIARY:OTHER
# 8  C3  C5  DISTINCT         OTHER:OTHER         OTHER:OTHER
# 9  C4  C5  DISTINCT  INTERMEDIARY:OTHER         OTHER:OTHER
#
#                                                   겹침  \
# 0  operatingModel, partnerModel, deliveryModel, t...
# 1  operatingModel, partnerModel, deliveryModel, t...
# 2  businessRole, operatingModel, partnerModel, de...
# 3  operatingModel, partnerModel, deliveryModel, m...
# 4  businessRole, operatingModel, partnerModel, de...
# 5  operatingModel, partnerModel, deliveryModel, m...
# 6  businessRole, operatingModel, partnerModel, de...
# 7  operatingModel, partnerModel, deliveryModel, m...
# 8  businessRole, operatingModel, partnerModel, de...
# 9  operatingModel, partnerModel, deliveryModel, t...
#
#                                                실질 차이  \
# 0  businessRole, customerInteractionModel, valueP...
# 1  businessRole, valuePropositionThesis, offerThe...
# 2  transactionModel, valuePropositionThesis, offe...
# 3  businessRole, transactionModel, valuePropositi...
# 4  customerInteractionModel, valuePropositionThes...
# 5  businessRole, transactionModel, customerIntera...
# 6  transactionModel, customerInteractionModel, va...
# 7  businessRole, transactionModel, valuePropositi...
# 8  transactionModel, valuePropositionThesis, offe...
# 9  businessRole, valuePropositionThesis, offerThe...
#
#                           단계  semantic judge  \
# 0    PRIMARY_BUSINESS_CHOICE           False
# 1    PRIMARY_BUSINESS_CHOICE           False
# 2    PRIMARY_BUSINESS_CHOICE           False
# 3    PRIMARY_BUSINESS_CHOICE           False
# 4    PRIMARY_BUSINESS_CHOICE           False
# 5    PRIMARY_BUSINESS_CHOICE           False
# 6  MEANINGFUL_THESIS_VARIANT           False
# 7    PRIMARY_BUSINESS_CHOICE           False
# 8    PRIMARY_BUSINESS_CHOICE           False
# 9    PRIMARY_BUSINESS_CHOICE           False
#
#                                                관계 설명
# 0  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 1  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 2  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 3  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 4  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 5  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 6  Architecture family는 유사하지만 target/use case/val...
# 7  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 8  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.
# 9  핵심 solution 또는 주요 Business Architecture 선택이 다릅니다.

# %% [markdown]
# ## 26. Legal Fact Completeness + Business Design Completion + C1 Fact Pattern

# %%
prechecks = [engine.legal_precheck(item) for item in candidates] if RUN_STAGED_LEGAL else []
display(show_legal_precheck(prechecks))
legal_preparation = (await engine.prepare_legal_candidates(seed, candidates)
                     if RUN_STAGED_LEGAL and candidates else None)
candidates_before_legal = candidates
candidates = legal_preparation.candidates if legal_preparation else candidates
display({'factCompleteness': [item.model_dump(mode='json') for item in legal_preparation.reports]
                              if legal_preparation else [],
         'roleSemanticBatchCalls': legal_preparation.roleSemanticBatchCalls if legal_preparation else 0,
         'dependencySemanticBatchCalls': legal_preparation.dependencySemanticBatchCalls if legal_preparation else 0,
         'completionAttempted': legal_preparation.completionAttempted if legal_preparation else 0,
         'completionValidated': legal_preparation.completionValidated if legal_preparation else 0,
         'completionAccepted': legal_preparation.completionAccepted if legal_preparation else 0,
         'completionExhausted': legal_preparation.completionExhausted if legal_preparation else 0,
         'completionCompliance': [item.model_dump(mode='json') for item in legal_preparation.completionCompliance] if legal_preparation else [],
         'factConsistency': [item.model_dump(mode='json') for item in legal_preparation.consistencyReports] if legal_preparation else [],
         'consistencyRepairAttempted': legal_preparation.consistencyRepairAttempted if legal_preparation else 0,
         'consistencyRepairAccepted': legal_preparation.consistencyRepairAccepted if legal_preparation else 0,
         'consistencyRepairExhausted': legal_preparation.consistencyRepairExhausted if legal_preparation else 0,
         'preLegalExclusions': legal_preparation.excludedCandidates if legal_preparation else []})
display(show_legal_fact_pattern(candidates[0].candidate, seed) if candidates else [])
# Out:
#   candidateId                                              label  \
# 0          C1  Structural risk precheck — not final legal review
# 1          C2  Structural risk precheck — not final legal review
# 2          C3  Structural risk precheck — not final legal review
# 3          C4  Structural risk precheck — not final legal review
# 4          C5  Structural risk precheck — not final legal review
#
#    directSeller  intermediary  regulatedPhysicalActivity  \
# 0          True          True                       True
# 1          True         False                       True
# 2          True         False                       True
# 3          True          True                       True
# 4          True         False                       True
#
#    personalDataDependency  qualificationDependency riskHints
# 0                   False                    False   [물리 활동]
# 1                   False                    False   [물리 활동]
# 2                   False                    False   [물리 활동]
# 3                   False                    False   [물리 활동]
# 4                   False                    False   [물리 활동]
# {'factCompleteness': [{'candidateId': 'C1',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'NOT_REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'NOT_REQUIRED',
#      'safeReason': '데이터 비의존 구조이며 개인 단위 처리 신호가 없습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'CONSISTENT',
#     'businessRole': 'INTERMEDIARY',
#     'confidence': 'HIGH',
#     'safeReason': '고신뢰 architecture와 Candidate의 중개 역할이 일치합니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C2',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'EXPLICIT_ABSENCE',
#      'presence': 'EXPLICIT_ABSENCE',
#      'deterministicStatus': 'EXPLICIT_ABSENCE',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'EXPLICIT_ABSENCE',
#      'safeReason': '역할이 명시적으로 존재하지 않습니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'NOT_REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'NOT_REQUIRED',
#      'safeReason': '데이터 비의존 구조이며 개인 단위 처리 신호가 없습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'OTHER',
#     'confidence': 'LOW',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C3-FC1',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'EXPLICIT_ABSENCE',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'EXPLICIT_ABSENCE',
#      'finalStatus': 'EXPLICIT_ABSENCE',
#      'safeReason': '역할이 명시적으로 존재하지 않습니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticDecision': 'NOT_REQUIRED',
#      'finalDecision': 'NOT_REQUIRED',
#      'safeReason': '사업 사실에 개인 데이터 사용이 명시되어 있지 않음.',
#      'consistencyStatus': 'POTENTIAL_CONFLICT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'CONSISTENT',
#     'businessRole': 'PLATFORM_INFRASTRUCTURE',
#     'confidence': 'HIGH',
#     'safeReason': '비중개형 고신뢰 architecture와 명시적 중개 부재가 일치합니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C4',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'NOT_REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'NOT_REQUIRED',
#      'safeReason': '데이터 비의존 구조이며 개인 단위 처리 신호가 없습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'CONSISTENT',
#     'businessRole': 'INTERMEDIARY',
#     'confidence': 'HIGH',
#     'safeReason': '고신뢰 architecture와 Candidate의 중개 역할이 일치합니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'},
#   {'candidateId': 'C5',
#    'status': 'COMPLETE',
#    'missingDesignFacts': [],
#    'contradictions': [],
#    'completionRequirements': [],
#    'affectedFields': [],
#    'roleSemantics': [{'field': 'platformRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'providerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'sellerRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'MATCH',
#      'semanticUsed': False,
#      'semanticStatus': 'NOT_RUN',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'},
#     {'field': 'intermediaryRole',
#      'status': 'MATCH',
#      'presence': 'PRESENT',
#      'deterministicStatus': 'AMBIGUOUS',
#      'semanticUsed': True,
#      'semanticStatus': 'MATCH',
#      'finalStatus': 'MATCH',
#      'safeReason': '역할 의미가 필드와 일치합니다.'}],
#    'dependencyAssessments': [{'candidateId': None,
#      'dependencyType': 'PERSONAL_DATA',
#      'deterministicDecision': 'NOT_REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'NOT_REQUIRED',
#      'safeReason': '데이터 비의존 구조이며 개인 단위 처리 신호가 없습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'PHYSICAL_ACTIVITY',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '배송·방문·설치 등 물리적 이행이 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'},
#     {'candidateId': None,
#      'dependencyType': 'BUSINESS_PARTNER',
#      'deterministicDecision': 'REQUIRED',
#      'semanticUsed': False,
#      'semanticDecision': 'NOT_RUN',
#      'finalDecision': 'REQUIRED',
#      'safeReason': '사업 이행에 필요한 외부 계약·운영 파트너가 명시되었습니다.',
#      'consistencyStatus': 'CONSISTENT'}],
#    'structuredCompletionRequirements': [],
#    'architectureRoleConsistency': {'status': 'NOT_ENOUGH_EVIDENCE',
#     'businessRole': 'OTHER',
#     'confidence': 'LOW',
#     'safeReason': '진단용 architecture confidence 또는 역할 근거가 충분하지 않습니다.'},
#    'safeSummary': '법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.'}],
#  'roleSemanticBatchCalls': 1,
#  'dependencySemanticBatchCalls': 1,
#  'completionAttempted': 0,
#  'completionValidated': 0,
#  'completionAccepted': 0,
#  'completionExhausted': 0,
#  'completionCompliance': [],
#  'factConsistency': [{'candidateId': 'C1',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C2',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C3',
#    'status': 'INVALID_FACT',
#    'issues': [{'field': 'intermediaryRole',
#      'relation': 'TRANSACTION_INTERMEDIARY',
#      'status': 'INVALID_FACT',
#      'safeReason': '중개 역할 필드에 파트너 협력 설명만 있고 거래 연결 책임이 없습니다.',
#      'repairInstruction': '실제 거래 방식에 맞춰 intermediaryRole의 중개 존재·부재만 정정합니다.'}],
#    'safeSummary': 'Legal 전에 정정해야 할 명백한 사업 사실 자기모순이 있습니다.'},
#   {'candidateId': 'C3-FC1',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C4',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'},
#   {'candidateId': 'C5',
#    'status': 'CONSISTENT',
#    'issues': [],
#    'safeSummary': '검사 대상 사업 사실 사이에 명백한 모순이 없습니다.'}],
#  'consistencyRepairAttempted': 1,
#  'consistencyRepairAccepted': 1,
#  'consistencyRepairExhausted': 0,
#  'preLegalExclusions': []}
#                         field  \
# 0                platformRole
# 1                providerRole
# 2                  sellerRole
# 3            intermediaryRole
# 4             transactionFlow
# 5                 paymentFlow
# 6           personalDataUsage
# 7          physicalActivities
# 8         partnerRequirements
# 9   qualificationRequirements
# 10          advertisingClaims
#
#                                             legalFact             source  \
# 0                                     온라인 플랫폼 운영 및 관리  CONCEPT_GENERATED
# 1                                 장비 공급 및 유지보수 서비스 제공  CONCEPT_GENERATED
# 2                                 장비 대여 계약 체결 및 고객 관리  CONCEPT_GENERATED
# 3                                고객과 장비 공급업체 간의 중개 역할  CONCEPT_GENERATED
# 4   [고객이 온라인 플랫폼에서 장비 대여 신청, 대여 계약 체결, 장비 배송 및 설치,...  CONCEPT_GENERATED
# 5            [고객이 온라인 결제를 통해 대여 계약 체결, 정기 결제 수취 및 정산]  CONCEPT_GENERATED
# 6                                                  []  CONCEPT_GENERATED
# 7                        [장비 배송, 장비 설치, 정기 점검 및 유지보수]  CONCEPT_GENERATED
# 8            [장비 공급업체와의 계약 체결, 유지보수 서비스 제공을 위한 인력 확보]  CONCEPT_GENERATED
# 9                                                  []  CONCEPT_GENERATED
# 10  [최신 화상회의 장비를 부담 없이 이용할 수 있습니다., 고장 시 즉각적인 교체 서...  CONCEPT_GENERATED
#
#      authority  decision
# 0   REVIEWABLE  PROPOSED
# 1   REVIEWABLE  PROPOSED
# 2   REVIEWABLE  PROPOSED
# 3   REVIEWABLE  PROPOSED
# 4   REVIEWABLE  PROPOSED
# 5   REVIEWABLE  PROPOSED
# 6   REVIEWABLE  PROPOSED
# 7   REVIEWABLE  PROPOSED
# 8   REVIEWABLE  PROPOSED
# 9   REVIEWABLE  PROPOSED
# 10  REVIEWABLE  PROPOSED

# %% [markdown]
# ## 27. Prepared Legal C1 Evidence Summary

# %%
legal_adapter = CurrentLegalAdapter() if RUN_STAGED_LEGAL else None
legal_c1_input = (legal_adapter.task_input(candidates[0].candidate, seed)
                  if legal_adapter and candidates else None)
display({'candidateId': candidates[0].candidateId if candidates else None,
         'externalFacts': legal_c1_input['externalFactContext']['facts'] if legal_c1_input else [],
         'note': '공식 근거 수와 allowed index는 Full Legal 응답/실패 diagnostics에서 확인'})
# Out:
# {'candidateId': 'C1',
#  'externalFacts': [],
#  'note': '공식 근거 수와 allowed index는 Full Legal 응답/실패 diagnostics에서 확인'}

# %% [markdown]
# ## 28. Full Evidence Judgment — C1 Staged Smoke

# %%
RUN_FULL_LEGAL_C1 = RUN_STAGED_LEGAL
legal_one = None
if RUN_FULL_LEGAL_C1 and candidates:
    try:
        legal_one = (await engine.review_legal(seed, candidates[:1]))[0]
        display(show_legal_result([legal_one]))
    except Exception:
        display(show_legal_failure(candidates[0].candidateId, engine.gateway))
else:
    print('SKIPPED — RUN_FULL_LEGAL_C1=True로 명시해야 실행됩니다.')
# Out:
#   candidateId        route productionStatus     sourceStatus evidenceCoverage  \
# 0          C1  NEEDS_INPUT     REDESIGNABLE  SOURCE_COMPLETE             None
#
#     reviewPhase factCompletenessStatus legalSourceStatus  \
# 0  LEGAL_SOURCE                   None   SOURCE_COMPLETE
#
#    finalEvidenceJudgmentExecuted                recoveryResolution  ...  \
# 0                          False  LEGAL_FACT_REQUIRED_NOT_REDESIGN  ...
#
#    legalClarificationCount                        safeSummary  \
# 0                        0  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.
#
#                                         unknownFacts  requiredControls  \
# 0  [장비의 종류 및 특성에 대한 정보가 필요합니다., 고객 관리팀의 운영 방식에 대한...                []
#
#    requiredPartnersAndQualifications  requiredDisclosures prohibitedVariants  \
# 0                                 []                   []                 []
#
#   evidenceCount                                       evidenceRefs  \
# 0            20  [{'referenceIndex': 0, 'sourceType': 'OFFICIAL...
#
#                                  evidenceDiagnostics
# 0  {'coverageStatus': 'SOURCE_COMPLETE', 'coverag...
#
# [1 rows x 25 columns]

# %% [markdown]
# ## 29. C1 Route + Staged Redesign/Compliance/Second Legal

# %%
c1_portfolio, c1_legal_all, c1_required_inputs, c1_redesigned, c1_replanned = ([], [], [], 0, 0)
if legal_one and candidates:
    c1_portfolio, c1_legal_all, c1_required_inputs, c1_redesigned, c1_replanned = await engine.resolve_legal(
        seed, candidate_preparation.usedPlans, candidates[:1], [legal_one])
display({'initialRoute': legal_one.route.value if legal_one else 'SKIPPED',
         'redesignRequirements': legal_one.redesignRequirements if legal_one else [],
         'recoveryReviews': [item.model_dump(mode='json') for item in c1_legal_all[1:]],
         'requiredInputs': c1_required_inputs, 'terminalCandidates': len(c1_portfolio),
         'redesigned': c1_redesigned, 'replanned': c1_replanned})
# Out:
# {'initialRoute': 'NEEDS_INPUT',
#  'redesignRequirements': ['장비의 종류 및 특성에 대한 정보가 필요합니다.',
#   '고객 관리팀의 운영 방식에 대한 구체적인 정보가 필요합니다.'],
#  'recoveryReviews': [],
#  'requiredInputs': [{'candidateId': 'C1',
#    'scope': 'CANDIDATE',
#    'unknownFacts': ['장비의 종류 및 특성에 대한 정보가 필요합니다.',
#     '고객 관리팀의 운영 방식에 대한 구체적인 정보가 필요합니다.'],
#    'conflictingLock': None,
#    'currentValue': None,
#    'requiredLegalChange': None,
#    'reason': '법률검토 전에 Concept의 사업 구조를 보완해야 합니다.',
#    'possibleUserAction': '현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.',
#    'question': '현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.',
#    'safeSummary': '법률검토 전에 Concept의 사업 구조를 보완해야 합니다.'}],
#  'terminalCandidates': 0,
#  'redesigned': 0,
#  'replanned': 0}

# %% [markdown]
# ## 30. Remaining 4 Legal + Exhaustive Recovery Summary

# %%
RUN_REMAINING_LEGAL = RUN_STAGED_FULL
legal_remaining = []
portfolio, legal_all, required_inputs = (list(c1_portfolio), list(c1_legal_all), list(c1_required_inputs))
redesigned_count, replanned_count = c1_redesigned, c1_replanned
c1_terminal = bool(c1_portfolio or c1_required_inputs or (c1_legal_all and c1_legal_all[-1].route.value == 'SYSTEM_FAILURE'))
if RUN_REMAINING_LEGAL and c1_terminal and len(candidates) > 1:
    legal_remaining = await engine.review_legal(seed, candidates[1:])
    rest_portfolio, rest_legal, rest_inputs, rest_redesigned, rest_replanned = await engine.resolve_legal(
        seed, candidate_preparation.usedPlans, candidates[1:], legal_remaining)
    portfolio += rest_portfolio; legal_all += rest_legal; required_inputs += rest_inputs
    redesigned_count += rest_redesigned; replanned_count += rest_replanned
else:
    print('SKIPPED — C1이 정상 terminal에 도달한 후 remaining Legal을 실행합니다.')
legal_initial = ([legal_one] if legal_one else []) + legal_remaining
display({'recoveryTrace': [item.model_dump(mode='json') for item in legal_all
                           if item.candidateId not in {x.candidateId for x in legal_initial}],
         'requiredInputs': required_inputs, 'metrics': engine._legal_metrics})
print({'Plan Selected': len(selected_plans),
       'Candidate Generated': candidate_preparation.candidateGenerated if candidate_preparation else 0,
       'Candidate Valid Initially': candidate_preparation.candidateAcceptedInitially if candidate_preparation else 0,
       'Candidate Regenerated': candidate_preparation.candidateRegenerated if candidate_preparation else 0,
       'Candidate Recovered': candidate_preparation.candidateRecovered if candidate_preparation else 0,
       'Fact Completion Attempted': legal_preparation.completionAttempted if legal_preparation else 0,
       'Fact Completion Validated': legal_preparation.completionValidated if legal_preparation else 0,
       'Fact Completion Accepted': legal_preparation.completionAccepted if legal_preparation else 0,
       'Dependency Semantic Calls': legal_preparation.dependencySemanticBatchCalls if legal_preparation else 0,
       'Completion Compliance PASS': sum(item.status == 'PASS' for item in legal_preparation.completionCompliance) if legal_preparation else 0,
       'Fact Consistency Invalid': sum(item.status == 'INVALID_FACT' for item in legal_preparation.consistencyReports) if legal_preparation else 0,
       'Consistency Repair Accepted': legal_preparation.consistencyRepairAccepted if legal_preparation else 0,
       'Legal Ready': len(candidates) if legal_preparation else 0,
       'Legal Reviewed': len(legal_initial),
       'Legal Accepted': sum(item.route.value == 'ACCEPT' for item in legal_all),
       'Legal Redesigned': redesigned_count, 'Legal Replanned': replanned_count,
       'Final Portfolio': len(portfolio)})
# Out:
# {'recoveryTrace': [],
#  'requiredInputs': [{'candidateId': 'C1',
#    'scope': 'CANDIDATE',
#    'unknownFacts': ['장비의 종류 및 특성에 대한 정보가 필요합니다.',
#     '고객 관리팀의 운영 방식에 대한 구체적인 정보가 필요합니다.'],
#    'conflictingLock': None,
#    'currentValue': None,
#    'requiredLegalChange': None,
#    'reason': '법률검토 전에 Concept의 사업 구조를 보완해야 합니다.',
#    'possibleUserAction': '현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.',
#    'question': '현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.',
#    'safeSummary': '법률검토 전에 Concept의 사업 구조를 보완해야 합니다.'},
#   {'candidateId': 'C3-FC1',
#    'scope': 'CANDIDATE',
#    'unknownFacts': ['장비의 종류 및 사용되는 기술에 대한 구체적인 정보가 필요합니다.'],
#    'conflictingLock': None,
#    'currentValue': None,
#    'requiredLegalChange': None,
#    'reason': '법률검토 전에 Concept의 사업 구조를 보완해야 합니다.',
#    'possibleUserAction': '현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.',
#    'question': '현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.',
#    'safeSummary': '법률검토 전에 Concept의 사업 구조를 보완해야 합니다.'}],
#  'metrics': {'factAttempted': 0,
#   'factValidated': 0,
#   'factAccepted': 0,
#   'factExhausted': 0,
#   'dependencySemanticCalls': 1,
#   'completionCompliancePassed': 0,
#   'providerNoncompliant': 0,
#   'recheckFailed': 0,
#   'consistencyInvalid': 1,
#   'consistencyRepairAttempted': 1,
#   'consistencyRepairAccepted': 1,
#   'consistencyRepairExhausted': 0,
#   'redesignAttempted': 0,
#   'redesignValidated': 0,
#   'redesignAccepted': 0,
#   'redesignExhausted': 0,
#   'replanAttempted': 0,
#   'replanValidated': 0,
#   'replanAccepted': 0,
#   'replanExhausted': 0}}
# {'Plan Selected': 5, 'Candidate Generated': 5, 'Candidate Valid Initially': 5, 'Candidate Regenerated': 0, 'Candidate Recovered': 0, 'Fact Completion Attempted': 0, 'Fact Completion Validated': 0, 'Fact Completion Accepted': 0, 'Dependency Semantic Calls': 1, 'Completion Compliance PASS': 0, 'Fact Consistency Invalid': 1, 'Consistency Repair Accepted': 1, 'Legal Ready': 5, 'Legal Reviewed': 5, 'Legal Accepted': 1, 'Legal Redesigned': 0, 'Legal Replanned': 0, 'Final Portfolio': 1}

# %% [markdown]
# ## 31. Replan

# %%
display(show_replan(type('PortfolioView', (), {'concepts': portfolio})()))
print({'replanned': replanned_count, 'reserveAvailable': len(reserve_plans)})
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# {'replanned': 0, 'reserveAvailable': 1}

# %% [markdown]
# ## 32. Final Portfolio

# %%
legal_terminal_status = ('READY_FULL' if len(portfolio) == MAX_CONCEPTS else
    'READY_LIMITED' if portfolio else
    'LEGAL_RECOVERY_COMPLETE_NO_ACCEPTED_CANDIDATE' if legal_initial and len(legal_initial) == len(candidates)
    else 'LEGAL_PENDING')
display(show_final_portfolio(type('PortfolioView', (), {'concepts': portfolio})()) if portfolio else {'status': legal_terminal_status})
# Out:
#   candidateId lineageId parentCandidateId                             이름  \
# 0          C5        L5              None  소형 사무실 화상회의 장비 대여 및 기술 지원 서비스
#
#                                         핵심 작동방식         family  \
# 0  대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.  기타 역할 · 기타 운영
#
#                                           descriptor           수익  \
# 0  {'thesis': {'targetSegmentThesis': '10~50인 규모의...  구독 기반 수익 모델
#
#                                     운영
# 0  전문 기술 지원 팀을 운영하여 고객의 문제를 신속하게 해결한다.

# %% [markdown]
# ## 33. Unresolved Candidate Summary

# %%
display(show_required_inputs(required_inputs) if required_inputs else {'unresolved': []})
# Out:
#   candidateId      scope                                       unknownFacts  \
# 0          C1  CANDIDATE  [장비의 종류 및 특성에 대한 정보가 필요합니다., 고객 관리팀의 운영 방식에 대한...
# 1      C3-FC1  CANDIDATE             [장비의 종류 및 사용되는 기술에 대한 구체적인 정보가 필요합니다.]
#
#                               reason  \
# 0  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.
# 1  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.
#
#                          possibleUserAction currentValue requiredLegalChange  \
# 0  현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.         None                None
# 1  현재 운영 계획에서 이 요구와 관련된 실제 사업 사실을 확인해 주십시오.         None                None
#
#                          safeSummary
# 0  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.
# 1  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.

# %% [markdown]
# ## 34. Manual Concept Selection

# %%
SELECTED_CANDIDATE_ID = portfolio[0].candidateId if portfolio else None  # 사용자가 수정
selected_concept = next((item for item in portfolio if item.candidateId == SELECTED_CANDIDATE_ID), None)
print({'selectedCandidateId': SELECTED_CANDIDATE_ID})
# Out:
# {'selectedCandidateId': 'C5'}

# %% [markdown]
# ## 35. 7 Hypotheses

# %%
hypotheses = (engine.build_or_load_current_hypothesis_contract(selected_concept)
              if RUN_STAGED_FULL and selected_concept else [])
hypotheses = await engine.resolve_hypothesis_semantics(hypotheses) if hypotheses else []
display(show_hypotheses(hypotheses))
display(show_hypothesis_readiness(hypotheses))
# Out:
#          HypothesisType                                      ProposedValue  \
# 0         TARGET_REGION                                            대한민국 전역
# 1         REVENUE_MODEL                                        구독 기반 수익 모델
# 2                 PRICE                         월 10만원~20만원 (장비 종류에 따라 상이)
# 3              CHANNELS                                    온라인 플랫폼 및 직접 영업
# 4       DIFFERENTIATORS                     신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담
# 5  PRE_MARKET_SOM_SHARE  targetSharePercent=15.0 horizonYears=3 rationa...
# 6        PRE_MARKET_SOM  amount=50000000.0 currency='KRW' period='1년' c...
#
#   FinalValue SemanticStatus         SemanticReason  Locked DecisionStatus  \
# 0       None          VALID          실제 사업 가설값입니다.   False       PROPOSED
# 1       None          VALID          실제 사업 가설값입니다.   False       PROPOSED
# 2       None          VALID          실제 사업 가설값입니다.   False       PROPOSED
# 3       None          VALID          실제 사업 가설값입니다.   False       PROPOSED
# 4       None          VALID          실제 사업 가설값입니다.   False       PROPOSED
# 5       None          VALID  수치·기간·산식 가설이 명시되었습니다.   False       PROPOSED
# 6       None          VALID  수치·기간·산식 가설이 명시되었습니다.   False       PROPOSED
#
#   LegalImpact
# 0        NONE
# 1        NONE
# 2        NONE
# 3        NONE
# 4        NONE
# 5        NONE
# 6        NONE
# {'All Values Semantically Valid': True,
#  'All Decisions Confirmed': False,
#  'Ready For Handoff': False,
#  'status': 'NOT_READY',
#  'reason': 'UNRESOLVED_HYPOTHESES',
#  'unresolvedHypotheses': ['TARGET_REGION',
#   'REVENUE_MODEL',
#   'PRICE',
#   'CHANNELS',
#   'DIFFERENTIATORS',
#   'PRE_MARKET_SOM_SHARE',
#   'PRE_MARKET_SOM']}

# %% [markdown]
# ## 36. Confirm / Edit

# %%
CONFIRM_ALL_PROPOSED = True
HYPOTHESIS_EDITS = {
    # 'PRICE': '월 17,900원',
}
confirmed_hypotheses = engine.confirm_hypotheses(
    hypotheses, HYPOTHESIS_EDITS, confirm_all_proposed=CONFIRM_ALL_PROPOSED) if hypotheses else []
display(show_hypotheses(confirmed_hypotheses))
hypothesis_readiness = show_hypothesis_readiness(confirmed_hypotheses)
display(hypothesis_readiness)
# Out:
#          HypothesisType                                      ProposedValue  \
# 0         TARGET_REGION                                            대한민국 전역
# 1         REVENUE_MODEL                                        구독 기반 수익 모델
# 2                 PRICE                         월 10만원~20만원 (장비 종류에 따라 상이)
# 3              CHANNELS                                    온라인 플랫폼 및 직접 영업
# 4       DIFFERENTIATORS                     신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담
# 5  PRE_MARKET_SOM_SHARE  targetSharePercent=15.0 horizonYears=3 rationa...
# 6        PRE_MARKET_SOM  amount=50000000.0 currency='KRW' period='1년' c...
#
#                                           FinalValue SemanticStatus  \
# 0                                            대한민국 전역          VALID
# 1                                        구독 기반 수익 모델          VALID
# 2                         월 10만원~20만원 (장비 종류에 따라 상이)          VALID
# 3                                    온라인 플랫폼 및 직접 영업          VALID
# 4                     신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담          VALID
# 5  targetSharePercent=15.0 horizonYears=3 rationa...          VALID
# 6  amount=50000000.0 currency='KRW' period='1년' c...          VALID
#
#           SemanticReason  Locked DecisionStatus LegalImpact
# 0          실제 사업 가설값입니다.   False       ACCEPTED        NONE
# 1          실제 사업 가설값입니다.   False       ACCEPTED        NONE
# 2          실제 사업 가설값입니다.   False       ACCEPTED        NONE
# 3          실제 사업 가설값입니다.   False       ACCEPTED        NONE
# 4          실제 사업 가설값입니다.   False       ACCEPTED        NONE
# 5  수치·기간·산식 가설이 명시되었습니다.   False       ACCEPTED        NONE
# 6  수치·기간·산식 가설이 명시되었습니다.   False       ACCEPTED        NONE
# {'All Values Semantically Valid': True,
#  'All Decisions Confirmed': True,
#  'Ready For Handoff': True,
#  'status': 'READY',
#  'reason': None,
#  'unresolvedHypotheses': []}

# %% [markdown]
# ## 37. Actual Delta Legal

# %%
RUN_DELTA_LEGAL = True
delta_legal_result = None
if RUN_STAGED_FULL and RUN_DELTA_LEGAL and selected_concept and any(h.deltaLegalRequired for h in confirmed_hypotheses):
    delta_legal_result = await engine.review_delta_legal(seed, selected_concept, confirmed_hypotheses)
    confirmed_hypotheses = engine.mark_delta_legal_reviewed(confirmed_hypotheses, delta_legal_result)
display(delta_legal_result.model_dump(mode='json') if delta_legal_result else {'status': 'NOT_REQUIRED_OR_SKIPPED'})
# Out:
# {'status': 'NOT_REQUIRED_OR_SKIPPED'}

# %% [markdown]
# ## 38. Market Seed

# %%
handoff = None
if selected_concept and legal_all and hypothesis_readiness['Ready For Handoff']:
    handoff = engine.build_downstream_handoff(seed, selected_concept, confirmed_hypotheses, legal_all)
display(handoff.marketAnalysisSeedSnapshot if handoff else {
    'status': 'NOT_READY', 'reason': hypothesis_readiness.get('reason'),
    'unresolvedHypotheses': hypothesis_readiness.get('unresolvedHypotheses', [])})
# Out:
# {'contract': 'market-analysis-seed-snapshot-v1',
#  'schemaVersion': '2.0',
#  'snapshotId': 'lab-market-seed',
#  'projectId': 0,
#  'selectionId': 0,
#  'conceptId': 'C5',
#  'createdAt': '2026-08-10T08:49:55.601660+00:00',
#  'sourceSnapshotHash': 'sha256:f1a8f933df3571842eeda0815e57e13fdb5ec39cdc5434fabaefdb9a4087d3ad',
#  'originalSeed': {'ideaOverview': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#   'fields': {'ideaOverview': {'value': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#     'source': 'USER_INPUT',
#     'decisionState': 'LOCKED'},
#    'problem': {'value': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#     'source': 'USER_INPUT',
#     'decisionState': 'LOCKED'},
#    'targetUsers': {'value': '10~50인 규모의 소형 사무실 운영자',
#     'source': 'USER_INPUT',
#     'decisionState': 'LOCKED'}}},
#  'aiInterpretation': {'interpretedProblem': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#   'interpretedTargetUsers': '10~50인 규모의 소형 사무실 운영자',
#   'usageContext': '소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황',
#   'industryCategory': '서비스업',
#   'researchScope': '소형 사무실의 화상회의 장비 대여 시장',
#   'conciseIdeaDefinition': '소형 사무실을 위한 화상회의 장비 정기 대여 서비스',
#   'targetRegionInterpretation': '대여 서비스가 제공될 지역은 명시되지 않음',
#   'relevantKnownCompetitorContext': '경쟁자는 명시되지 않음'},
#  'selectedConcept': {'identity': {'conceptName': '소형 사무실 화상회의 장비 대여 및 기술 지원 서비스',
#    'conceptDefinition': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#    'introduction': '소형 사무실 운영자를 위한 화상회의 장비 대여 및 기술 지원 서비스로, 고객의 비즈니스 효율성을 높입니다.',
#    'coreValue': '장비 대여와 함께 제공되는 기술 지원을 통해 고객의 불편을 최소화하고 문제를 신속하게 해결합니다.',
#    'targetUsers': '10~50인 규모의 소형 사무실 운영자',
#    'industryCategory': '서비스업',
#    'researchScope': '소형 사무실의 화상회의 장비 대여 시장'},
#   'solution': {'problemScenario': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#    'solutionMechanism': '대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.',
#    'featureSet': ['정기적인 장비 대여', '신속한 기술 지원 서비스', '고객 맞춤형 기술 상담']},
#   'operation': {'actorRoles': ['고객', '기술 지원 팀', '장비 제조사'],
#    'platformRole': '온라인 플랫폼을 통해 고객과의 상호작용 및 서비스 제공',
#    'operatingModel': '전문 기술 지원 팀을 운영하여 고객의 문제를 신속하게 해결한다.',
#    'partnerModel': '장비 제조사와 협력하여 최신 기술 정보를 공유하고, 기술 지원을 강화한다.',
#    'providerRole': '서비스 제공자로서 고객에게 장비 대여 및 기술 지원을 제공',
#    'sellerRole': '장비 대여 계약을 체결하고 고객에게 서비스를 제공하는 역할',
#    'intermediaryRole': '고객과 기술 지원 팀 간의 소통을 원활하게 하는 역할',
#    'transactionFlow': ['고객이 장비 대여 요청',
#     '계약 체결 및 대여 시작',
#     '기술 지원 요청 시 지원 제공',
#     '장비 반납 및 상태 점검'],
#    'paymentFlow': ['고객이 월 구독료 결제', '기술 지원 서비스에 대한 추가 비용 청구'],
#    'personalDataUsage': [],
#    'physicalActivities': ['장비 배송', '장비 설치', '현장 기술 지원'],
#    'partnerRequirements': ['장비 제조사와의 협력 계약 체결', '기술 지원 팀의 전문성 확보'],
#    'qualificationRequirements': []},
#   'valueSemantics': [{'fieldKey': 'conceptName',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'conceptDefinition',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'introduction',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'coreValue',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'targetUsers',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'industryCategory',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'researchScope',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'targetRegion',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'revenueModel',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'price',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'channels',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'differentiators',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'preMarketSomShareHypothesis',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'preMarketSomHypothesis',
#     'source': 'AI_HYPOTHESIS',
#     'authority': 'OPEN',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'actorRoles',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'platformRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'problemScenario',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'solutionMechanism',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'featureSet',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'operatingModel',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'partnerModel',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'providerRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'sellerRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'intermediaryRole',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'transactionFlow',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'paymentFlow',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'personalDataUsage',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'physicalActivities',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'partnerRequirements',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'qualificationRequirements',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'},
#    {'fieldKey': 'advertisingClaims',
#     'source': 'CONCEPT_GENERATED',
#     'authority': 'REVIEWABLE',
#     'decision': 'PROPOSED'}],
#   'canonicalHash': 'sha256:127948514a5d7bae9e5afe8977fdee41da1591011a6b57436671407f1ba36d38'},
#  'finalHypotheses': {'targetRegion': {'value': '대한민국 전역',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'revenueModel': {'value': '구독 기반 수익 모델',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'price': {'value': '월 10만원~20만원 (장비 종류에 따라 상이)',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'channels': {'value': '온라인 플랫폼 및 직접 영업',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'differentiators': {'value': '신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담',
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'preMarketSomShare': {'value': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='소형 사무실의 화상회의 장비 대여 수요 증가에 따라 시장 점유율 확대 가능', assumptions=['소형 사무실의 화상회의 수요 증가', '경쟁사 대비 우수한 기술 지원 서비스 제공']),
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'},
#   'preMarketSom': {'value': PreMarketSomHypothesis(amount=50000000.0, currency='KRW', period='1년', calculationBasis='소형 사무실 500개 고객 확보 시 예상 매출', assumptions=['소형 사무실의 화상회의 장비 대여 수요 증가', '기술 지원 서비스에 대한 고객 만족도 향상'], confidence='HIGH'),
#    'source': 'AI_HYPOTHESIS',
#    'decisionStatus': 'ACCEPTED',
#    'proposalVersion': 1,
#    'legalImpact': 'NONE',
#    'legalReviewStatus': 'NOT_REQUIRED'}},
#  'legalResult': {'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#   'safeSummary': '고객의 개인정보 보호 및 안전한 서비스 제공을 위한 조치를 이행하며, 법령을 준수하는 방식으로 사업을 운영할 수 있습니다.',
#   'requiredControls': ['고객의 개인정보 보호를 위한 처리방침 수립 및 고지',
#    '부당한 표시 및 광고 행위 금지를 위한 내부 규정 마련',
#    '고영향 인공지능에 대한 사전 검토 및 안전성 확보 조치 이행',
#    '전자상거래 관련 법령 준수를 위한 고객 정보 제공 및 신고 의무 이행',
#    '부가가치세 관련 법령 준수를 위한 사업자 등록 및 영수증 발급'],
#   'requiredPartnersAndQualifications': ['장비 제조사와의 협력 계약 체결 및 기술 지원 팀의 전문성 확보'],
#   'prohibitedVariants': [],
#   'requiredDisclosures': ['서비스 제공에 대한 고지 및 이용약관 명시'],
#   'officialEvidenceReferences': [{'referenceIndex': 0,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제3조',
#     'title': '기본원칙 및 국가 등의 책무',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:d3af532ea737d1273289ec05ed2ff55c735bccac16c517b64292d7beeccd5312',
#     'boundedProvisionSummary': '인공지능기술과 인공지능산업은 안전성과 신뢰성을 제고하여 국민의 삶의 질을 향상시키는 방향으로 발전되어야 한다.',
#     'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 1,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제33조',
#     'title': '고영향 인공지능의 확인',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:3fc48c2346668bf69d17684a6ea9e0adf2b1e2deb1409e8094281cbeefa8b48d',
#     'boundedProvisionSummary': '인공지능사업자는 고영향 인공지능에 해당하는지 사전에 검토해야 한다.',
#     'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 2,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제34조',
#     'title': '고영향 인공지능과 관련한 사업자의 책무',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:617313212eede73a9fa4de775860b754747632549637a3da96e8e1b7fc0677c4',
#     'boundedProvisionSummary': '고영향 인공지능의 안전성 및 신뢰성을 확보하기 위한 조치를 이행해야 한다.',
#     'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 3,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제35조',
#     'title': '고영향 인공지능 영향평가',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:fb8ebf040c2029dd28b2bd73badb7e225880c1a211d422abac790f568fb5d8c5',
#     'boundedProvisionSummary': '고영향 인공지능을 이용한 제품 또는 서비스의 영향을 평가해야 한다.',
#     'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 4,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000030',
#     'officialIdentifier': '282481',
#     'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#     'articleReference': '제3조',
#     'title': '정보통신서비스 제공자 및 이용자의 책무',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260106',
#     'effectiveDate': '20260707',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:0f8a92d020f0e4f81e3020f1fae1178b3a63b92768de88a28f48449d7d37dd83',
#     'boundedProvisionSummary': '정보통신서비스 제공자는 이용자를 보호하고 안전한 서비스를 제공해야 한다.',
#     'queryKey': 'sha256:7950518a36e66a586195226f8a68f7683de9c44930cbffec85bfe270ccd8cc59',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 5,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000030',
#     'officialIdentifier': '282481',
#     'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#     'articleReference': '제4조',
#     'title': '정보통신망 이용촉진 및 정보보호등에 관한 시책의 마련',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260106',
#     'effectiveDate': '20260707',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:fa6d134f7eaa58efaed72e7d30f93e2d19c6edf8b92fb43c9f1ce70e616989e1',
#     'boundedProvisionSummary': '정보통신망 이용촉진 및 정보보호 시책을 마련해야 한다.',
#     'queryKey': 'sha256:7950518a36e66a586195226f8a68f7683de9c44930cbffec85bfe270ccd8cc59',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 6,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제3조',
#     'title': '부당한 표시ㆍ광고 행위의 금지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#     'boundedProvisionSummary': '부당한 표시ㆍ광고 행위를 금지해야 한다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 7,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제5조',
#     'title': '표시ㆍ광고 내용의 실증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#     'boundedProvisionSummary': '사업자는 표시ㆍ광고의 사실과 관련한 사항을 실증할 수 있어야 한다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 8,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제10조',
#     'title': '손해배상책임',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#     'boundedProvisionSummary': '부당한 표시ㆍ광고 행위로 피해를 입은 경우 손해배상 책임을 진다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 9,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제17조',
#     'title': '벌칙',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#     'boundedProvisionSummary': '부당한 표시ㆍ광고 행위를 한 경우 벌칙에 처한다.',
#     'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 10,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제12조',
#     'title': '통신판매업자의 신고 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#     'boundedProvisionSummary': '통신판매업자는 신고해야 한다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 11,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제13조',
#     'title': '신원 및 거래조건에 대한 정보의 제공',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#     'boundedProvisionSummary': '통신판매업자는 신원 및 거래조건에 대한 정보를 제공해야 한다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 12,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제17조',
#     'title': '청약철회등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#     'boundedProvisionSummary': '소비자는 청약철회 등을 할 수 있다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 13,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제18조',
#     'title': '청약철회등의 효과',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#     'boundedProvisionSummary': '청약철회 시 재화 등을 반환해야 한다.',
#     'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 14,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제5조',
#     'title': '과세기간',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#     'boundedProvisionSummary': '부가가치세의 과세기간을 규정한다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 15,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제8조',
#     'title': '사업자등록',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#     'boundedProvisionSummary': '사업자는 사업자등록을 신청해야 한다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 16,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제36조',
#     'title': '영수증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#     'boundedProvisionSummary': '영수증을 발급해야 한다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 17,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제53조의2',
#     'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#     'boundedProvisionSummary': '국외사업자의 사업자등록 및 납부 등에 관한 특례를 규정한다.',
#     'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#     'registryVersion': 'legal-registry-v1'}],
#   'deltaLegalReviews': []}}

# %% [markdown]
# ## 39. Marketing Source

# %%
display(handoff.marketingSourceSnapshot if handoff else {
    'status': 'NOT_READY', 'reason': hypothesis_readiness.get('reason'),
    'unresolvedHypotheses': hypothesis_readiness.get('unresolvedHypotheses', [])})
# Out:
# {'contract': 'marketing-source-snapshot-v1',
#  'schemaVersion': '2.0',
#  'snapshotId': 'lab-marketing-source',
#  'projectId': 0,
#  'selectionId': 0,
#  'conceptId': 'C5',
#  'marketAnalysisSeedSnapshotId': 'lab-market-seed',
#  'marketAnalysisSeedSnapshotHash': 'sha256:b09efb746b893de88c33a09b9f49746338fcf07a11a97f76389d71f4d414f6cf',
#  'createdAt': '2026-08-10T08:49:55.601660+00:00',
#  'conceptName': '소형 사무실 화상회의 장비 대여 및 기술 지원 서비스',
#  'targetSegment': '10~50인 규모의 소형 사무실 운영자',
#  'problem': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#  'valueProposition': '장비 대여와 함께 제공되는 기술 지원을 통해 고객의 불편을 최소화하고 문제를 신속하게 해결합니다.',
#  'positioning': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#  'keyFeatures': ['정기적인 장비 대여', '신속한 기술 지원 서비스', '고객 맞춤형 기술 상담'],
#  'targetRegion': '대한민국 전역',
#  'revenueModel': '구독 기반 수익 모델',
#  'price': '월 10만원~20만원 (장비 종류에 따라 상이)',
#  'pricing': '구독 기반 수익 모델 · 월 10만원~20만원 (장비 종류에 따라 상이)',
#  'channels': ['온라인 플랫폼 및 직접 영업'],
#  'competitorDifferentiators': ['신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담'],
#  'preMarketSomShare': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='소형 사무실의 화상회의 장비 대여 수요 증가에 따라 시장 점유율 확대 가능', assumptions=['소형 사무실의 화상회의 수요 증가', '경쟁사 대비 우수한 기술 지원 서비스 제공']),
#  'preMarketSom': PreMarketSomHypothesis(amount=50000000.0, currency='KRW', period='1년', calculationBasis='소형 사무실 500개 고객 확보 시 예상 매출', assumptions=['소형 사무실의 화상회의 장비 대여 수요 증가', '기술 지원 서비스에 대한 고객 만족도 향상'], confidence='HIGH'),
#  'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#  'allowedClaims': ['신속한 기술 지원으로 고객 만족도 향상', '비용 효율적인 화상회의 솔루션 제공'],
#  'prohibitedClaims': [],
#  'requiredDisclosures': ['서비스 제공에 대한 고지 및 이용약관 명시'],
#  'requiredControls': ['고객의 개인정보 보호를 위한 처리방침 수립 및 고지',
#   '부당한 표시 및 광고 행위 금지를 위한 내부 규정 마련',
#   '고영향 인공지능에 대한 사전 검토 및 안전성 확보 조치 이행',
#   '전자상거래 관련 법령 준수를 위한 고객 정보 제공 및 신고 의무 이행',
#   '부가가치세 관련 법령 준수를 위한 사업자 등록 및 영수증 발급'],
#  'communicationRequiredControls': ['고객의 개인정보 보호를 위한 처리방침 수립 및 고지',
#   '부당한 표시 및 광고 행위 금지를 위한 내부 규정 마련',
#   '고영향 인공지능에 대한 사전 검토 및 안전성 확보 조치 이행',
#   '전자상거래 관련 법령 준수를 위한 고객 정보 제공 및 신고 의무 이행',
#   '부가가치세 관련 법령 준수를 위한 사업자 등록 및 영수증 발급'],
#  'officialEvidenceReferences': [{'referenceIndex': 0,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '014820',
#    'officialIdentifier': '282791',
#    'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#    'articleReference': '제3조',
#    'title': '기본원칙 및 국가 등의 책무',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:d3af532ea737d1273289ec05ed2ff55c735bccac16c517b64292d7beeccd5312',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 1,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '014820',
#    'officialIdentifier': '282791',
#    'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#    'articleReference': '제33조',
#    'title': '고영향 인공지능의 확인',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:3fc48c2346668bf69d17684a6ea9e0adf2b1e2deb1409e8094281cbeefa8b48d',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 2,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '014820',
#    'officialIdentifier': '282791',
#    'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#    'articleReference': '제34조',
#    'title': '고영향 인공지능과 관련한 사업자의 책무',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:617313212eede73a9fa4de775860b754747632549637a3da96e8e1b7fc0677c4',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 3,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '014820',
#    'officialIdentifier': '282791',
#    'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#    'articleReference': '제35조',
#    'title': '고영향 인공지능 영향평가',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:fb8ebf040c2029dd28b2bd73badb7e225880c1a211d422abac790f568fb5d8c5',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 4,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '000030',
#    'officialIdentifier': '282481',
#    'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#    'articleReference': '제3조',
#    'title': '정보통신서비스 제공자 및 이용자의 책무',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260106',
#    'effectiveDate': '20260707',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:0f8a92d020f0e4f81e3020f1fae1178b3a63b92768de88a28f48449d7d37dd83',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 5,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '000030',
#    'officialIdentifier': '282481',
#    'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#    'articleReference': '제4조',
#    'title': '정보통신망 이용촉진 및 정보보호등에 관한 시책의 마련',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260106',
#    'effectiveDate': '20260707',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:fa6d134f7eaa58efaed72e7d30f93e2d19c6edf8b92fb43c9f1ce70e616989e1',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 6,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제3조',
#    'title': '부당한 표시ㆍ광고 행위의 금지',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 7,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제5조',
#    'title': '표시ㆍ광고 내용의 실증 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 8,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제10조',
#    'title': '손해배상책임',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 9,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '002011',
#    'officialIdentifier': '268659',
#    'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#    'articleReference': '제17조',
#    'title': '벌칙',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20250121',
#    'effectiveDate': '20250121',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 10,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제12조',
#    'title': '통신판매업자의 신고 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 11,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제13조',
#    'title': '신원 및 거래조건에 대한 정보의 제공',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 12,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제17조',
#    'title': '청약철회등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 13,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '009318',
#    'officialIdentifier': '282793',
#    'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#    'articleReference': '제18조',
#    'title': '청약철회등의 효과',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20260120',
#    'effectiveDate': '20260721',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 14,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제5조',
#    'title': '과세기간',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 15,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제8조',
#    'title': '사업자등록',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 16,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제36조',
#    'title': '영수증 등',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#    'registryVersion': 'legal-registry-v1'},
#   {'referenceIndex': 17,
#    'sourceType': 'OFFICIAL_LAW',
#    'lawId': '001571',
#    'officialIdentifier': '276117',
#    'lawName': '부가가치세법',
#    'articleReference': '제53조의2',
#    'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#    'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#    'jurisdiction': 'KR',
#    'promulgationDate': '20251001',
#    'effectiveDate': '20260102',
#    'retrievedAt': '2026-08-10T08:49:49.105036Z',
#    'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#    'registryVersion': 'legal-registry-v1'}],
#  'hash': 'sha256:53553d1efbd4572f8343c0d99a65daf35e7ae1dccfe40a1aa5c171654f11f21d',
#  'sourceSnapshotHash': 'sha256:53553d1efbd4572f8343c0d99a65daf35e7ae1dccfe40a1aa5c171654f11f21d'}

# %% [markdown]
# ## 40. Contract Compatibility

# %%
display(show_downstream_handoff(handoff) if handoff else {
    'contract': 'NOT_READY', 'reason': hypothesis_readiness.get('reason'),
    'unresolvedHypotheses': hypothesis_readiness.get('unresolvedHypotheses', [])})
# Out:
# {'호환성': 'PASS',
#  '구조': 'STRUCTURE_PASS',
#  '계약': 'CONTRACT_PASS',
#  '필드 매핑':                        v2Field                             downstreamField  \
#  0        candidate.conceptName        selectedConcept.identity.conceptName
#  1  candidate.solutionMechanism  selectedConcept.solution.solutionMechanism
#  2                hypotheses[*]                             finalHypotheses
#  3                        legal                                 legalResult
#
#                source  transformed  required
#  0  CONCEPT_GENERATED        False      True
#  1  CONCEPT_GENERATED        False      True
#  2     USER_CONFIRMED         True      True
#  3  OFFICIAL_EVIDENCE         True      True  ,
#  'Market payload': {'contract': 'market-analysis-seed-snapshot-v1',
#   'schemaVersion': '2.0',
#   'snapshotId': 'lab-market-seed',
#   'projectId': 0,
#   'selectionId': 0,
#   'conceptId': 'C5',
#   'createdAt': '2026-08-10T08:49:55.601660+00:00',
#   'sourceSnapshotHash': 'sha256:f1a8f933df3571842eeda0815e57e13fdb5ec39cdc5434fabaefdb9a4087d3ad',
#   'originalSeed': {'ideaOverview': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#    'fields': {'ideaOverview': {'value': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#      'source': 'USER_INPUT',
#      'decisionState': 'LOCKED'},
#     'problem': {'value': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#      'source': 'USER_INPUT',
#      'decisionState': 'LOCKED'},
#     'targetUsers': {'value': '10~50인 규모의 소형 사무실 운영자',
#      'source': 'USER_INPUT',
#      'decisionState': 'LOCKED'}}},
#   'aiInterpretation': {'interpretedProblem': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#    'interpretedTargetUsers': '10~50인 규모의 소형 사무실 운영자',
#    'usageContext': '소형 사무실에서 화상회의를 위한 장비를 필요로 하는 상황',
#    'industryCategory': '서비스업',
#    'researchScope': '소형 사무실의 화상회의 장비 대여 시장',
#    'conciseIdeaDefinition': '소형 사무실을 위한 화상회의 장비 정기 대여 서비스',
#    'targetRegionInterpretation': '대여 서비스가 제공될 지역은 명시되지 않음',
#    'relevantKnownCompetitorContext': '경쟁자는 명시되지 않음'},
#   'selectedConcept': {'identity': {'conceptName': '소형 사무실 화상회의 장비 대여 및 기술 지원 서비스',
#     'conceptDefinition': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#     'introduction': '소형 사무실 운영자를 위한 화상회의 장비 대여 및 기술 지원 서비스로, 고객의 비즈니스 효율성을 높입니다.',
#     'coreValue': '장비 대여와 함께 제공되는 기술 지원을 통해 고객의 불편을 최소화하고 문제를 신속하게 해결합니다.',
#     'targetUsers': '10~50인 규모의 소형 사무실 운영자',
#     'industryCategory': '서비스업',
#     'researchScope': '소형 사무실의 화상회의 장비 대여 시장'},
#    'solution': {'problemScenario': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#     'solutionMechanism': '대여 서비스와 기술 지원을 결합하여 고객의 화상회의 환경을 안정적으로 유지한다.',
#     'featureSet': ['정기적인 장비 대여', '신속한 기술 지원 서비스', '고객 맞춤형 기술 상담']},
#    'operation': {'actorRoles': ['고객', '기술 지원 팀', '장비 제조사'],
#     'platformRole': '온라인 플랫폼을 통해 고객과의 상호작용 및 서비스 제공',
#     'operatingModel': '전문 기술 지원 팀을 운영하여 고객의 문제를 신속하게 해결한다.',
#     'partnerModel': '장비 제조사와 협력하여 최신 기술 정보를 공유하고, 기술 지원을 강화한다.',
#     'providerRole': '서비스 제공자로서 고객에게 장비 대여 및 기술 지원을 제공',
#     'sellerRole': '장비 대여 계약을 체결하고 고객에게 서비스를 제공하는 역할',
#     'intermediaryRole': '고객과 기술 지원 팀 간의 소통을 원활하게 하는 역할',
#     'transactionFlow': ['고객이 장비 대여 요청',
#      '계약 체결 및 대여 시작',
#      '기술 지원 요청 시 지원 제공',
#      '장비 반납 및 상태 점검'],
#     'paymentFlow': ['고객이 월 구독료 결제', '기술 지원 서비스에 대한 추가 비용 청구'],
#     'personalDataUsage': [],
#     'physicalActivities': ['장비 배송', '장비 설치', '현장 기술 지원'],
#     'partnerRequirements': ['장비 제조사와의 협력 계약 체결', '기술 지원 팀의 전문성 확보'],
#     'qualificationRequirements': []},
#    'valueSemantics': [{'fieldKey': 'conceptName',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'conceptDefinition',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'introduction',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'coreValue',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'targetUsers',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'industryCategory',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'researchScope',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'targetRegion',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'revenueModel',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'price',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'channels',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'differentiators',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'preMarketSomShareHypothesis',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'preMarketSomHypothesis',
#      'source': 'AI_HYPOTHESIS',
#      'authority': 'OPEN',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'actorRoles',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'platformRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'problemScenario',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'solutionMechanism',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'featureSet',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'operatingModel',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'partnerModel',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'providerRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'sellerRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'intermediaryRole',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'transactionFlow',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'paymentFlow',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'personalDataUsage',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'physicalActivities',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'partnerRequirements',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'qualificationRequirements',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'},
#     {'fieldKey': 'advertisingClaims',
#      'source': 'CONCEPT_GENERATED',
#      'authority': 'REVIEWABLE',
#      'decision': 'PROPOSED'}],
#    'canonicalHash': 'sha256:127948514a5d7bae9e5afe8977fdee41da1591011a6b57436671407f1ba36d38'},
#   'finalHypotheses': {'targetRegion': {'value': '대한민국 전역',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'revenueModel': {'value': '구독 기반 수익 모델',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'price': {'value': '월 10만원~20만원 (장비 종류에 따라 상이)',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'channels': {'value': '온라인 플랫폼 및 직접 영업',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'differentiators': {'value': '신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담',
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'preMarketSomShare': {'value': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='소형 사무실의 화상회의 장비 대여 수요 증가에 따라 시장 점유율 확대 가능', assumptions=['소형 사무실의 화상회의 수요 증가', '경쟁사 대비 우수한 기술 지원 서비스 제공']),
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'},
#    'preMarketSom': {'value': PreMarketSomHypothesis(amount=50000000.0, currency='KRW', period='1년', calculationBasis='소형 사무실 500개 고객 확보 시 예상 매출', assumptions=['소형 사무실의 화상회의 장비 대여 수요 증가', '기술 지원 서비스에 대한 고객 만족도 향상'], confidence='HIGH'),
#     'source': 'AI_HYPOTHESIS',
#     'decisionStatus': 'ACCEPTED',
#     'proposalVersion': 1,
#     'legalImpact': 'NONE',
#     'legalReviewStatus': 'NOT_REQUIRED'}},
#   'legalResult': {'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#    'safeSummary': '고객의 개인정보 보호 및 안전한 서비스 제공을 위한 조치를 이행하며, 법령을 준수하는 방식으로 사업을 운영할 수 있습니다.',
#    'requiredControls': ['고객의 개인정보 보호를 위한 처리방침 수립 및 고지',
#     '부당한 표시 및 광고 행위 금지를 위한 내부 규정 마련',
#     '고영향 인공지능에 대한 사전 검토 및 안전성 확보 조치 이행',
#     '전자상거래 관련 법령 준수를 위한 고객 정보 제공 및 신고 의무 이행',
#     '부가가치세 관련 법령 준수를 위한 사업자 등록 및 영수증 발급'],
#    'requiredPartnersAndQualifications': ['장비 제조사와의 협력 계약 체결 및 기술 지원 팀의 전문성 확보'],
#    'prohibitedVariants': [],
#    'requiredDisclosures': ['서비스 제공에 대한 고지 및 이용약관 명시'],
#    'officialEvidenceReferences': [{'referenceIndex': 0,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '014820',
#      'officialIdentifier': '282791',
#      'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#      'articleReference': '제3조',
#      'title': '기본원칙 및 국가 등의 책무',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:d3af532ea737d1273289ec05ed2ff55c735bccac16c517b64292d7beeccd5312',
#      'boundedProvisionSummary': '인공지능기술과 인공지능산업은 안전성과 신뢰성을 제고하여 국민의 삶의 질을 향상시키는 방향으로 발전되어야 한다.',
#      'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 1,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '014820',
#      'officialIdentifier': '282791',
#      'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#      'articleReference': '제33조',
#      'title': '고영향 인공지능의 확인',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:3fc48c2346668bf69d17684a6ea9e0adf2b1e2deb1409e8094281cbeefa8b48d',
#      'boundedProvisionSummary': '인공지능사업자는 고영향 인공지능에 해당하는지 사전에 검토해야 한다.',
#      'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 2,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '014820',
#      'officialIdentifier': '282791',
#      'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#      'articleReference': '제34조',
#      'title': '고영향 인공지능과 관련한 사업자의 책무',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:617313212eede73a9fa4de775860b754747632549637a3da96e8e1b7fc0677c4',
#      'boundedProvisionSummary': '고영향 인공지능의 안전성 및 신뢰성을 확보하기 위한 조치를 이행해야 한다.',
#      'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 3,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '014820',
#      'officialIdentifier': '282791',
#      'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#      'articleReference': '제35조',
#      'title': '고영향 인공지능 영향평가',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:fb8ebf040c2029dd28b2bd73badb7e225880c1a211d422abac790f568fb5d8c5',
#      'boundedProvisionSummary': '고영향 인공지능을 이용한 제품 또는 서비스의 영향을 평가해야 한다.',
#      'queryKey': 'sha256:5df7a84e71ddb6c9bbd565f0fbe1a0986b1c9b0ac7bb1179c4e7c0753c8175d9',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 4,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '000030',
#      'officialIdentifier': '282481',
#      'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#      'articleReference': '제3조',
#      'title': '정보통신서비스 제공자 및 이용자의 책무',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260106',
#      'effectiveDate': '20260707',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:0f8a92d020f0e4f81e3020f1fae1178b3a63b92768de88a28f48449d7d37dd83',
#      'boundedProvisionSummary': '정보통신서비스 제공자는 이용자를 보호하고 안전한 서비스를 제공해야 한다.',
#      'queryKey': 'sha256:7950518a36e66a586195226f8a68f7683de9c44930cbffec85bfe270ccd8cc59',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 5,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '000030',
#      'officialIdentifier': '282481',
#      'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#      'articleReference': '제4조',
#      'title': '정보통신망 이용촉진 및 정보보호등에 관한 시책의 마련',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260106',
#      'effectiveDate': '20260707',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:fa6d134f7eaa58efaed72e7d30f93e2d19c6edf8b92fb43c9f1ce70e616989e1',
#      'boundedProvisionSummary': '정보통신망 이용촉진 및 정보보호 시책을 마련해야 한다.',
#      'queryKey': 'sha256:7950518a36e66a586195226f8a68f7683de9c44930cbffec85bfe270ccd8cc59',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 6,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제3조',
#      'title': '부당한 표시ㆍ광고 행위의 금지',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#      'boundedProvisionSummary': '부당한 표시ㆍ광고 행위를 금지해야 한다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 7,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제5조',
#      'title': '표시ㆍ광고 내용의 실증 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#      'boundedProvisionSummary': '사업자는 표시ㆍ광고의 사실과 관련한 사항을 실증할 수 있어야 한다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 8,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제10조',
#      'title': '손해배상책임',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#      'boundedProvisionSummary': '부당한 표시ㆍ광고 행위로 피해를 입은 경우 손해배상 책임을 진다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 9,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '002011',
#      'officialIdentifier': '268659',
#      'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#      'articleReference': '제17조',
#      'title': '벌칙',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20250121',
#      'effectiveDate': '20250121',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#      'boundedProvisionSummary': '부당한 표시ㆍ광고 행위를 한 경우 벌칙에 처한다.',
#      'queryKey': 'sha256:90d9771bc75e6de6069905fe746a5d12ae11896159015fd6e37c2f5d242dbfbe',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 10,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제12조',
#      'title': '통신판매업자의 신고 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#      'boundedProvisionSummary': '통신판매업자는 신고해야 한다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 11,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제13조',
#      'title': '신원 및 거래조건에 대한 정보의 제공',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#      'boundedProvisionSummary': '통신판매업자는 신원 및 거래조건에 대한 정보를 제공해야 한다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 12,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제17조',
#      'title': '청약철회등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#      'boundedProvisionSummary': '소비자는 청약철회 등을 할 수 있다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 13,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '009318',
#      'officialIdentifier': '282793',
#      'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#      'articleReference': '제18조',
#      'title': '청약철회등의 효과',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20260120',
#      'effectiveDate': '20260721',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#      'boundedProvisionSummary': '청약철회 시 재화 등을 반환해야 한다.',
#      'queryKey': 'sha256:602e295f16136be3303188937186db5e352b09cf13eb7009076c93ed7530c296',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 14,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제5조',
#      'title': '과세기간',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#      'boundedProvisionSummary': '부가가치세의 과세기간을 규정한다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 15,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제8조',
#      'title': '사업자등록',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#      'boundedProvisionSummary': '사업자는 사업자등록을 신청해야 한다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 16,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제36조',
#      'title': '영수증 등',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#      'boundedProvisionSummary': '영수증을 발급해야 한다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'},
#     {'referenceIndex': 17,
#      'sourceType': 'OFFICIAL_LAW',
#      'lawId': '001571',
#      'officialIdentifier': '276117',
#      'lawName': '부가가치세법',
#      'articleReference': '제53조의2',
#      'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#      'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#      'jurisdiction': 'KR',
#      'promulgationDate': '20251001',
#      'effectiveDate': '20260102',
#      'retrievedAt': '2026-08-10T08:49:49.105036Z',
#      'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#      'boundedProvisionSummary': '국외사업자의 사업자등록 및 납부 등에 관한 특례를 규정한다.',
#      'queryKey': 'sha256:429aa4f8a57d8492b35af70d9b48863ff9fd0a0c6026ce94f2febbc466f58bb8',
#      'registryVersion': 'legal-registry-v1'}],
#    'deltaLegalReviews': []}},
#  'Marketing payload': {'contract': 'marketing-source-snapshot-v1',
#   'schemaVersion': '2.0',
#   'snapshotId': 'lab-marketing-source',
#   'projectId': 0,
#   'selectionId': 0,
#   'conceptId': 'C5',
#   'marketAnalysisSeedSnapshotId': 'lab-market-seed',
#   'marketAnalysisSeedSnapshotHash': 'sha256:b09efb746b893de88c33a09b9f49746338fcf07a11a97f76389d71f4d414f6cf',
#   'createdAt': '2026-08-10T08:49:55.601660+00:00',
#   'conceptName': '소형 사무실 화상회의 장비 대여 및 기술 지원 서비스',
#   'targetSegment': '10~50인 규모의 소형 사무실 운영자',
#   'problem': '소규모 사업장은 회의장비 구매 비용과 유지보수 부담 때문에 적절한 장비를 운영하기 어렵다.',
#   'valueProposition': '장비 대여와 함께 제공되는 기술 지원을 통해 고객의 불편을 최소화하고 문제를 신속하게 해결합니다.',
#   'positioning': '소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 서비스',
#   'keyFeatures': ['정기적인 장비 대여', '신속한 기술 지원 서비스', '고객 맞춤형 기술 상담'],
#   'targetRegion': '대한민국 전역',
#   'revenueModel': '구독 기반 수익 모델',
#   'price': '월 10만원~20만원 (장비 종류에 따라 상이)',
#   'pricing': '구독 기반 수익 모델 · 월 10만원~20만원 (장비 종류에 따라 상이)',
#   'channels': ['온라인 플랫폼 및 직접 영업'],
#   'competitorDifferentiators': ['신속한 기술 지원 서비스 제공, 고객 맞춤형 기술 상담'],
#   'preMarketSomShare': PreMarketSomShareHypothesis(targetSharePercent=15.0, horizonYears=3, rationale='소형 사무실의 화상회의 장비 대여 수요 증가에 따라 시장 점유율 확대 가능', assumptions=['소형 사무실의 화상회의 수요 증가', '경쟁사 대비 우수한 기술 지원 서비스 제공']),
#   'preMarketSom': PreMarketSomHypothesis(amount=50000000.0, currency='KRW', period='1년', calculationBasis='소형 사무실 500개 고객 확보 시 예상 매출', assumptions=['소형 사무실의 화상회의 장비 대여 수요 증가', '기술 지원 서비스에 대한 고객 만족도 향상'], confidence='HIGH'),
#   'legalStatus': 'IMPLEMENTABLE_WITH_CONTROLS',
#   'allowedClaims': ['신속한 기술 지원으로 고객 만족도 향상', '비용 효율적인 화상회의 솔루션 제공'],
#   'prohibitedClaims': [],
#   'requiredDisclosures': ['서비스 제공에 대한 고지 및 이용약관 명시'],
#   'requiredControls': ['고객의 개인정보 보호를 위한 처리방침 수립 및 고지',
#    '부당한 표시 및 광고 행위 금지를 위한 내부 규정 마련',
#    '고영향 인공지능에 대한 사전 검토 및 안전성 확보 조치 이행',
#    '전자상거래 관련 법령 준수를 위한 고객 정보 제공 및 신고 의무 이행',
#    '부가가치세 관련 법령 준수를 위한 사업자 등록 및 영수증 발급'],
#   'communicationRequiredControls': ['고객의 개인정보 보호를 위한 처리방침 수립 및 고지',
#    '부당한 표시 및 광고 행위 금지를 위한 내부 규정 마련',
#    '고영향 인공지능에 대한 사전 검토 및 안전성 확보 조치 이행',
#    '전자상거래 관련 법령 준수를 위한 고객 정보 제공 및 신고 의무 이행',
#    '부가가치세 관련 법령 준수를 위한 사업자 등록 및 영수증 발급'],
#   'officialEvidenceReferences': [{'referenceIndex': 0,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제3조',
#     'title': '기본원칙 및 국가 등의 책무',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:d3af532ea737d1273289ec05ed2ff55c735bccac16c517b64292d7beeccd5312',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 1,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제33조',
#     'title': '고영향 인공지능의 확인',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:3fc48c2346668bf69d17684a6ea9e0adf2b1e2deb1409e8094281cbeefa8b48d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 2,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제34조',
#     'title': '고영향 인공지능과 관련한 사업자의 책무',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:617313212eede73a9fa4de775860b754747632549637a3da96e8e1b7fc0677c4',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 3,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '014820',
#     'officialIdentifier': '282791',
#     'lawName': '인공지능 발전과 신뢰 기반 조성 등에 관한 기본법',
#     'articleReference': '제35조',
#     'title': '고영향 인공지능 영향평가',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%20%EB%B0%9C%EC%A0%84%EA%B3%BC%20%EC%8B%A0%EB%A2%B0%20%EA%B8%B0%EB%B0%98%20%EC%A1%B0%EC%84%B1%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EA%B8%B0%EB%B3%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:fb8ebf040c2029dd28b2bd73badb7e225880c1a211d422abac790f568fb5d8c5',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 4,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000030',
#     'officialIdentifier': '282481',
#     'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#     'articleReference': '제3조',
#     'title': '정보통신서비스 제공자 및 이용자의 책무',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260106',
#     'effectiveDate': '20260707',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:0f8a92d020f0e4f81e3020f1fae1178b3a63b92768de88a28f48449d7d37dd83',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 5,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '000030',
#     'officialIdentifier': '282481',
#     'lawName': '정보통신망 이용촉진 및 정보보호 등에 관한 법률',
#     'articleReference': '제4조',
#     'title': '정보통신망 이용촉진 및 정보보호등에 관한 시책의 마련',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%95%EB%B3%B4%ED%86%B5%EC%8B%A0%EB%A7%9D%20%EC%9D%B4%EC%9A%A9%EC%B4%89%EC%A7%84%20%EB%B0%8F%20%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%20%EB%93%B1%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260106',
#     'effectiveDate': '20260707',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:fa6d134f7eaa58efaed72e7d30f93e2d19c6edf8b92fb43c9f1ce70e616989e1',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 6,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제3조',
#     'title': '부당한 표시ㆍ광고 행위의 금지',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:8a232304b3941209cf6afb47ff8485dec72a80b22d8ea0bd5f72b07f583b5826',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 7,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제5조',
#     'title': '표시ㆍ광고 내용의 실증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:175e1d20e79b88964eddbcfa658507a8968209ddba38fe094bc7005015b0ba30',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 8,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제10조',
#     'title': '손해배상책임',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:9e32cfffe5aee496b1832d5e3707961c9f4280d83dc0f91deaf66f0318f1de73',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 9,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '002011',
#     'officialIdentifier': '268659',
#     'lawName': '표시ㆍ광고의 공정화에 관한 법률',
#     'articleReference': '제17조',
#     'title': '벌칙',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%ED%91%9C%EC%8B%9C%E3%86%8D%EA%B4%91%EA%B3%A0%EC%9D%98%20%EA%B3%B5%EC%A0%95%ED%99%94%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20250121',
#     'effectiveDate': '20250121',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:f8efc781c87796884bf25f8d680b1efcd4e223f5e470a5b156122d6d82e15692',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 10,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제12조',
#     'title': '통신판매업자의 신고 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:448fe0bd6a72942700268999bc17abaf1a130dc75ff98338f016366ffccb8d53',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 11,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제13조',
#     'title': '신원 및 거래조건에 대한 정보의 제공',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:6e496bba7781eda4a1e42db7cb6ead3a7f9648a8557ee96ea09e290d3f30b30d',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 12,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제17조',
#     'title': '청약철회등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:086921e6e5bc694ea2d723423f266762b50490e33b8739d64e1920b7a13bde5c',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 13,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '009318',
#     'officialIdentifier': '282793',
#     'lawName': '전자상거래 등에서의 소비자보호에 관한 법률',
#     'articleReference': '제18조',
#     'title': '청약철회등의 효과',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EC%A0%84%EC%9E%90%EC%83%81%EA%B1%B0%EB%9E%98%20%EB%93%B1%EC%97%90%EC%84%9C%EC%9D%98%20%EC%86%8C%EB%B9%84%EC%9E%90%EB%B3%B4%ED%98%B8%EC%97%90%20%EA%B4%80%ED%95%9C%20%EB%B2%95%EB%A5%A0',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20260120',
#     'effectiveDate': '20260721',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:48bb8d8484384496bed84e6eac658a1ea9dcd53ed91bc5d6291359764c102642',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 14,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제5조',
#     'title': '과세기간',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:55e12be5d081847f6c347a9be100376c35ba524c561e8d24448e063534c29ca9',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 15,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제8조',
#     'title': '사업자등록',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:f592e37dcf9ad848267be7603a224ad1645f2b8ef32bd5463d0f81b6296939b2',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 16,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제36조',
#     'title': '영수증 등',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:73a2ea65e521a0d7b21520ba72f17ce4be74a0258a17177073833853d88968f2',
#     'registryVersion': 'legal-registry-v1'},
#    {'referenceIndex': 17,
#     'sourceType': 'OFFICIAL_LAW',
#     'lawId': '001571',
#     'officialIdentifier': '276117',
#     'lawName': '부가가치세법',
#     'articleReference': '제53조의2',
#     'title': '전자적 용역을 공급하는 국외사업자의 사업자등록 및 납부 등에 관한 특례',
#     'officialSourceUri': 'https://www.law.go.kr/법령/%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EB%B2%95',
#     'jurisdiction': 'KR',
#     'promulgationDate': '20251001',
#     'effectiveDate': '20260102',
#     'retrievedAt': '2026-08-10T08:49:49.105036Z',
#     'contentHash': 'sha256:fb9766cb992d59a2c98a513510e00823fbac4ba1662f6afa5554c0e5e1e5dc18',
#     'registryVersion': 'legal-registry-v1'}],
#   'hash': 'sha256:53553d1efbd4572f8343c0d99a65daf35e7ae1dccfe40a1aa5c171654f11f21d',
#   'sourceSnapshotHash': 'sha256:53553d1efbd4572f8343c0d99a65daf35e7ae1dccfe40a1aa5c171654f11f21d'},
#  '오류': []}

# %% [markdown]
# ## 41. Trace

# %%
display(show_trace(engine.trace))
# Out:
#     순서                                시각                 stage  \
# 0    1  2026-08-10T08:44:24.989221+00:00               CREATED
# 1    2  2026-08-10T08:44:30.968378+00:00       SAFETY_CHECKING
# 2    3  2026-08-10T08:44:30.968388+00:00       SAFETY_CHECKING
# 3    4  2026-08-10T08:44:31.010373+00:00        SEED_ANALYZING
# 4    5  2026-08-10T08:44:31.010883+00:00        SEED_ANALYZING
# 5    6  2026-08-10T08:44:31.076872+00:00              PLANNING
# 6    7  2026-08-10T08:45:13.028932+00:00              PLANNING
# 7    8  2026-08-10T08:45:13.030116+00:00              PLANNING
# 8    9  2026-08-10T08:45:24.051062+00:00              PLANNING
# 9   10  2026-08-10T08:45:24.051106+00:00       PLAN_VALIDATING
# 10  11  2026-08-10T08:45:24.057260+00:00       PLAN_VALIDATING
# 11  12  2026-08-10T08:45:37.215842+00:00             EXPANDING
# 12  13  2026-08-10T08:45:48.147278+00:00             EXPANDING
# 13  14  2026-08-10T08:45:59.180506+00:00             EXPANDING
# 14  15  2026-08-10T08:46:11.356731+00:00             EXPANDING
# 15  16  2026-08-10T08:46:26.230944+00:00             EXPANDING
# 16  17  2026-08-10T08:46:26.668486+00:00  CANDIDATE_VALIDATING
# 17  18  2026-08-10T08:46:38.332271+00:00  CANDIDATE_VALIDATING
# 18  19  2026-08-10T08:46:38.332907+00:00  CANDIDATE_VALIDATING
# 19  20  2026-08-10T08:46:38.333697+00:00  CANDIDATE_VALIDATING
# 20  21  2026-08-10T08:46:38.334268+00:00  CANDIDATE_VALIDATING
# 21  22  2026-08-10T08:46:43.820159+00:00  CANDIDATE_VALIDATING
# 22  23  2026-08-10T08:46:43.820509+00:00  CANDIDATE_VALIDATING
# 23  24  2026-08-10T08:46:43.821287+00:00  CANDIDATE_VALIDATING
# 24  25  2026-08-10T08:46:43.822087+00:00  CANDIDATE_VALIDATING
# 25  26  2026-08-10T08:46:43.822141+00:00  CANDIDATE_VALIDATING
# 26  27  2026-08-10T08:46:43.884800+00:00      LEGAL_RECOVERING
# 27  28  2026-08-10T08:46:43.885114+00:00      LEGAL_RECOVERING
# 28  29  2026-08-10T08:46:43.885307+00:00      LEGAL_RECOVERING
# 29  30  2026-08-10T08:46:43.885544+00:00      LEGAL_RECOVERING
# 30  31  2026-08-10T08:46:46.792993+00:00  CANDIDATE_VALIDATING
# 31  32  2026-08-10T08:46:56.441000+00:00  CANDIDATE_VALIDATING
# 32  33  2026-08-10T08:46:56.441500+00:00  CANDIDATE_VALIDATING
# 33  34  2026-08-10T08:46:59.472730+00:00  CANDIDATE_VALIDATING
# 34  35  2026-08-10T08:46:59.473358+00:00  CANDIDATE_VALIDATING
# 35  36  2026-08-10T08:46:59.473578+00:00      LEGAL_RECOVERING
# 36  37  2026-08-10T08:46:59.473744+00:00      LEGAL_RECOVERING
# 37  38  2026-08-10T08:46:59.473932+00:00      LEGAL_RECOVERING
# 38  39  2026-08-10T08:47:01.952579+00:00      LEGAL_RECOVERING
# 39  40  2026-08-10T08:47:04.908369+00:00      LEGAL_RECOVERING
# 40  41  2026-08-10T08:47:04.908401+00:00      LEGAL_RECOVERING
# 41  42  2026-08-10T08:47:04.911628+00:00      LEGAL_RECOVERING
# 42  43  2026-08-10T08:47:04.911643+00:00      LEGAL_RECOVERING
# 43  44  2026-08-10T08:47:04.911649+00:00      LEGAL_RECOVERING
# 44  45  2026-08-10T08:47:04.911653+00:00      LEGAL_RECOVERING
# 45  46  2026-08-10T08:47:04.911658+00:00      LEGAL_RECOVERING
# 46  47  2026-08-10T08:47:05.064212+00:00       LEGAL_REVIEWING
# 47  48  2026-08-10T08:47:43.336377+00:00       LEGAL_REVIEWING
# 48  49  2026-08-10T08:47:43.364969+00:00      LEGAL_RECOVERING
# 49  50  2026-08-10T08:47:43.387391+00:00       LEGAL_REVIEWING
# 50  51  2026-08-10T08:48:26.597217+00:00       LEGAL_REVIEWING
# 51  52  2026-08-10T08:48:53.136616+00:00       LEGAL_REVIEWING
# 52  53  2026-08-10T08:49:25.163077+00:00       LEGAL_REVIEWING
# 53  54  2026-08-10T08:49:55.507439+00:00       LEGAL_REVIEWING
# 54  55  2026-08-10T08:49:55.507460+00:00      LEGAL_RECOVERING
# 55  56  2026-08-10T08:49:55.608310+00:00  PORTFOLIO_VALIDATING
#
#                                   action          entity parent  \
# 0                                CREATED             NaN    NaN
# 1                     IDEA_BRIEF_DERIVED             NaN    NaN
# 2                 READINESS_INCONSISTENT             NaN    NaN
# 3                               ANALYZED  lab-idea-brief    NaN
# 4                     DESIGN_SPACE_READY             NaN    NaN
# 5                                STARTED             NaN    NaN
# 6                       DRAFTS_GENERATED             NaN    NaN
# 7                             NORMALIZED             NaN    NaN
# 8         ARCHITECTURE_SEMANTIC_FALLBACK             NaN    NaN
# 9                                STARTED             NaN    NaN
# 10                              SELECTED             NaN    NaN
# 11                              EXPANDED              C1     P1
# 12                              EXPANDED              C2     P5
# 13                              EXPANDED              C3     P2
# 14                              EXPANDED              C4     P3
# 15                              EXPANDED              C5     P4
# 16                               STARTED             NaN    NaN
# 17        ARCHITECTURE_SEMANTIC_FALLBACK             NaN    NaN
# 18                             VALIDATED              C1    NaN
# 19                             VALIDATED              C2    NaN
# 20                    FIDELITY_AMBIGUOUS              C3    NaN
# 21             SEMANTIC_FIDELITY_CHECKED              C3    NaN
# 22                             VALIDATED              C3    NaN
# 23                             VALIDATED              C4    NaN
# 24                             VALIDATED              C5    NaN
# 25             CANDIDATE_PORTFOLIO_READY             NaN    NaN
# 26       LEGAL_FACT_COMPLETENESS_STARTED             NaN    NaN
# 27      CONCEPT_FACT_CONSISTENCY_CHECKED              C1    NaN
# 28      CONCEPT_FACT_CONSISTENCY_CHECKED              C2    NaN
# 29      CONCEPT_FACT_CONSISTENCY_CHECKED              C3    NaN
# 30                               STARTED             NaN    NaN
# 31        ARCHITECTURE_SEMANTIC_FALLBACK             NaN    NaN
# 32                    FIDELITY_AMBIGUOUS          C3-FC1    NaN
# 33             SEMANTIC_FIDELITY_CHECKED          C3-FC1    NaN
# 34                             VALIDATED          C3-FC1    NaN
# 35     CONCEPT_FACT_CONSISTENCY_REPAIRED          C3-FC1     C3
# 36      CONCEPT_FACT_CONSISTENCY_CHECKED              C4    NaN
# 37      CONCEPT_FACT_CONSISTENCY_CHECKED              C5    NaN
# 38          BUSINESS_ROLE_SEMANTIC_BATCH             NaN    NaN
# 39  LEGAL_FACT_DEPENDENCY_SEMANTIC_BATCH             NaN    NaN
# 40           BATCH_EXTRA_RESULTS_IGNORED             NaN    NaN
# 41       LEGAL_FACT_COMPLETENESS_CHECKED              C1    NaN
# 42       LEGAL_FACT_COMPLETENESS_CHECKED              C2    NaN
# 43       LEGAL_FACT_COMPLETENESS_CHECKED          C3-FC1    NaN
# 44       LEGAL_FACT_COMPLETENESS_CHECKED              C4    NaN
# 45       LEGAL_FACT_COMPLETENESS_CHECKED              C5    NaN
# 46                               STARTED             NaN    NaN
# 47                              REVIEWED              C1    NaN
# 48                               STARTED             NaN    NaN
# 49                               STARTED             NaN    NaN
# 50              CANDIDATE_SYSTEM_FAILURE              C2    NaN
# 51                              REVIEWED          C3-FC1    NaN
# 52              CANDIDATE_SYSTEM_FAILURE              C4    NaN
# 53                              REVIEWED              C5    NaN
# 54                               STARTED             NaN    NaN
# 55                     HANDOFF_VALIDATED              C5    NaN
#
#             status  mode    호출  \
# 0          RUNNING  LIVE   NaN
# 1             PASS  LIVE   1.0
# 2          WARNING  LIVE   NaN
# 3             PASS  LIVE   NaN
# 4             PASS  LIVE   NaN
# 5          RUNNING  LIVE   NaN
# 6             PASS  LIVE   2.0
# 7             PASS  LIVE   NaN
# 8             PASS  LIVE   3.0
# 9          RUNNING  LIVE   NaN
# 10            PASS  LIVE   NaN
# 11            PASS  LIVE   4.0
# 12            PASS  LIVE   5.0
# 13            PASS  LIVE   6.0
# 14            PASS  LIVE   7.0
# 15            PASS  LIVE   8.0
# 16         RUNNING  LIVE   NaN
# 17            PASS  LIVE   9.0
# 18            PASS  LIVE   NaN
# 19            PASS  LIVE   NaN
# 20         RUNNING  LIVE   NaN
# 21            PASS  LIVE  10.0
# 22            PASS  LIVE   NaN
# 23            PASS  LIVE   NaN
# 24            PASS  LIVE   NaN
# 25            PASS  LIVE   NaN
# 26         RUNNING  LIVE   NaN
# 27      CONSISTENT  LIVE   NaN
# 28      CONSISTENT  LIVE   NaN
# 29    INVALID_FACT  LIVE   NaN
# 30         RUNNING  LIVE   NaN
# 31            PASS  LIVE  12.0
# 32         RUNNING  LIVE   NaN
# 33            PASS  LIVE  13.0
# 34            PASS  LIVE   NaN
# 35            PASS  LIVE  13.0
# 36      CONSISTENT  LIVE   NaN
# 37      CONSISTENT  LIVE   NaN
# 38            PASS  LIVE  14.0
# 39            PASS  LIVE  15.0
# 40            PASS  LIVE   NaN
# 41        COMPLETE  LIVE   NaN
# 42        COMPLETE  LIVE   NaN
# 43        COMPLETE  LIVE   NaN
# 44        COMPLETE  LIVE   NaN
# 45        COMPLETE  LIVE   NaN
# 46         RUNNING  LIVE   NaN
# 47     NEEDS_INPUT  LIVE  16.0
# 48         RUNNING  LIVE   NaN
# 49         RUNNING  LIVE   NaN
# 50  SYSTEM_FAILURE  LIVE   NaN
# 51     NEEDS_INPUT  LIVE  18.0
# 52  SYSTEM_FAILURE  LIVE   NaN
# 53          ACCEPT  LIVE  20.0
# 54         RUNNING  LIVE   NaN
# 55            PASS  LIVE   NaN
#
#                                                    요약                decision  \
# 0                                  V2 Lab 실행을 생성했습니다.                     NaN
# 1   Idea interpretation/readiness를 보존했습니다: READY_F...                     NaN
# 2   READY_FOR_REVIEW이지만 score=0입니다. V2 gating은 막지 ...  READINESS_INCONSISTENT
# 3                             필수 3개와 LOCK 3개를 분류했습니다.                     NaN
# 4               Open=11 Constrained=0 Breadth=EXPLORE                     NaN
# 5                               최대 5개 동적 plan을 요청합니다.                     NaN
# 6                                   Plan draft pool=6                     NaN
# 7                         System metadata를 부여한 Plan=6                     NaN
# 8   low-confidence Plan architecture 6개를 batch 분류했...                     NaN
# 9   Opportunity·LOCK·DUPLICATE/VARIANT/DISTINCT 관계...                     NaN
# 10                                 Plans=5 Rejected=0                     NaN
# 11                                            P1 → C1                     NaN
# 12                                            P5 → C2                     NaN
# 13                                            P2 → C3                     NaN
# 14                                            P3 → C4                     NaN
# 15                                            P4 → C5                     NaN
# 16                            Candidate 검사를 분리 수행합니다.                     NaN
# 17  low-confidence Candidate architecture 5개를 batc...                     NaN
# 18                                              검사 통과                     NaN
# 19                                              검사 통과                     NaN
# 20         lexical 판정이 불확실해 semantic fidelity를 요청합니다.                     NaN
# 21  소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 ...                    PASS
# 22                                              검사 통과                     NaN
# 23                                              검사 통과                     NaN
# 24                                              검사 통과                     NaN
# 25               Candidate Portfolio=5/5, recovered=0              READY_FULL
# 26                  Candidate 5개의 법률 사실패턴 완결성을 검사합니다.                     NaN
# 27                      검사 대상 사업 사실 사이에 명백한 모순이 없습니다.              CONSISTENT
# 28                      검사 대상 사업 사실 사이에 명백한 모순이 없습니다.              CONSISTENT
# 29              Legal 전에 정정해야 할 명백한 사업 사실 자기모순이 있습니다.            INVALID_FACT
# 30                            Candidate 검사를 분리 수행합니다.                     NaN
# 31  low-confidence Candidate architecture 1개를 batc...                     NaN
# 32         lexical 판정이 불확실해 semantic fidelity를 요청합니다.                     NaN
# 33  소형 사무실에 화상회의 장비를 정기 대여하고 고장 시 교체·회수까지 제공하는 구독 ...                    PASS
# 34                                              검사 통과                     NaN
# 35                      검사 대상 사업 사실 사이에 명백한 모순이 없습니다.                     NaN
# 36                      검사 대상 사업 사실 사이에 명백한 모순이 없습니다.              CONSISTENT
# 37                      검사 대상 사업 사실 사이에 명백한 모순이 없습니다.              CONSISTENT
# 38                       불명확 역할 2개를 1회 batch로 판정했습니다.          BATCH_COMPLETE
# 39               불명확 dependency 1개를 1회 batch로 판정했습니다.          BATCH_COMPLETE
# 40  요청하지 않은 추가 의미판정 결과를 사용하지 않고 폐기했습니다. ignoredKey...           IGNORED_EXTRA
# 41               법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.                COMPLETE
# 42               법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.                COMPLETE
# 43               법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.                COMPLETE
# 44               법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.                COMPLETE
# 45               법률 사전검토에 필요한 사업 사실패턴이 구조적으로 완결되었습니다.                COMPLETE
# 46                    공식 Legal contract route를 실행합니다.                     NaN
# 47                  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.             NEEDS_INPUT
# 48                            Legal route별 복구를 수행합니다.                     NaN
# 49                    공식 Legal contract route를 실행합니다.                     NaN
# 50          이 후보의 Legal 결과 계약을 복구하지 못해 후보 단위로 제외했습니다.          SYSTEM_FAILURE
# 51                  법률검토 전에 Concept의 사업 구조를 보완해야 합니다.             NEEDS_INPUT
# 52          이 후보의 Legal 결과 계약을 복구하지 못해 후보 단위로 제외했습니다.          SYSTEM_FAILURE
# 53  고객의 개인정보 보호 및 안전한 서비스 제공을 위한 조치를 이행하며, 법령을 준수하...                  ACCEPT
# 54                            Legal route별 복구를 수행합니다.                     NaN
# 55             downstream contract compatibility=PASS                     NaN
#
#                         reasonCode
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20  CANDIDATE_FIDELITY_RECOVERABLE
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32  CANDIDATE_FIDELITY_RECOVERABLE
# 33                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# 40                             NaN
# 41                             NaN
# 42                             NaN
# 43                             NaN
# 44                             NaN
# 45                             NaN
# 46                             NaN
# 47                             NaN
# 48                             NaN
# 49                             NaN
# 50           RESULT_SCHEMA_INVALID
# 51                             NaN
# 52           RESULT_SCHEMA_INVALID
# 53                             NaN
# 54                             NaN
# 55                             NaN

# %% [markdown]
# ## 42. Provider/Legal Usage

# %%
display(show_provider_usage(engine.gateway.usage))
print('상위 외부 작업 수는 내부 AI/MOLEG 네트워크 호출 수와 동일하다고 주장하지 않습니다.')
# Out:
#    논리 작업  상위 외부 작업                                          논리 stage별  \
# 0     20        20  {'SAFETY_CHECKING': 1, 'PLANNING': 1, 'NORMALI...
#
#                                      상위 외부 작업 stage별  재시도  소요(ms)  \
# 0  {'SAFETY_CHECKING': 1, 'PLANNING': 1, 'NORMALI...    0  329153
#
#             모드별 token 보고 비용
# 0  {'LIVE': 20}  None  None
# 상위 외부 작업 수는 내부 AI/MOLEG 네트워크 호출 수와 동일하다고 주장하지 않습니다.

# %% [markdown]
# ## 43. Replay Manifest

# %%
display(show_replay_manifest(engine.gateway))
# Out:
# {'status': 'REPLAY_PARTIAL',
#  'entries':                    operation  \
#  0               LEGAL_REVIEW
#  1          SEMANTIC_RELATION
#  2              PLAN_FIDELITY
#  3                     EXPAND
#  4    NORMALIZE_ARCHITECTURES
#  ..                       ...
#  638    IDEA_BRIEF_DERIVATION
#  639       PLAN_REPLENISHMENT
#  640                PLAN_POOL
#  641  NORMALIZE_ARCHITECTURES
#  642             LEGAL_REVIEW
#
#                                                    hash operationVersion  \
#  0    00489dd62bff3c4b9e8711093fb3e398a39dde1547de32...               v3
#  1    00c1eeb4f93989a6db3891fb7a22355a71a68800a6f641...               v3
#  2    00e62d4c1a15307c38d9024cb66e28f8d13300af644fff...               v3
#  3    0120f755ef50e68db6e1d7d1adb0563892b2f762578608...               v3
#  4    013ebfc11d61a317c1041ddcf75902b1dab0d310e73666...               v1
#  ..                                                 ...              ...
#  638  fc5b3fe1b2fb09f8b0b6587abc4a067f3c1f1682a4e68c...               v2
#  639  fcc0dde517404bc3712e16384ce9f3a9c44ca5d5f06242...               v3
#  640  fd4ea7d8f4c176971dc390682c54fb6d7bc7428fa2d79a...               v3
#  641  fea1f1598d55de131f0c6485d3428dcec697b958ef73af...               v1
#  642  ff7ecbd2ee5cb90f030bc7972f25779b05155b203be50c...               v3
#
#                                      promptVersion schemaVersion  recordExists  \
#  0                         concept-legal-review-v3           2.0          True
#  1                   concept-portfolio-relation-v3           2.0          True
#  2                   concept-portfolio-fidelity-v3           2.0          True
#  3          concept-portfolio-generic-candidate-v3           2.0          True
#  4    concept-portfolio-architecture-classifier-v1           2.0          True
#  ..                                            ...           ...           ...
#  638                         idea-brief-current-v2           2.0          True
#  639             concept-portfolio-generic-plan-v3           2.0          True
#  640             concept-portfolio-generic-plan-v3           2.0          True
#  641  concept-portfolio-architecture-classifier-v2           2.0          True
#  642                       concept-legal-review-v3           2.0          True
#
#                              timestamp  versionCompatible
#  0    2026-08-10T05:26:30.277902+00:00               True
#  1    2026-08-10T05:23:00.398650+00:00               True
#  2    2026-08-10T08:46:11.451002+00:00               True
#  3    2026-08-10T07:53:56.875008+00:00               True
#  4    2026-08-10T06:48:53.957430+00:00               True
#  ..                                ...                ...
#  638  2026-08-10T08:44:30.967742+00:00               True
#  639  2026-08-10T07:55:41.833711+00:00               True
#  640  2026-08-10T04:53:21.046707+00:00               True
#  641  2026-08-10T08:46:56.440111+00:00               True
#  642  2026-08-10T05:18:41.881979+00:00               True
#
#  [643 rows x 8 columns]}

# %% [markdown]
# ## 44. One-click MOCK

# %%
mock_result = None
if LIVE_TEST_LEVEL == 'FULL_E2E' and MODE != 'LIVE':
    mock_result = await ConceptPortfolioEngine('MOCK').run_full(
        TEST_INPUT, max_concepts=MAX_CONCEPTS, auto_confirm_hypotheses=True)
display(show_run_summary(mock_result) if mock_result else {'status': 'SKIPPED'})
assert mock_result is None or (mock_result.handoff and mock_result.handoff.contractStatus == 'CONTRACT_PASS')
# Out:
# {'status': 'SKIPPED'}

# %% [markdown]
# ## 45. One-click REPLAY

# %%
RUN_ONE_CLICK_REPLAY = False
replay_result = None
if RUN_ONE_CLICK_REPLAY:
    replay_gateway = ProviderGateway('REPLAY', recordings_dir=RECORDINGS_DIR)
    replay_result = await ConceptPortfolioEngine('REPLAY', gateway=replay_gateway).run_full(
        TEST_INPUT, max_concepts=MAX_CONCEPTS, auto_confirm_hypotheses=False)
display(show_run_summary(replay_result) if replay_result else {'status': 'SKIPPED'})
# Out:
# {'status': 'SKIPPED'}

# %% [markdown]
# ## 46. One-click LIVE

# %%
RUN_ONE_CLICK_LIVE = True
live_result = None
if RUN_ONE_CLICK_LIVE and LIVE_TEST_LEVEL == 'ONE_CLICK':
    assert MODE == 'LIVE', 'MODE=LIVE를 먼저 명시하세요.'
    one_click_gateway = ProviderGateway('LIVE', recordings_dir=RECORDINGS_DIR)
    one_click_engine = ConceptPortfolioEngine('LIVE', gateway=one_click_gateway)
    live_result = await one_click_engine.run_full(TEST_INPUT, max_concepts=MAX_CONCEPTS,
                                                  auto_confirm_hypotheses=False)
display(show_run_summary(live_result) if live_result else {'status': 'SKIPPED'})
if live_result:
    display(show_live_validation_summary(LIVE_SCENARIO, live_result))
    display(show_required_inputs(live_result))
    display(show_pre_legal_exclusions(live_result))
    display(show_legal_resolutions(live_result))
    if live_result.runStatus.value == 'FAILED':
        display(show_run_failure(live_result))
        display(show_provider_failure(one_click_engine.gateway))
        display(show_provider_usage(live_result.providerUsage))
        display(show_trace(live_result.trace[-20:]))
        display({'unresolvedCandidates': live_result.unresolvedCandidates,
                 'lastSuccessfulStage': live_result.failureDiagnostics.lastSuccessfulStage if live_result.failureDiagnostics else None,
                 'firstFailedStage': live_result.failureDiagnostics.firstFailedStage if live_result.failureDiagnostics else None})
# Out:
# {'status': 'SKIPPED'}
